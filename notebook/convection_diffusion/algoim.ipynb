# %% [markdown]
# ### Dependencies for plotting

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.ticker import FormatStrFormatter




new_rc_paramas = {
    'text.usetex' : True,
    'figure.dpi' : 180,
    'text.latex.preamble' : r'\usepackage{libertine}'r'\usepackage{libertinust1math}',
    'font.family' : 'Linux Libertine',
    'axes.titlesize' : 22,
    'axes.labelsize' : 18,
    'xtick.labelsize' : 16,
    'ytick.labelsize' : 16,
    'xtick.direction' : 'in',
    'ytick.direction' : 'in',
    'xtick.top' : True,
    'ytick.right' : True,
    'legend.fontsize' : 'large',
    'axes.linewidth' : 1.2,
    'savefig.bbox' : 'tight',
    'image.aspect' : 'equal',
}

Oh2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^2)$')
Oh3 = mlines.Line2D([], [], color='black', linestyle="-.", label=r'$\mathcal{O}(h^3)$')
Oh1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h)$')
Ohneg2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-2})$')
Ohneg1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-1})$')
Odt = mlines.Line2D([], [], color='black', linestyle="--", label=r'$\mathcal{O}(\Delta t)$')
Odt2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(\Delta t^2)$')
tau1 = mlines.Line2D([], [], color='C4', linestyle="--", label=r'$\tau_0 = \tau_1 = 1$')
tau10neg4 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-4}$')
tau10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-3}$')
tau3x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-3}$')
tau5x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-3}$')
tau3x10neg4 = mlines.Line2D([], [], color='C2', linestyle="-.", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-4}$')
tau5x10neg4 = mlines.Line2D([], [], color='C3', linestyle=":", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-4}$')

circle = mlines.Line2D([0], [0], marker='o', color='black', 
                          markersize=9, markerfacecolor="None", 
                          linestyle="none", markeredgewidth=0.8,
                           label='Full Stabilization.')
                          
star = mlines.Line2D([], [], color='black', marker='*',
                          markersize=9,linestyle="none",
                        markeredgewidth=0.8, markerfacecolor="None", 
                        label='Macro Stabilization.')

triangle = mlines.Line2D([0], [0], marker='^', color='black', 
                          markersize=9, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label='Macro stab. 2')


import matplotlib.pyplot as plt

mpl.rcParams.update(new_rc_paramas)

import numpy as np

# %% [markdown]
# # **Surface problems**

# %% [markdown]
# ## *Stationary problems*

# %% [markdown]
# ### Laplace-Beltrami

# %%
# tau = 1e-6

L2_error_our_method_n5 = [0.03898794116364322, 0.008826262777246342, 0.00204293213672901, 0.0005449989146457055, 0.0001316587162743803]
L2_error_our_method_n4 = [0.03898794116364322, 0.008826262777246342, 0.00204293213672901, 0.0005449989146457055, 0.0001316587162743803]
cond_our_method_n4 = [3.892427e+08,1.333624e+09,4.957148e+09,2.028250e+10,7.877746e+10]
L2_error_our_method_n3 = [0.03898794116365693, 0.008826262777272345, 0.002042932136787824, 0.0005449989146182669, 0.0001316587155570316]
L2_error_our_method_n2 = [0.03898794116365693, 0.008826262777272345, 0.002042932136787824, 0.0005449989146182669, 0.0001316587155570316]
L2_error_our_method_n1 = [0.05057998628546215, 0.01109027130284156, 0.002545123137062884, 0.0006777378799266183, 0.000161789430665281]
L2_error_algoim_n5 = [0.0118151049859421, 0.002954749061967184, 0.0007388430885909628, 0.0001847784523110397, 4.622903254271583e-05]
L2_error_algoim_n4 = [0.01181510516942275, 0.002954749062242765, 0.0007388430886066655, 0.000184778452337938, 4.622903261257052e-05]
cond_algoim_n4 = [1.021612e+07,1.836913e+07,3.705214e+07,8.109594e+07,1.633672e+08]
L2_error_algoim_n3 = [0.01181514366364742, 0.002954749309542805, 0.0007388430896355895, 0.0001847784524518238, 4.622903252799841e-05]
cond_algoim_n3 = [1.021612e+07,1.836899e+07,3.705213e+07,8.109594e+07,1.633672e+08]
L2_error_algoim_n2 = [0.01273723511816915, 0.002954100866245891, 0.0007387648372536154, 0.0001847736746812884, 4.622871032354223e-05]
cond_algoim_n2 = [1.521135e+07,2.049386e+07,3.794153e+07,8.165724e+07,1.636757e+08]
L2_error_algoim_n1 = [6047.971666312436, 1261.694660416631, 275.2016899063397, 91.85767255876078, 21.53736768932204]
cond_algoim_n1 = [1.035993e+09,4.984849e+09,2.311679e+10,1.062719e+11,4.718923e+11]


# n = 5

# triangle
L2_error_our_method_tau1eneg6 = [0.03898794116364322, 0.008826262777246342, 0.00204293213672901, 0.0005449989146457055, 0.0001316587162743803]
cond_our_method_tau1eneg6 = [3.892427e+08,1.333624e+09,4.957148e+09,2.028250e+10,7.877746e+10]
L2_error_our_method_tau001 = [0.03983776681492464, 0.009099595508430281, 0.002117917730143056, 0.0005684419717935645, 0.000137771811986836]
cond_our_method_tau001 = [4.316052e+04,1.503848e+05,5.667317e+05,2.359491e+06,9.157906e+06]
L2_error_our_method_tau1 = [0.1178538441684013, 0.03059806598783113, 0.007685081870215948, 0.001950731792232045, 0.0004858822696359949]
cond_our_method_tau1 = [8.072217e+03,3.148363e+04,1.260369e+05,5.017587e+05,2.014082e+06]
L2_error_our_method_tau10 = [0.6334176451820015, 0.2198732939541899, 0.06148894891919354, 0.01589853811453799, 0.004009543380405278]
cond_our_method_tau10 = [7.115947e+04,2.813124e+05,1.131600e+06,4.490858e+06,1.806957e+07]

# algoim (not affected by the implementation of Gradlambda)
L2_error_algoim_tau1eneg10 = [0.01181399354886422, 0.002954192136268045, 0.000738562220711243, 0.0001846373908018902, 4.615839161062968e-05]
cond_algoim_tau1eneg10 = [1.021424e+11,1.071428e+11,1.107941e+11,3.443095e+11,1.391970e+12]
L2_error_algoim_tau1eneg6 = [0.01181510493965883, 0.00295474906188485, 0.0007388430885907656, 0.000184778452311029, 4.622903254273037e-05]
cond_algoim_tau1eneg6 = [1.021612e+07,1.836913e+07,3.705214e+07,8.109594e+07,1.633672e+08]
#L2_error_algoim_tau0001 = 
#cond_algoim_tau0001 = 
L2_error_algoim_tau001 = [0.01563808642982922, 0.004035512317426796, 0.001014343202982364, 0.0002501735854112109, 6.24416732899902e-05]
cond_algoim_tau001 = [1.856271e+04,8.085469e+04,3.552918e+05,1.568951e+06,6.791694e+06] 
L2_error_algoim_tau1 = [0.07247088724046104, 0.01854101302817378, 0.004576304079982843, 0.001127601931799673, 0.0002782951563318408]
cond_algoim_tau1 = [3.599492e+03,1.602841e+04,7.255759e+04,3.277493e+05,1.444198e+06]
L2_error_algoim_tau10 = [0.3713385154495941, 0.1109676464097616, 0.02992853783386599, 0.007803799274722737, 0.00196764678659277]
cond_algoim_tau10 = [2.428679e+04,9.348410e+04,3.699054e+05,1.472275e+06,5.882178e+06]

# quad  (pseudo-implemented normals) (error explodes when I put GradL = 1./4)
L2_error_quad_tau001 = [0.01464707225952362, 0.003562205605499552, 0.0008567588951288246, 0.0002039884120580569, 4.93511130599844e-05]
cond_quad_tau001 = [6.624178e+04,2.689877e+05,1.057301e+06,4.845121e+06,1.914560e+07]

# DG MACRO, ouble tau1 = 1, tau2 = 1, tau3 = 0.1, lambda = 50
dg_error = [0.0432522, 0.00886489, 0.00238076, 0.000551376, 0.000139415]

# length error
len_err_our_method_n5 = [0.006899800693971336, 0.001843803227699503, 0.0004789429209068885, 0.000117758939700785, 3.00836749964617e-05]
len_err_our_method_n4 = [0.006899800693971336, 0.001843803227699503, 0.0004789429209068885, 0.000117758939700785, 3.00836749964617e-05]
len_err_our_method_n3 = [0.006899800693957125, 0.001843803227710161, 0.0004789429209068885, 0.0001177589396963441, 3.008367501511344e-05]
len_err_our_method_n2 = [0.006899800693957125, 0.001843803227710161, 0.0004789429209068885, 0.0001177589396963441, 3.008367501511344e-05]
len_err_our_method_n1 = [0.006899800693952685, 0.001843803227704832, 0.0004789429209148821, 0.0001177589396981205, 3.008367500090259e-05]

len_err_algoim_n7 = [4.281019982954604e-13, 4.174438572590589e-13, 4.130029651605582e-13, 4.11226608321158e-13, 3.916866830877552e-13]
len_err_algoim_n5 = [1.394440118929197e-12, 4.174438572590589e-13, 4.174438572590589e-13, 4.005684672847565e-13, 4.076738946423575e-13]
len_err_algoim_n4 = [2.205631233209715e-10, 7.842615445952106e-13, 4.360956040727615e-13, 4.2543746303636e-13, 4.307665335545607e-13]
len_err_algoim_n3 = [5.25624841429817e-08, 4.401039532808682e-10, 4.108713369532779e-12, 5.577760475716786e-13, 4.378719609121617e-13]
len_err_algoim_n2 = [1.440195829705004e-05, 6.020963905228882e-07, 2.549082278591186e-08, 2.652730479724141e-09, 1.372741920135923e-10]
len_err_algoim_n1 = [0.005770539249222217, 0.001212662641460582, 0.0002646356907307634, 7.7692238549254e-05, 1.817964112671433e-05]

h = [0.1, 0.05, 0.025, 0.0125, 0.00625]


fig1, ax1 = plt.subplots()

ax1.loglog(h, 5.7e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

ax1.loglog(h, L2_error_our_method_n2,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Piece-wise linear, $n=2$")
ax1.loglog(h, L2_error_our_method_n3,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Piece-wise linear, $n=3$")
ax1.loglog(h, L2_error_our_method_n4,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Piece-wise linear, $n=4$")
ax1.loglog(h, L2_error_algoim_n2,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Algoim, $n=2$")
ax1.loglog(h, L2_error_algoim_n3,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Algoim, $n=3$")
ax1.loglog(h, L2_error_algoim_n4,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Algoim, $n=4$")


ax1.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.set_xlabel(r"$h$ (log)", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$L^2$ error (log)", fontsize=22)
ax1.set_title(r"Laplace-Beltrami, $\tau = 10^{-6}$")

plt.show()


fig2, ax2 = plt.subplots()

ax2.loglog(h, 5.7e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

#ax2.loglog(h, L2_error_our_method_tau1eneg6,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Piece-wise linear, $\tau_1 = 10^{-6}$")
ax2.loglog(h, L2_error_our_method_tau001,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Piece-wise linear, $\tau_1 = 0.01$")
#ax2.loglog(h, L2_error_our_method_tau1,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Piece-wise linear, $\tau_1 = 1$")
#ax2.loglog(h, L2_error_our_method_tau10,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Piece-wise linear, $\tau_1 = 10$")

#ax2.loglog(h, L2_error_algoim_tau1eneg10,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C5", label=r"Algoim, $\tau_1 = 10^{-10}$")
#ax2.loglog(h, L2_error_algoim_tau1eneg6,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Algoim, $\tau_1 = 10^{-6}$")
ax2.loglog(h, L2_error_algoim_tau001,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Algoim, $\tau_1= 0.01$")
#ax2.loglog(h, L2_error_algoim_tau1,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Algoim, $\tau_1 = 1$")
#ax2.loglog(h, L2_error_algoim_tau10,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Algoim, $\tau_1 = 10$")

ax2.loglog(h, L2_error_quad_tau001,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Quad, $\tau_1= 0.01$")


ax2.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$L^2$ error (log)", fontsize=22)
ax2.set_title(r"Laplace-Beltrami, $n=5$")

plt.show()
#fig1.savefig("output/reynold_error_example1.pdf", bbox_inches="tight")

fig3, ax3 = plt.subplots()

ax3.loglog(h, 1e3*np.power(h, -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

#ax3.loglog(h, cond_our_method_tau1eneg6,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Piece-wise linear, $\tau_1 = 10^{-6}$")
ax3.loglog(h, cond_our_method_tau001,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Piece-wise linear, $\tau_1 = 0.01$")
#ax3.loglog(h, cond_our_method_tau1,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Piece-wise linear, $\tau_1 = 1$")
#ax3.loglog(h, cond_our_method_tau10,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Piece-wise linear, $\tau_1 = 10$")
#ax3.loglog(h, cond_algoim_tau1eneg6,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Algoim, $\tau_1 = 10^{-6}$")
ax3.loglog(h, cond_algoim_tau001,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Algoim, $\tau_1= 0.01$")
#ax3.loglog(h, cond_algoim_tau1,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Algoim, $\tau_1 = 1$")
#ax3.loglog(h, cond_algoim_tau10,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Algoim, $\tau_1 = 10$")
ax3.loglog(h, cond_quad_tau001,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Quad, $\tau_1= 0.01$")

ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
ax3.set_title(r"Laplace-Beltrami, $n=5$")

plt.show()

fig4, ax4 = plt.subplots()

ax4.loglog(h, 5.7e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

ax4.loglog(h, len_err_our_method_n1,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Length error, $n=1$")
ax4.loglog(h, len_err_our_method_n2,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Length error, $n=2$")
ax4.loglog(h, len_err_our_method_n3,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Length error, $n=3$")
ax4.loglog(h, len_err_our_method_n4,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Length error, $n=4$")

ax4.loglog(h, L2_error_our_method_n2,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$L^2$ error, $n=2$")
ax4.loglog(h, L2_error_our_method_n3,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$L^2$ error, $n=3$")
ax4.loglog(h, L2_error_our_method_n4,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$L^2$ error, $n=4$")

ax4.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$h$ (log)", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
ax4.set_ylabel(r"$|2\pi - |\Gamma_h||$ (log)", fontsize=22)
ax4.set_title(r"Length error, Our method")

plt.show()

fig5, ax5 = plt.subplots()

ax5.loglog(h, 5.7e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax5.loglog(h, len_err_algoim_n1,  marker='^', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Length error, $n=1$")
ax5.loglog(h, len_err_algoim_n2,  marker='^', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Length error, $n=2$")
ax5.loglog(h, len_err_algoim_n3,  marker='^', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Length error, $n=3$")
ax5.loglog(h, len_err_algoim_n4,  marker='^', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Length error, $n=4$")

ax5.loglog(h, L2_error_algoim_n2,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$L^2$ error, $n=2$")
ax5.loglog(h, L2_error_algoim_n3,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$L^2$ error, $n=3$")
ax5.loglog(h, L2_error_algoim_n4,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$L^2$ error, $n=4$")

ax5.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax5.set_xlabel(r"$h$ (log)", fontsize=18)
ax5.tick_params(axis='both', which='major', labelsize=17)
ax5.set_ylabel(r"$|2\pi - |\Gamma_h||$ (log)", fontsize=22)
ax5.set_title(r"Length error, Algoim")

plt.show()

# %% [markdown]
# ### Stationary surface convection diffusion

# %%
betaconst = False

if betaconst:
    ### beta = [0.4, 0.6]

    # triangle
    L2_error_our_method_tau001 = [0.04200304529010726, 0.009651599682742745, 0.002257200217708357, 0.0006036847250085222, 0.0001466368663914628]
    cond_our_method_tau001 = [4.316603e+04,1.503889e+05,5.667354e+05,2.359494e+06,9.157909e+06]

    # algoim
    L2_error_algoim_tau001 = [0.01604443892556477, 0.004138675039356573, 0.001040197291846799, 0.0002566215594527008, 6.405144151436549e-05]
    cond_algoim_tau001 = [1.856622e+04,8.085814e+04,3.552957e+05,1.568955e+06,6.791699e+06]

    # quad  (pseudo-implemented normals) (error explodes when I put GradL = 1./4)
    L2_error_quad_tau001 = [0.01501674218713291, 0.003653180947946062, 0.0008794941725602698, 0.0002102524439026384, 5.093826298278086e-05]
    cond_quad_tau001 = [6.629762e+04,2.690417e+05,1.057353e+06,4.845178e+06,1.914566e+07]

else:
    ### beta = [y, -x]

    # triangle
    L2_error_our_method_tau001 = [0.03821710229422395, 0.008646462409536662, 0.001978267291622685, 0.0005464309897732437, 0.000131912616556981]
    cond_our_method_tau001 = [4.316046e+04,1.503843e+05,5.667299e+05,2.359487e+06,9.157902e+06]

    # algoim
    L2_error_algoim_tau001 = [0.01516521913153729, 0.003894048502260368, 0.0009739246262441643, 0.0002369058156759803, 5.8664164903454e-05]
    cond_algoim_tau001 = [1.704927e+04,7.591568e+04,3.433304e+05,1.802197e+06,7.576800e+06]

    # quad  (pseudo-implemented normals) (error explodes when I put GradL = 1./4)
    L2_error_quad_tau001 = [0.01402053142208245, 0.003409828534637136, 0.0008180813436670271, 0.0001860624699211108, 4.505168019854792e-05]
    cond_quad_tau001 = [6.371264e+04,2.632026e+05,1.052667e+06,5.022735e+06,1.910010e+07]

h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig2, ax2 = plt.subplots()

ax2.loglog(h, 2.3e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")


ax2.loglog(h, L2_error_our_method_tau001,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Piece-wise linear, $\tau_1 = 0.01$")
ax2.loglog(h, L2_error_algoim_tau001,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Algoim, $\tau_1= 0.01$")
ax2.loglog(h, L2_error_quad_tau001,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Quad, $\tau_1= 0.01$")


ax2.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$L^2$ error (log)", fontsize=22)
if betaconst:
    ax2.set_title(r"Surface, $\beta = [0.4,\ 0.6]$")
else:
    ax2.set_title(r"Surface, $\beta = [y,\ -x]$")

plt.show()
#fig1.savefig("output/reynold_error_example1.pdf", bbox_inches="tight")

fig3, ax3 = plt.subplots()

ax3.loglog(h, 1e3*np.power(h, -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

ax3.loglog(h, cond_our_method_tau001,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Piece-wise linear, $\tau_1 = 0.01$")
ax3.loglog(h, cond_algoim_tau001,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Algoim, $\tau_1= 0.01$")
ax3.loglog(h, cond_quad_tau001,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Quad, $\tau_1= 0.01$")

ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
if betaconst:
    ax3.set_title(r"Surface, $\beta = [0.4,\ 0.6]$")
else:
    ax3.set_title(r"Surface, $\beta = [y,\ -x]$")

plt.show()

# %% [markdown]
# ## *Time-dependent problems*

# %% [markdown]
# ### Deckelnick 2 shifting study with algoim
#
# We look at the exact solution $$u(t,x,y) = e^{-4t}y(x+\frac{1}{2}-2t) + \delta$$ and solve the surface equation on the unit sphere, initially centered in $(-0.5,0)$ moving with $\beta = [2,0]^T$, and investigate the numerical solutions for the two schemes as we vary $\delta$.
#
# We set $\tau_1 = 1$, $\Delta t_n = h/4$, $T=0.5$, and we look at both the $L^2$ error and the condition number.

# %%
L2_error_conservative_delta0 = np.array([0.00683999, 0.00172723, 0.0004311, 0.00010739, 2.69884e-05])    
condition_number_conservative_delta0 = np.array([2.694977e+04,7.687256e+04,2.135206e+05,6.456964e+05,2.108137e+06])

L2_error_conservative_delta0_algoim = [0.0007974248730181818, 0.0002006446413480273, 5.440404601487312e-05]
condition_number_conservative_delta0_algoim = [3.156793e+04,1.064058e+05,3.705868e+05]

# Non-conservative
L2_error_classical_delta0 = np.array([0.00684464, 0.00172538, 0.000431005, 0.000107127, 2.67838e-05])
#condition_number_classical_delta0 = np.array()

L2_error_classical_delta0_algoim = [0.0008001362194968954, 0.0001978229713840776, 4.911420070297627e-05]
condition_number_classical_delta0_algoim = [3.146236e+04,1.059381e+05,3.710772e+05]

### delta = 1
# Conservative
L2_error_conservative_delta1 = np.array([0.00699495, 0.00177728, 0.00047092, 0.000159315, 6.67664e-05])
condition_number_conservative_delta1 = np.array([2.694977e+04,7.687256e+04,2.135206e+05,6.456964e+05,2.108137e+06])

# Non-conservative
L2_error_classical_delta1 = np.array([0.00684464, 0.00172538, 0.000431005, 0.000107127, 2.67838e-05])
condition_number_classical_delta1 = np.array([2.688649e+04,7.674337e+04,2.136327e+05,6.454918e+05,2.108123e+06])



### delta = 2
# Conservative
L2_error_conservative_delta2 = np.array([0.00731393, 0.00192853, 0.000571934, 0.000253921, 0.000122898])    #[0.007287658235855706, 0.001927195714789306, 0.0006031734603858412] with not sqrt on level set
condition_number_conservative_delta2 = np.array([2.694977e+04,7.687256e+04,2.135206e+05,6.456964e+05,2.108137e+06])

L2_error_conservative_delta2_algoim = [0.008449613360727396, 0.00376579573330354, 0.002114641668127267, 0.0008022643332180558]

# Non-conservative (time 1465 s)
L2_error_classical_delta2 = [0.006752574932349046, 0.00170053121658419, 0.0004251018667079989, 0.0001059052528370006, 2.642707254440119e-05]    #np.array([0.00684464, 0.00172538, 0.000431005, 0.000107127, 2.67838e-05])   
condition_number_classical_delta2 = [2.687178e+04,7.653216e+04,2.128620e+05,6.414554e+05,2.087441e+06]  #np.array([2.688649e+04,7.674337e+04,2.136327e+05,6.454918e+05,2.108123e+06])

# time algoim: 1237 s
L2_error_classical_delta2_algoim = [0.0008001362195178283, 0.0001978229713700144, 4.911420081073756e-05, 1.224300439238931e-05, 3.051882138684911e-06]
condition_number_classical_delta2_algoim = [3.146236e+04,1.059381e+05,3.710772e+05,1.437329e+06,5.774941e+06]


h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig1, ax1 = plt.subplots()

ax1.loglog(h, 3.7e-1*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
# delta = 0
ax1.loglog(h, L2_error_conservative_delta0,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, $\delta = 0$")
ax1.loglog(h[:-2], L2_error_conservative_delta0_algoim,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, color="C0", label=r"Conservative, $\delta = 0$, algoim")
ax1.loglog(h, L2_error_classical_delta0,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, $\delta = 0$")
ax1.loglog(h, L2_error_classical_delta2_algoim,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, color="C0", label=r"Non-conservative, $\delta = 0$, algoim")

#ax1.loglog(h[:-2], L2_error_classical_delta0_algoim,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8,  color="C0", label=r"Non-conservative, $\delta = 0$, algoim")

# delta = 1
ax1.loglog(h, L2_error_conservative_delta1,  marker='^', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, $\delta = 1$")
#ax1.loglog(h, L2_error_classical_delta1_tau1,  marker='^', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, $\delta = 1$, $\tau_1 = 1$")

# delta = 2
ax1.loglog(h, L2_error_conservative_delta2,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, $\delta = 2$")
ax1.loglog(h[:-1], L2_error_conservative_delta2_algoim,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, color="C3", label=r"Conservative, $\delta = 2$, algoim")


ax1.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.set_xlabel(r"$h$ (log)", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$L^2$ error (log)", fontsize=22)
ax1.set_title(r"Deckelnick 2 for different $\delta$", fontsize=22)

plt.show()

fig2, ax2 = plt.subplots()

ax2.loglog(h, 3.7e2*np.power(h, -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
# delta = 0
ax2.loglog(h, condition_number_conservative_delta0,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, $\delta = 0$")
#ax1.loglog(h, condition_number_classical_delta0,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, $\delta = 0$")

ax2.loglog(h[:-2], condition_number_conservative_delta0_algoim,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, color="C0", label=r"Conservative, $\delta = 0$, algoim")
ax2.loglog(h[:-2], condition_number_classical_delta0_algoim,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8,  color="C0", label=r"Non-conservative, $\delta = 0$, algoim")

# delta = 1
ax2.loglog(h, condition_number_conservative_delta1,  marker='^', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, $\delta = 1$")
ax2.loglog(h, condition_number_classical_delta1,  marker='^', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, $\delta = 1$")

# delta = 2
ax2.loglog(h, condition_number_conservative_delta2,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, $\delta = 2$")
#ax1.loglog(h[:-1], condition_number_conservative_delta2_algoim,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, color="C3", label=r"Conservative, $\delta = 2$, algoim")
ax2.loglog(h, condition_number_classical_delta2_algoim,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, color="C0", label=r"Non-conservative, $\delta = 0$, algoim")

ax2.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$\kappa(A)$ (log)", fontsize=22)
ax2.set_title(r"Condition number for different $\delta$", fontsize=22)

plt.show()

# %% [markdown]
# ### Deckelnick 2, $\delta = 2$
#
# We look at the exact solution $$u(t,x,y) = e^{-4t}y(x+\frac{1}{2}-2t) + 2$$ and solve the surface equation on the unit sphere, initially centered in $(-0.5,0)$ moving with $\beta = [2,0]^T$, and investigate the numerical solutions for the two schemes as we vary problem parameters such as $n$ and $\Delta t$.
#
# We set $\tau_1 = 1$, $\Delta t_n = h/4$, $T=0.5$, and we look at both the $L^2$ error and the condition number.
#
# We use C stabilization.

# %%
# delta = 2

# n = 3

# Conservative
L2_error_conservative_n3 = np.array([0.00731393, 0.00192853, 0.000571934, 0.000253921, 0.000122898])    #[0.007287658235855706, 0.001927195714789306, 0.0006031734603858412] with not sqrt on level set
condition_number_conservative_n3 = np.array([2.694977e+04,7.687256e+04,2.135206e+05,6.456964e+05,2.108137e+06])

L2_error_conservative_n3_algoim = [0.008449613360727396, 0.00376579573330354, 0.002114641668127267, 0.0008022643332180558]

# Non-conservative (time 1465 s)
L2_error_classical_n3 = [0.006752574932349046, 0.00170053121658419, 0.0004251018667079989, 0.0001059052528370006, 2.642707254440119e-05]    #np.array([0.00684464, 0.00172538, 0.000431005, 0.000107127, 2.67838e-05])   
condition_number_classical_n3 = [2.687178e+04,7.653216e+04,2.128620e+05,6.414554e+05,2.087441e+06]  #np.array([2.688649e+04,7.674337e+04,2.136327e+05,6.454918e+05,2.108123e+06])

# time algoim: 1237 s
L2_error_classical_n3_algoim = [0.0008001362195178283, 0.0001978229713700144, 4.911420081073756e-05, 1.224300439238931e-05, 3.051882138684911e-06]
condition_number_classical_n3_algoim = [3.146236e+04,1.059381e+05,3.710772e+05,1.437329e+06,5.774941e+06]


# n = 7

L2_error_conservative_n7 = [0.00716968, 0.00183254, 0.000458558, 0.000115999, 3.40878e-05]
L2_error_conservative_n7_algoim = [0.002075258179865079, 0.0009717813656852353, 0.000245298294677182, 0.000152889925925723, 7.122353383152478e-05]  #time 2213 s

# time algoim: 2205 s
L2_error_classical_n7_algoim = [0.0009491677493564191, 0.00021315841328999, 5.815513878942588e-05, 1.214354001420134e-05, 3.03485514535732e-06]


# n = 7, tau = 10
L2_error_conservative_n7_algoim_tau10 = [0.001946908429275574, 0.0008636273753438907, 0.0001314909196814999, 9.1852938798959e-05, 2.404738908891995e-05]


h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig1, ax1 = plt.subplots()

ax1.loglog(h, 3.7e-1*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

#ax1.loglog(h[:-2], L2_error_classical_delta0_algoim,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8,  color="C0", label=r"Non-conservative, $\delta = 0$, algoim")

# n = 3
ax1.loglog(h, L2_error_conservative_n3,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, $n = 3$")
ax1.loglog(h, L2_error_classical_n3,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, $n=3$")

ax1.loglog(h[:-1], L2_error_conservative_n3_algoim,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, color="C0", label=r"Conservative, $n=3$, algoim")
ax1.loglog(h, L2_error_classical_n3_algoim,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, color="C0", label=r"Non-conservative, $n = 3$, algoim")


ax1.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.set_xlabel(r"$h$ (log)", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$L^2$ error (log)", fontsize=22)
ax1.set_title(r"Deckelnick 2 for $n=3$", fontsize=22)

plt.show()

fig2, ax2 = plt.subplots()

ax2.loglog(h, 3.7e-1*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

# n = 7
ax2.loglog(h, L2_error_conservative_n7,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, $n = 7$")
ax2.loglog(h, L2_error_classical_n3,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Non-conservative, $n=7$")

ax2.loglog(h, L2_error_conservative_n7_algoim,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, color="C3", label=r"Conservative, $n=7$, algoim")
ax2.loglog(h, L2_error_classical_n7_algoim,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, color="C3", label=r"Non-conservative, $n = 7$, algoim")

ax2.loglog(h, L2_error_conservative_n7_algoim_tau10,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, color="C4", label=r"Conservative, $n = 7$, $\tau = 10$,algoim")


ax2.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$L^2$ error (log)", fontsize=22)
ax2.set_title(r"Deckelnick 2 for $n=7$", fontsize=22)

plt.show()


fig3, ax3 = plt.subplots()

ax3.loglog(h, 3.7e-1*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")


ax3.loglog(h, L2_error_conservative_n7_algoim,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, color="C3", label=r"Conservative, $\tau = 1$, algoim")
ax3.loglog(h, L2_error_classical_n7_algoim,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, color="C3", label=r"Non-conservative, $\tau = 1$, algoim")

ax3.loglog(h, L2_error_conservative_n7_algoim_tau10,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, color="C4", label=r"Conservative, $\tau = 10$, algoim")


ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"$L^2$ error (log)", fontsize=22)
ax3.set_title(r"Deckelnick 2 for $n=7$", fontsize=22)

plt.show()

# %% [markdown]
# ### Example 1
# C stabilization with $\Delta t = h/4$ and $n=3$.

# %%
### tau = 0.1

# Conservative
L2_error_conservative_fullstab_tau01 = np.array([0.00800323, 0.00202853, 0.000510264, 0.000120384, 3.43877e-05])


# L2_error_conservative_macro_tau01 = np.array()
### tau = 0.1
L2_error_classical_tau01 = [0.00733337672759482, 0.001854283244404721, 0.0004486983624887922, 0.0001197477403527553, 3.043058394950553e-05]
L2_error_classical_tau01_algoim = [0.005226892141940665, 0.001497094527498031, 0.0004395773016004504, 0.0001609626627747234, 5.40542910177091e-05]     # without n in face stabilization
L2_error_classical_tau01_quad = [0.006511645208998354, 0.001356180026100853, 0.000439227969968623, 0.0001619735227924727, 5.682641412527358e-05]


# # Classical
# L2_error_classical_fullstab_tau01 = np.array([0.00780156, 0.00194555, 0.000480089, 0.000126057, 3.18969e-05])
# L2_error_classical_tau1_C_algoim = [0.005676021330265076, 0.001723507948987314, 0.0005077338859437803, 0.0001659201037832795, 5.650847422411849e-05] # C stabilization, tau = 1
# L2_error_classical_tau01_hh_algoim = [0.005126442948316681, 0.001530898184212822, 0.0004425184611920048, 0.0001567541205409538, 4.31391435391031e-05]
# L2_error_classical_tau01_C_algoim = [0.005226892141941269, 0.001497094527496402, 0.0004395773016006475, 0.0001609626627672095, 5.405429102602527e-05]


h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig3, ax3 = plt.subplots()

ax3.loglog(h, 2.4e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

ax3.loglog(h, L2_error_classical_tau01,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, $\tau = 0.1$, triangle")
ax3.loglog(h, L2_error_classical_tau01_algoim,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, $\tau = 0.1$, algoim")
ax3.loglog(h, L2_error_classical_tau01_quad,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, $\tau = 0.1$, quad")


ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=18)
ax3.set_ylabel(r"$L^2$ error (log)", fontsize=22)
#ax3.set_title(r"Example 1 on $\Gamma(t)$")
#ax3.set_title(r"Example 5")
#fig3.savefig("example1_Gamma_t.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# # **Bulk problems**

# %% [markdown]
# ## *Stationary problems*

# %% [markdown]
# ### Stationary bulk convection-diffusion

# %%
diffusion = True
convdiffconstvel = False
convdiff = False

# we use dirichlet conditions on outer boundary and neumann on the interface

if convdiffconstvel:
    ### beta = [0.4, 0.6]

    # triangle
    L2_error_our_method_tau001 = [0.03684992927070726, 0.007597715019822966, 0.001655921263824495, 0.0003832993270266832, 9.210179589656891e-05]

    # # algoim
    L2_error_algoim_tau001 = [0.03241842807711362, 0.01209389757966569, 0.006138744223362889, 0.003158640871639394, 0.001607132319514999]

    # # quad  (pseudo-implemented normals) (error explodes when I put GradL = 1./4)
    L2_error_quad_tau001 = [0.03165903814759718, 0.01203723950736168, 0.006155746563740907, 0.00316650945445701, 0.00160951011444884]

elif convdiff:
    ### beta = [y, -x]

    # triangle
    L2_error_our_method_tau001 = [0.03547471164381925, 0.007354173208337999, 0.001611258584023636, 0.000373998325143838, 8.999686997807584e-05]

    # algoim
    L2_error_algoim_tau001 = [0.03941655169072561, 0.01355138547142143, 0.006091755860977397, 0.002947260388007126, 0.001461024641524639]

    # quad  (pseudo-implemented normals) (error explodes when I put GradL = 1./4)
    L2_error_quad_tau001 = [0.03858641860905951, 0.01338936007881146, 0.006070569824077274, 0.002944819723131353, 0.001460772285948527]

elif diffusion:
    
    # triangle
    L2_error_our_method_tau001 = [0.03640548839171155, 0.007546534295977474, 0.001651643470962442, 0.0003830266561869374, 9.212168945261744e-05]

    # algoim
    L2_error_algoim_tau001 = [0.03969611894660221, 0.01346576963850211, 0.00598215793875443, 0.002881782699044602, 0.001422599334023035]
    # dirichlet both boundaries: [0.01906679374313905, 0.006950936452001711, 0.003106287242124739, 0.001535097529926159, 0.000774926884265229]

    # quad  (independent if normals are implemented or not when not using *n on interface, if n is used on interface it is sensitive)
    L2_error_quad_tau001 = [0.03880374935477038, 0.01328774546141208, 0.005958534761112879, 0.002879056093436271, 0.001422318567078936]

    # dirichlet both boundaries, quasi-implemented normals: [0.01917002288369608, 0.006957929905219546, 0.003105283651134297, 0.001534602267435356, 0.0007747723984665956]
    # dirichlet both boundaries, normals=1/4: [0.0182974811992856, 0.008305709657916846, 0.01395788991119232, 0.00198050619248382, 0.001045816969708738]


h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig2, ax2 = plt.subplots()

ax2.loglog(h, 1.5e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax2.loglog(h, 1.5e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="--", color="black")


ax2.loglog(h, L2_error_our_method_tau001,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Piece-wise linear, $\tau_1 = 0.01$")
ax2.loglog(h, L2_error_algoim_tau001,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Algoim, $\tau_1= 0.01$")
ax2.loglog(h, L2_error_quad_tau001,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Quad, $\tau_1= 0.01$")


ax2.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$L^2$ error (log)", fontsize=22)
ax2.set_title(r"Surface Convection Diffusion")

plt.show()
#fig1.savefig("output/reynold_error_example1.pdf", bbox_inches="tight")

# fig3, ax3 = plt.subplots()

# ax3.loglog(h, 1e3*np.power(h, -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

# #ax3.loglog(h, cond_our_method_tau001,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Piece-wise linear, $\tau_1 = 0.01$")
# #ax3.loglog(h, cond_algoim_tau001,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Algoim, $\tau_1= 0.01$")
# #ax3.loglog(h, cond_quad_tau001,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Quad, $\tau_1= 0.01$")

# ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
# ax3.set_xlabel(r"$h$ (log)", fontsize=18)
# ax3.tick_params(axis='both', which='major', labelsize=17)
# ax3.set_ylabel(r"Condition number (log)", fontsize=22)
# ax3.set_title(r"Surface Convection Diffusion")

# plt.show()

# %% [markdown]
# ## *Time-dependent problems*

# %% [markdown]
# ### Example 1 in $\Omega_2(t)$

# %%
### tau = 5e-3

# Classical
L2_error_classical_fullstab_tau5eneg3 = [0.00172042, 0.0009469, 7.43673e-05, 1.74078e-05, 4.9032e-06]
cond_classical_fullstab_tau5neg3 = [8.473886e+02,9.672338e+02,9.811114e+02,8.788197e+02,1.394101e+03]
L2_error_classical_fullstab_tau5eneg3_algoim = [0.00118897, 0.000426416, 0.000182481, 9.65508e-05, 5.18822e-05]
cond_classical_fullstab_tau5neg3_algoim = [2.910935e+03,1.761169e+03,1.086165e+03,1.199063e+03,1.285984e+03]

L2_error_classical_fullstab_tau5eneg3_quad = [0.00156229, 0.00054886, 0.000190689, 0.000101804, 5.68408e-05]


length_error_algoim = np.fabs(np.array([1.068139283424453, 1.068141501299539, 1.068141502215956, 1.068141502220527, 1.068141502220527]) - 2*np.pi*0.17)
area_error_algoim = np.fabs(np.array([0.09079203947201836, 0.090792027695672, 0.09079202768877627, 0.09079202768874028, 0.09079202768873357]) - np.pi*0.17**2)

length_error_quad = np.fabs(np.array([1.020456355848041, 1.056392391588329, 1.065295533473755, 1.0674437870886, 1.067961984671567]) - 2*np.pi*0.17)
area_error_quad = np.fabs(np.array([0.08020342666983191, 0.08816439551257044, 0.09014332560602371, 0.09063232731098403, 0.09075117732387411]) - np.pi*0.17**2)


h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig3, ax3 = plt.subplots()

ax3.loglog(h, 2.4e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
#ax3.loglog(h, 2.4e-1*np.power(h, 1.75), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

#* n = 3


ax3.loglog(h, L2_error_classical_fullstab_tau5eneg3,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Non-conservative, $\tau = 0.005$, triangle")
ax3.loglog(h, L2_error_classical_fullstab_tau5eneg3_algoim,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, color="C3", label=r"Non-conservative, $\tau = 0.005$, algoim")
ax3.loglog(h, L2_error_classical_fullstab_tau5eneg3_quad,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, color="C3", label=r"Non-conservative, $\tau = 0.005$, quad")



ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=18)
ax3.set_ylabel(r"$L^2$ error (log)", fontsize=22)
#ax3.set_title(r"Example 1 on $\Gamma(t)$")
#ax3.set_title(r"Example 5")
#fig3.savefig("example1_Gamma_t.pdf", bbox_inches='tight')
plt.show()


fig2, ax2 = plt.subplots()

ax2.loglog(h, 3.8e-0*np.power(h, 8), label=r"$\mathcal{O}(h^{8})$", linestyle="-", color="black")

ax2.loglog(h, area_error_algoim,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"area algoim")
ax2.loglog(h, length_error_algoim,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"length algoim")


ax2.loglog(h, 2.4e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="--", color="black")
ax2.loglog(h, area_error_quad,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"area quad")
ax2.loglog(h, length_error_quad,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"length quad")

ax2.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax2.set_ylabel(r"Area error (log)", fontsize=22)
#ax3.set_title(r"Example 1 on $\Gamma(t)$")
#ax3.set_title(r"Example 5")
#fig3.savefig("example1_Gamma_t.pdf", bbox_inches='tight')
plt.show()
