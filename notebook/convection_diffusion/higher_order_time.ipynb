# %% [markdown]
# ### Dependencies for plotting

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.ticker import FormatStrFormatter




new_rc_paramas = {
    'text.usetex' : True,
    'figure.dpi' : 180,
    'text.latex.preamble' : r'\usepackage{libertine}'r'\usepackage{libertinust1math}',
    'font.family' : 'Linux Libertine',
    'axes.titlesize' : 22,
    'axes.labelsize' : 18,
    'xtick.labelsize' : 16,
    'ytick.labelsize' : 16,
    'xtick.direction' : 'in',
    'ytick.direction' : 'in',
    'xtick.top' : True,
    'ytick.right' : True,
    'legend.fontsize' : 'large',
    'axes.linewidth' : 1.2,
    'savefig.bbox' : 'tight',
    'image.aspect' : 'equal',
}

Oh2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^2)$')
Oh3 = mlines.Line2D([], [], color='black', linestyle="-.", label=r'$\mathcal{O}(h^3)$')
Oh1 = mlines.Line2D([], [], color='black', linestyle="--", label=r'$\mathcal{O}(h)$')

Ohneg2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-2})$')
Ohneg1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-1})$')
Odt = mlines.Line2D([], [], color='black', linestyle="--", label=r'$\mathcal{O}(\Delta t)$')
Odt2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(\Delta t^2)$')
tau1 = mlines.Line2D([], [], color='C4', linestyle="--", label=r'$\tau_0 = \tau_1 = 1$')
tau10neg4 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-4}$')
tau10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-3}$')
tau3x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-3}$')
tau5x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-3}$')
tau3x10neg4 = mlines.Line2D([], [], color='C2', linestyle="-.", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-4}$')
tau5x10neg4 = mlines.Line2D([], [], color='C3', linestyle=":", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-4}$')


space = mlines.Line2D([0], [0], marker='None', color='None', linestyle="None", label=' ')

star = mlines.Line2D([], [], color='C3', marker='*',
                          markersize=9,linestyle="none",
                        markeredgewidth=0.8, markerfacecolor="None", 
                        label='P0 Time, P1 Space')

square = mlines.Line2D([], [], color='C0', marker='s',
                          markersize=9,linestyle="none",
                        markeredgewidth=0.8, markerfacecolor="None", 
                        label='P1 Time, P1 Space')

circle = mlines.Line2D([0], [0], marker='o', color='C2', 
                          markersize=9, markerfacecolor="None", 
                          linestyle="none", markeredgewidth=0.8,
                           label='P2 Time, P2 Space')



triangle = mlines.Line2D([0], [0], marker='^', color='black', 
                          markersize=9, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label='Macro stab. 2')

conservative = mlines.Line2D([0], [0], marker='none', color='black', linestyle=":", label='Conservative')
classical = mlines.Line2D([0], [0], marker='none', color='black', linestyle=(0, (5,7)), label='Non-conservative')




import matplotlib.pyplot as plt

mpl.rcParams.update(new_rc_paramas)

import numpy as np

# %% [markdown]
# ### We study P1Poly vs P2Poly

# %%
# h = 0.1
error_classical_P1poly_h01 = [0.004658284201040151, 0.001795679129286413, 0.001160309516592264]

# h = 0.01
error_classical_P0poly_h001 = [0.008487533687903689, 0.006652848342084824, 0.004484124743172225, 0.002677118241163346, 0.001477394493749876]
error_classical_P1poly_h001 = [0.004595560458952595, 0.001105637662663956, 0.0002796429778542854]
error_classical_P2poly_h001 = [0.00325415242351019, 0.001054254132233221, 0.0004499198235124248]

dt = [0.1, 0.05, 0.025, 0.0125, 0.00625]

# h = 0.1
#error_classical_P1poly_h01 =

# h = 0.01
# error_classical_P0poly_h001 = 
error_classical_P1poly_h001 = [0.0003040909166329155, 6.844797282968641e-05, 2.456410825025958e-05]#[0.000701913816927888, 0.0001783427566349638, 5.106624987562535e-05]#[0.0008560003148982499, 0.000361025551474996, 0.0001714420728856806]
error_classical_P2poly_h001 = [1.922233206857067e-05, 1.133123067549472e-05, 6.436135357741294e-06]#[5.13716516667355e-05, 3.530578096390168e-05, 2.317328016338706e-05]#[0.000573866995462571, 0.000153132697091117, 4.831441516203925e-05]#[0.0007871784875629006, 0.0003516135983427735, 0.0001703142539716034]


fig1, ax1 = plt.subplots()

ax1.loglog(dt, 0.4e-1*np.power(dt, 3), label=r"$\mathcal{O}(\Delta t_n^{3})$", linestyle=":", color="black")
ax1.loglog(dt, 3.0e-1*np.power(dt, 2), label=r"$\mathcal{O}(\Delta t_n^{2})$", linestyle="-", color="black")
ax1.loglog(dt, 1.4e-1*np.power(dt, 1), label=r"$\mathcal{O}(\Delta t_n)$", linestyle="--", color="black")
#ax1.loglog(dt, 1.2e-2*np.power(dt, 1), label=r"$\mathcal{O}(\Delta t_n)$", linestyle="--", color="black")
#ax1.loglog(dt, error_classical_P1poly_h01,  marker='o', markersize=9, linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, P1Poly, $h=0.1$")
ax1.loglog(dt, error_classical_P0poly_h001,  marker='*', markersize=9, linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, P0Poly, $h=0.01$")
ax1.loglog(dt[:-2], error_classical_P1poly_h001,  marker='o', markersize=9, linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, P1Poly, $h=0.01$")
ax1.loglog(dt[:-2], error_classical_P2poly_h001,  marker='s', markersize=9, linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Non-conservative, P2Poly, $h=0.01$")
ax1.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.set_xlabel(r"$\Delta t_n$ (log)", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=18)
ax1.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Gamma(T)}$ (log)", fontsize=22)
ax1.set_title(r"Error")
plt.show()

# The data is always interpolated in P2Poly and P2Quad

# tau1 = 0.1
# T = 0.1
# dT = h/3

error_conservative_P0Poly_P1Quad = [0.00104781455413818, 0.0006510646431074398, 0.0003355448362877795, 0.0001668867885124935, 8.338290525192938e-05]
error_conservative_P1Poly_P1Quad = [0.0007084109577294917, 0.0002854853034878608, 7.815782488454483e-05, 1.562037349950845e-05, 2.665715164075652e-06]
error_conservative_P2Poly_P2Quad = [0.0001494488616177271, 3.881628420637765e-05, 5.486702404706657e-06, 3.405538596876311e-07, 3.529888657103865e-08]
cond_conservative_P2Poly_P2Quad = [9.363431e+06,1.648957e+07,3.287586e+07,4.932920e+07,7.457605e+07]


error_classical_P0Poly_P1Quad = [0.001047800901942141, 0.0006510198366411318, 0.000335540969870371, 0.0001668862956387252, 8.33829055311301e-05]    # P2Quad: [0.001117273711428273, 0.0006180195642465502, 0.0003198347454808016, 0.0001633215518491205, 8.261851885385448e-05]
error_classical_P1Poly_P1Quad = [0.0007085944832910808, 0.0002855949983347337, 7.81638419833073e-05, 1.562191287471175e-05, 2.662768571432827e-06]
error_classical_P2Poly_P2Quad = [0.0001491344710695951, 3.880958904581239e-05, 5.483954283717008e-06, 3.388107376750641e-07, 2.617694498661298e-08]

h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig2, ax2 = plt.subplots()

ax2.loglog(h, 0.3e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="--", color="black")
ax2.loglog(h, 2.0e-1*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax2.loglog(h, 2.4e-1*np.power(h, 3), label=r"$\mathcal{O}(h^{3})$", linestyle="-.", color="black")
#ax2.loglog(h, 2.4e-1*np.power(h, 4), label=r"$\mathcal{O}(h^{4})$", linestyle=":", color="black")
ax2.loglog(h, error_conservative_P0Poly_P1Quad,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, P0 Time, P1 Space")
ax2.loglog(h, error_conservative_P1Poly_P1Quad,  marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, P1 Time, P1 Space")
ax2.loglog(h, error_conservative_P2Poly_P2Quad,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, P2 Time, P2 Space")
#ax2.loglog(h[:-1],[0.01117926330921224, 0.001345154740405157, 0.0001668449371540097, 2.083700699994401e-05])
ax2.plot([],[],linestyle="",label=" ")
ax2.loglog(h, error_classical_P0Poly_P1Quad,  marker='*', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Non-conservative, P0 Time, P1 Space")
ax2.loglog(h, error_classical_P1Poly_P1Quad,  marker='s', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, P1 Time, P1 Space")
ax2.loglog(h, error_classical_P2Poly_P2Quad,  marker='o', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, P2 Time, P2 Space")
#ax2.legend(handles=[Oh1, Oh2, Oh3, space, star, square, circle, space, conservative, classical], prop={'size': 13},loc='best', frameon=False)

ax2.legend(handles=[Oh1, Oh2, Oh3, space, star, square, circle, space, conservative, classical], prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)

ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax2.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$ (log)", fontsize=22)
#ax2.set_title(r"Example 1 in $\Omega_2(t)$")
plt.show()
fig2.savefig("higher_order.pdf", bbox_inches='tight')

# %% [markdown]
# ### Example 1 on $\Gamma(t)$

# %%
# The data is always interpolated in P2Poly and P2Quad

# tau1 = tau2 = 0.1
# T = 0.1
# dT = h/3

error_conservative_P0Poly_P1Quad = [0.004176178929463561, 0.001969006558195548, 0.0009062976631668737, 0.0004332599747212314, 0.0002038205063467534]
cond_conservative_P0Poly_P1Quad = [2.234878e+02,6.053089e+02,3.139440e+03,7.762751e+03,2.114802e+04]

error_conservative_P1Poly_P1Quad = [0.0005952804391091721, 0.0001702985086357971, 3.522227103941794e-05, 9.460366242351922e-06, 1.619097169606596e-05]
cond_conservative_P1Poly_P1Quad = [4.111185e+03,1.084541e+04,5.365662e+04,1.347506e+05,3.776788e+05]

error_conservative_P2Poly_P2Quad = [0.0002381776183611831, 0.0001096848558282958, 1.406534260104983e-05, 2.682808948024448e-06, 9.380373064602307e-06]  # average: [0.0003534173111265258, 6.384871340283936e-05, 2.214028573156773e-05, 1.691878138917605e-05, 8.548987876389342e-06]
cond_conservative_P2Poly_P2Quad = [7.165492e+06,2.152341e+07,1.091562e+08,4.280145e+08,1.425946e+09]

error_classical_P0Poly_P1Quad = [0.004170273054092658, 0.001972792672969865, 0.0009031603077419193, 0.0004329737242728962, 0.0002034234781726484]
cond_classical_P0Poly_P1Quad = [2.234927e+02,6.054866e+02,3.139405e+03,7.762749e+03,2.114988e+04]

error_classical_P1Poly_P1Quad = [0.0005720806164883872, 0.0001568176375544405, 3.791719742680578e-05, 9.387639125681805e-06, 2.347443894450253e-06]
cond_classical_P1Poly_P1Quad = [4.111249e+03,1.084541e+04,5.365664e+04,1.347505e+05,3.777233e+05]

error_classical_P2Poly_P2Quad = [0.0002301713445165581, 4.433703523871045e-05, 6.002940226630738e-06, 9.771897658747917e-07, 1.171587804038156e-07]
cond_classical_P2Poly_P2Quad = [7.166370e+06,2.152348e+07,1.091218e+08,4.280335e+08,1.426047e+09]


# tau1 = 10

#error_conservative_P0Poly_P1Quad = [0.005355325947484372, 0.003103630927217521, 0.001554125246245805, 0.0007050936216804043, 0.0003250875420292031]
# cond_conservative_P0Poly_P1Quad = 

#error_conservative_P1Poly_P1Quad = [0.002317630620356059, 0.001885595451994211, 0.0008644719795026677, 0.0002797919261173575, 8.409629461003636e-05]
# cond_conservative_P1Poly_P1Quad = 

#error_conservative_P2Poly_P2Quad = [0.0002004284847939963, 4.396541947980199e-05, 7.97706388726065e-06, 2.358458892897653e-06, 8.494707469574812e-07]   #Average: [0.0003280191062868651, 3.599485844322708e-05, 8.040577903705898e-06, 2.799098719802704e-06, 9.954218423136193e-07]
# cond_conservative_P2Poly_P2Quad = 

# error_classical_P0Poly_P1Quad =
# cond_classical_P0Poly_P1Quad = 

# error_classical_P1Poly_P1Quad =
# cond_classical_P1Poly_P1Quad = 

# error_classical_P2Poly_P2Quad =
# cond_classical_P2Poly_P2Quad = 


# the conservative scheme converges nicely for P2 x P2 if one uses dt = c h^2.

h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig2, ax2 = plt.subplots()

ax2.loglog(h, .7e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="--", color="black")
ax2.loglog(h, 1.e-1*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax2.loglog(h, 8.e-1*np.power(h, 3), label=r"$\mathcal{O}(h^{3})$", linestyle="-.", color="black")
ax2.loglog(h, error_conservative_P0Poly_P1Quad,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, P0 Time, P1 Space")
ax2.loglog(h, error_conservative_P1Poly_P1Quad,  marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, P1 Time, P1 Space")
ax2.loglog(h, error_conservative_P2Poly_P2Quad,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, P2 Time, P2 Space")
ax2.plot([],[],linestyle="",label=" ")
ax2.loglog(h, error_classical_P0Poly_P1Quad,  marker='*', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Non-conservative, P0 Time, P1 Space")
ax2.loglog(h, error_classical_P1Poly_P1Quad,  marker='s', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, P1 Time, P1 Space")
ax2.loglog(h, error_classical_P2Poly_P2Quad,  marker='o', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, P2 Time, P2 Space")
#ax2.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax2.legend(handles=[Oh1, Oh2, Oh3, space, star, square, circle, space, conservative, classical], prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)

ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax2.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Gamma(T)}$ (log)", fontsize=22)
ax2.set_title(r"Example 1 on $\Gamma(t)$")
plt.show()

fig3, ax3 = plt.subplots()

#ax3.loglog(h, .7e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="--", color="black")
ax3.loglog(h, 1.e4*np.power(h, -2), label=r"$\mathcal{O}(h^{-2})$", linestyle="-", color="black")
#ax3.loglog(h, 8.e-1*np.power(h, 3), label=r"$\mathcal{O}(h^{3})$", linestyle="-.", color="black")
ax3.loglog(h, cond_conservative_P0Poly_P1Quad,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, P0 Time, P1 Space")
ax3.loglog(h, cond_conservative_P1Poly_P1Quad,  marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, P1 Time, P1 Space")
ax3.loglog(h, cond_conservative_P2Poly_P2Quad,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, P2 Time, P2 Space")
ax3.plot([],[],linestyle="",label=" ")
ax3.loglog(h, cond_classical_P0Poly_P1Quad,  marker='*', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Non-conservative, P0 Time, P1 Space")
ax3.loglog(h, cond_classical_P1Poly_P1Quad,  marker='s', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, P1 Time, P1 Space")
ax3.loglog(h, cond_classical_P2Poly_P2Quad,  marker='o', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, P2 Time, P2 Space")
#ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.legend(handles=[Ohneg2, space, star, square, circle, space, conservative, classical], prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)

ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=18)
ax3.set_ylabel(r"$\kappa(A)(T)$ (log)", fontsize=22)
ax3.set_title(r"Condition number")
plt.show()

# %% [markdown]
# ### P0 Time Conservative

# %%
# The data is always interpolated in P2Poly and P2Quad

# tau1 = tau2 = 0.1
# T = 0.1
# dT = h/3

error_conservative_P0Poly_P1Quad_tau01 = [0.004176178929463561, 0.001969006558195548, 0.0009062976631668737, 0.0004332599747212314, 0.0002038205063467534]
cond_conservative_P0Poly_P1Quad = [2.234878e+02,6.053089e+02,3.139440e+03,7.762751e+03,2.114802e+04]

error_classical_P0Poly_P1Quad_tau01 = [0.00422633641904183, 0.001975819519093977, 0.0008994291433150287, 0.0004318472650091431, 0.0002031756865608157]

# tau1 = = tau2 = 0.01
# T = 0.1
# dT = h/3
error_conservative_P0Poly_P1Quad_tau001 = [0.003721708302368898, 0.001693155176329597, 0.0008340388562398379, 0.0004017051778640355, 0.0001903722460464327]
error_classical_P0Poly_P1Quad_tau001 = [0.003648779750766435, 0.00169574532396593, 0.0008166180544123443, 0.0004013047017354872, 0.0001911204147350228]

# tau1 = = tau2 = 0.001
# T = 0.1
# dT = h/3
error_conservative_P0Poly_P1Quad_tau0001 = [0.003687619526153093, 0.002260372207939859, 0.0008412148150100014, 0.0003942791970907422, 0.0003134319125213329]
error_classical_P0Poly_P1Quad_tau0001 = [0.003490938702240943, 0.001652462388163804, 0.0008031223234093128, 0.0003927907034196029, 0.0001870614659631307]

h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig2, ax2 = plt.subplots()

ax2.loglog(h, .7e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="--", color="black")
#ax2.loglog(h, 1.e-1*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
#ax2.loglog(h, 8.e-1*np.power(h, 3), label=r"$\mathcal{O}(h^{3})$", linestyle="-.", color="black")
ax2.loglog(h, error_conservative_P0Poly_P1Quad_tau01,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative,  $\tau = 0.1$")
ax2.loglog(h, error_conservative_P0Poly_P1Quad_tau001,  marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative,  $\tau = 0.01$")
ax2.loglog(h, error_conservative_P0Poly_P1Quad_tau0001,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, $\tau = 0.001$")
ax2.plot([],[],linestyle="",label=" ")
ax2.loglog(h, error_classical_P0Poly_P1Quad_tau01,  marker='*', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Non-conservative, $\tau = 0.1$")
ax2.loglog(h, error_classical_P0Poly_P1Quad_tau001,  marker='s', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative,  $\tau = 0.01$")
ax2.loglog(h, error_classical_P0Poly_P1Quad_tau0001,  marker='o', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, $\tau = 0.001$")
ax2.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
#ax2.legend(handles=[Oh1, Oh2, Oh3, space, star, square, circle, space, conservative, classical], prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)

ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax2.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Gamma(T)}$ (log)", fontsize=22)
ax2.set_title(r"Example 1 on $\Gamma(t)$, P0 Time, P1 Space")
plt.show()
