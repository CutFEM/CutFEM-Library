# %% [markdown]
# ### Dependencies

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.ticker import FormatStrFormatter
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

new_rc_paramas = {
    'text.usetex' : True,
    'figure.dpi' : 180,
    'text.latex.preamble' : r'\usepackage{libertine}'r'\usepackage{libertinust1math}',
    'font.family' : 'Linux Libertine',
    'axes.titlesize' : 22,
    'axes.labelsize' : 18,
    'xtick.labelsize' : 16,
    'ytick.labelsize' : 16,
    'xtick.direction' : 'in',
    'ytick.direction' : 'in',
    'xtick.top' : True,
    'ytick.right' : True,
    'legend.fontsize' : 'large',
    'axes.linewidth' : 1.2,
    'savefig.bbox' : 'tight',
    'image.aspect' : 'equal',
}

Oh2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^2)$')
Oh3 = mlines.Line2D([], [], color='black', linestyle="-.", label=r'$\mathcal{O}(h^3)$')
Oh1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h)$')
Ohneg2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-2})$')
Ohneg1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-1})$')
Odt = mlines.Line2D([], [], color='black', linestyle="--", label=r'$\mathcal{O}(\Delta t)$')
Odt2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(\Delta t^2)$')
tau1 = mlines.Line2D([], [], color='C4', linestyle="--", label=r'$\tau_0 = \tau_1 = 1$')
tau10neg4 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-4}$')
tau10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-3}$')
tau3x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-3}$')
tau5x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-3}$')
tau3x10neg4 = mlines.Line2D([], [], color='C2', linestyle="-.", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-4}$')
tau5x10neg4 = mlines.Line2D([], [], color='C3', linestyle=":", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-4}$')

conservative = mlines.Line2D([0], [0], marker='None', color='black', linestyle=":", label='Conservative')
classical = mlines.Line2D([0], [0], marker='None', color='black', linestyle=(0, (5,7)), label='Non-conservative')


space = mlines.Line2D([0], [0], marker='None', color='None', linestyle="None", label=' ')

circle = mlines.Line2D([0], [0], marker='o', color='black', 
                          markersize=9, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label='Full stabilization.')
                          
star = mlines.Line2D([], [], color='black', marker='*',
                          markersize=9,linestyle="None",
                        markeredgewidth=0.8, markerfacecolor="None", 
                        label='Macro stabilization.')

triangle = mlines.Line2D([0], [0], marker='^', color='black', 
                          markersize=9, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label='Macro stab. 2')


import matplotlib.pyplot as plt

mpl.rcParams.update(new_rc_paramas)

import numpy as np

def convergence_rate(errors, mesh_sizes):
    if len(errors) < 2 or len(mesh_sizes) < 2 or len(errors) != len(mesh_sizes):
        raise ValueError("At least two errors and mesh sizes are required.")

    # Take logarithm of errors and mesh sizes
    log_errors = np.log(errors)
    log_mesh_sizes = np.log(mesh_sizes)

    # Compute differences between consecutive elements
    delta_errors = np.diff(log_errors)
    delta_mesh_sizes = np.diff(log_mesh_sizes)

    # Compute convergence rate
    convergence_rates = delta_errors / delta_mesh_sizes

    return convergence_rates
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### $L^2$-Error vs $h$, $\Delta t_n \propto h$

# %%
# paper.cpp

# N = 7, T = 0.5, tau = 0.05
#error_classical_P1P1_fullstab =  
error_conservative_P1P1_fullstab = [0.9103922923112666, 0.6831133501255253, 0.1790694186989171, 0.05580567115696776, 0.01339335764314571, 0.003331764718875724, 0.0008076682052737521, 0.0001998769950510804]
error_conservative_P1P1_fullstab_T = [0.4582848214356584, 0.2856321446808385, 0.08177771419499358, 0.02530536992930246, 0.006233718785223333, 0.001521292228672025, 0.0003677946941598954, 9.060962291039232e-05]

#error_classical_P1P1_macro = 
#error_conservative_P1P1_macro =

error_conservative_P2P2_fullstab = [0.3496442462945067, 0.2770147578588354, 0.04908378344162034, 0.006413251167785013, 0.0004576717349585284, 5.429622963486653e-05, 6.579099193449326e-06, 8.169415114955786e-07]
error_conservative_P2P2_fullstab_T = [0.1695454054592171, 0.1353596329033109, 0.02672786319383531, 0.002675553338593597, 0.0002373537442938859, 2.735960737724968e-05, 3.287539339430602e-06, 4.076673719933756e-07]

# N = 9 in space and time, tau = 0.05
#error_conservative_P3P3_fullstab = ### running for 8 iterations on eight
#error_conservative_P3P3_fullstab_T = ### same
error_conservative_P3P3_fullstab = [0.3141849015999858, 0.2254248413911485, 0.004043646246458325, 0.0003154892853603781, 1.420536615053008e-05, 8.8924e-07, 4.69033e-08]
error_conservative_P3P3_fullstab_T = [0.05630564443765843, 0.0445709428814355, 0.001431549500903281, 9.07845289400755e-05, 4.377541191166081e-06, np.sqrt(2.14758e-13), np.sqrt(6.84681e-16)]

h = [0.9, 0.45, 0.225, 0.1125, 0.05625, 0.028125, 0.0140625, 0.00703125]
dT = [0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625, 0.001953125]
nx = [4, 7, 14, 27, 54, 107, 214, 427]
ny = [4, 7, 14, 27, 54, 107, 214, 427]

ih = np.arange(0,8)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
ax1.semilogy(ih, 6.5*np.power(h, 2), linestyle="--", color="black", label=r"$\mathcal{O}(h^{k+1})$")   
ax1.semilogy(ih, 1.5*np.power(h, 3), linestyle="--", color="black")   
ax1.semilogy(ih, 1.5*np.power(h, 4), linestyle="--", color="black")   


# ax1.loglog(h, 4.*np.power(h, 3), linestyle="--", color="black")   
# ax1.loglog(h, 4*np.power(h, 4),label=r"Order $3, 4$", linestyle="--", color="black")   

ax1.semilogy(ih, error_conservative_P1P1_fullstab, label= r"$k=m=1$", marker='o', markersize=9, linestyle="-", color="C3")
ax1.semilogy(ih, error_conservative_P2P2_fullstab, label= r"$k=m=2$", marker='s', markersize=9, linestyle="-", color="C0")
ax1.semilogy(ih[:7], error_conservative_P3P3_fullstab, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="C2")

#ax1.loglog(h, error_classical_P1P1, label= r"Non-conservative", marker='o', markersize=9, linestyle=(0, (5,7)), color="C3")

#ax1.set_ylim(1e-4, 2)
ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"Refinements in space and time")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u(T)-u_h(T)\|_{L^2(\Omega(T))}$ (log)")
ax1.set_title(r"$\|e_h(T)\|_{L^2(\Omega(T))}$ vs $h$")
ax1.legend()
ax1.grid()

ax2.semilogy(ih, 6.5*np.power(h, 2), linestyle="--", color="black", label=r"$\mathcal{O}(h^{k+1})$")   
ax2.semilogy(ih, 1.5*np.power(h, 3), linestyle="--", color="black")  
ax2.semilogy(ih, 1.5*np.power(h, 4), linestyle="--", color="black")   

# ax2.loglog(h, 4.*np.power(h, 3), linestyle="--", color="black")   
# ax2.loglog(h, 4*np.power(h, 4),label=r"Order $3, 4$", linestyle="--", color="black")   

ax2.semilogy(ih, error_conservative_P1P1_fullstab_T, label= r"$k=m=1$", marker='o', markersize=9, linestyle="-", color="C3")
ax2.semilogy(ih, error_conservative_P2P2_fullstab_T, label= r"$k=m=2$", marker='s', markersize=9, linestyle="-", color="C0")
ax2.semilogy(ih[:7], error_conservative_P3P3_fullstab_T, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="C2")

ax2.set_xticks([0, 2, 4, 6])
ax2.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax2.set_xlabel(r"Refinements in space and time")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"\Big($\int_0^T\|u(t)-u_h(t)\|^2_{L^2(\Omega(t))}dt\Big)^{\frac{1}{2}}$ (log)")
ax2.set_title(r"$\|e_h\|_{L^2(L^2(\Omega(t)), 0, T)}$ vs $h$")
ax2.legend()
ax2.grid()
fig.tight_layout()
#fig.savefig("kite_error.pdf")
plt.show()


fig, ax3 = plt.subplots(1, 1, figsize=(6, 5))
ax3.loglog(h, 6.5*np.power(h, 2), linestyle="--", color="black", label=r"$\mathcal{O}(h^{k+1})$")   
ax3.loglog(h, 1.5*np.power(h, 3), linestyle="--", color="black")   
ax3.loglog(h, 1.5*np.power(h, 4), linestyle="--", color="black")   


# ax1.loglog(h, 4.*np.power(h, 3), linestyle="--", color="black")   
# ax1.loglog(h, 4*np.power(h, 4),label=r"Order $3, 4$", linestyle="--", color="black")   

ax3.loglog(h, error_conservative_P1P1_fullstab, label= r"$k=m=1$", marker='o', markersize=9, linestyle="-", color="C3")
ax3.loglog(h, error_conservative_P2P2_fullstab, label= r"$k=m=2$", marker='s', markersize=9, linestyle="-", color="C0")
ax3.loglog(h[:7], error_conservative_P3P3_fullstab, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="C2")

#ax1.loglog(h, error_classical_P1P1, label= r"Non-conservative", marker='o', markersize=9, linestyle=(0, (5,7)), color="C3")

#ax1.set_ylim(1e-4, 2)
ax3.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax3.set_xlabel(r"$h$")
ax3.tick_params(axis='both', which='major')
ax3.set_ylabel(r"$\|u(T)-u_h(T)\|_{L^2(\Omega(T))}$ (log)")
ax3.set_title(r"$L^2$-error vs $h$")
ax3.legend()
ax3.grid()

fig.tight_layout()
fig.savefig("kite_error.pdf")
plt.show()

# %% [markdown]
# ### Superconvergence
# Conservative method

# %%
# P1Poly x P1
# N = 5 space and time, tau = 5e-2, T = 0.5


# L2 vs dt

# # h = 0.4
# error_P1P1_h04 = [0.3483218326253995, 0.3686101769727116, 0.369213593321408, 0.3532324938464482, 0.3308684902586849, 0.3132582741680247, 0.3101811497313781]
# error_P1P1_h04_T = [0.2374386242574263, 0.2090173287020117, 0.1858441836149657, 0.1800175590536413, 0.1748278161272143, 0.1727430062674719, 0.1720723192582971]


# # h = 0.2
# error_P1P1_h02 = [0.1642983263541072, 0.1176390116288283, 0.1275752372786413, 0.1273065558710802, 0.1274129228151194, 0.1273576129666262, 0.1273540011498294]
# error_P1P1_h02_T = [0.1319852806913871, 0.0764992389987794, 0.06695452219612803, 0.06561676586670828, 0.06533597546713354, 0.06518335265660351, 0.06515475152332749]

# # h = 0.1  
# error_P1P1_h01 = [0.1384042087316602, 0.03729070321750615, 0.03943033120859772, 0.04101296913458928, 0.04108428027948224, 0.04104089958178153, 0.04092976053898319]
# error_P1P1_h01_T = [0.1162262855881213, 0.04189444623364152, 0.02245413452752096, 0.01966517010529952, 0.01922557712340756, 0.01912477477525088, 0.01908028015453076]

# # h = 0.05
# error_P1P1_h005 = [0.1423322696432013, 0.02934058434690687, 0.008971088361912469, 0.01023219597625425, 0.01048852091669769, 0.01050216107521076, 0.01047027459226796]
# error_P1P1_h005_T = [0.1145615786841949, 0.03632141994145915, 0.01148438407580198, 0.005784819290665178, 0.004954031675090805, 0.004853515543396999, 0.00482448217558666]

# # h = 0.025
# # error_P1P1_h0025 = 
# # error_P1P1_h0025_T = 



### Redoing fig 13 (left) in Lehrenfeld

# k = 1, 2
# m = 2k + 1


# P1Poly x P3, h = 0.025, Nspace = 8, Ntime = 5 
error_P1Poly = [0.0331589713159257, 0.005388076858008533, 0.0007993512830396838, 0.0001123917094427442, 1.543685409022662e-05, 2.184247365215758e-06]
error_P1Poly_T = [0.03589802252522702, 0.01008813903000439, 0.002697192264315159, 0.0006998836379517722, 0.0001784750285205032, 4.507988334633133e-05]

print("Convergence rate, last step, T-error:")
print(np.log(error_P1Poly[-2]/error_P1Poly[-1])/np.log(2))
print("\n")
print("Convergence rate, last step, int_0^T-error:")
print(np.log(error_P1Poly_T[-2]/error_P1Poly_T[-1])/np.log(2))


#error_P2Poly = 
#error_P2Poly_T = 


dt = [0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125]
h = [0.025, 0.025, 0.025, 0.025, 0.025, 0.025]

it = np.arange(0,6)

# P1 x P1
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.semilogy(it, 1.5*np.power(dt, 2), linestyle="--", color="black")   
ax1.semilogy(it, 1*np.power(dt, 3),label=r"Order $2, 3$", linestyle="--", color="black")   

ax1.semilogy(it, error_P1Poly, label= r"$k = 1, m=3$", marker='o', markersize=9, linestyle="-", color="C3")
#ax1.loglog(dt, error_P2Poly, label= r"$h=0.1$", marker='s', markersize=9, linestyle="-", color="C3")

ax1.set_ylim(4e-9, 2)
ax1.set_yticks([1e-9, 1e-7, 1e-5, 1e-3, 1e-1])
ax1.set_xlabel(r"Refinements in time")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u(T)-u_h(T)\|_{L^2(\Omega(T))}$ (log)")
ax1.set_title(r"$L^2$-Error vs $\Delta t$")
ax1.legend()
ax1.grid()


ax2.semilogy(it, 1.5*np.power(dt, 2), linestyle="--", color="black")   
ax2.semilogy(it, 1*np.power(dt, 3),label=r"Order $2, 3$", linestyle="--", color="black")   

ax2.semilogy(it, error_P1Poly_T, label= r"$k = 1, m=3$", marker='o', markersize=9, linestyle="-", color="C3")
#ax1.loglog(dt, error_P2Poly, label= r"$h=0.1$", marker='s', markersize=9, linestyle="-", color="C3")

ax2.set_ylim(4e-9, 2)
ax2.set_yticks([1e-9, 1e-7, 1e-5, 1e-3, 1e-1])
ax2.set_xlabel(r"Refinements in time")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"$\|u-u_h\|_{L^2(L^2(\Omega(t)), 0, T)}$ (log)")
ax2.set_title(r"Time-integrated $L^2$-Error vs $\Delta t$")
ax2.legend()
ax2.grid()
#fig.savefig("myfig13.png")
plt.tight_layout()
plt.show()



### figure 14
# refining in both space and time, but ks=kt+1 for kt=1,2.
# tau = 0.05, T=0.5

# Case kt = 1: Nspace = 6, Ntime = 5
error_conservative_P1P2_fullstab = [0.3396851453378358, 0.2756543057662235, 0.0496269183269178, 0.006555460862581108, 0.0004546034620368424, 5.43146853907725e-05, 6.586216361909732e-06]
error_conservative_P1P2_fullstab_T = [0.1737464056239169, 0.1361041939243647, 0.02688518512051311, 0.002734168794006753, 0.0002978288682752793, 5.274583756629536e-05, 1.179632128309616e-05] 

# Case kt = 2: Nspace = 8, Ntime = 7
error_conservative_P2P3_fullstab = [0.3123795561369966, 0.2252312112535469, 0.004044974654120995, 0.0003153764750238567, 1.41904643751841e-05, 9.391911744873021e-07, 5.101954474656647e-08]
error_conservative_P2P3_fullstab_T = [0.1596758510198282, 0.09445067656010181, 0.002564018934040176, 0.0001551391577753607, 8.831602729348992e-06, 4.940167015221187e-07, 3.723702249737132e-08]

error_classical_P2P3_fullstab = [0.3123800273945472, 0.225231248265758, 0.004044976637693784, 0.0003153794557280313, 1.419045379683545e-05, 9.391894839819484e-07]
error_classical_P2P3_fullstab_T = [0.1596778650280721, 0.09445061610482815, 0.002564027142674637, 0.0001551617565278939, 8.831208268447421e-06, 4.919578118752475e-07]


it = np.arange(0,7)

h = [0.9, 0.45, 0.225, 0.1125, 0.05625, 0.028125, 0.0140625]
dt = [0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625]
n = [4, 7, 14, 27, 54, 107, 214]


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.semilogy(it, 2.5e1*np.power(dt, 3), linestyle="--", color="black",label=r"Order $3$, $4$")  
ax1.semilogy(it, 2.5e1*np.power(dt, 4), linestyle="--", color="black")  
ax1.semilogy(it, error_conservative_P1P2_fullstab, label= r"$k=1$, $m=2$", marker='o', markersize=9, linestyle="-", color="C3")
ax1.semilogy(it, error_conservative_P2P3_fullstab, label= r"$k=2$, $m=3$", marker='s', markersize=9, linestyle="-", color="C0")
ax1.semilogy(it[:-1], error_classical_P2P3_fullstab, label= r"$k=2$, $m=3$ classical", marker='p', markersize=9, linestyle="--", color="C2")

ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"Refinements in space and time")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u(T)-u_h(T)\|_{L^2(\Omega(T))}$ (log)")
ax1.set_title(r"$L^2$-Error")
ax1.legend()
ax1.grid()


ax2.semilogy(it, 2.5e1*np.power(dt, 3), linestyle="--", color="black",label=r"Order $3$, $4$")  
ax2.semilogy(it, 2.5e1*np.power(dt, 4), linestyle="--", color="black")  
ax2.semilogy(it, error_conservative_P1P2_fullstab_T, label= r"$k=1$, $m=2$", marker='o', markersize=9, linestyle="-", color="C3")
ax2.semilogy(it, error_conservative_P2P3_fullstab_T, label= r"$k=2$, $m=3$", marker='s', markersize=9, linestyle="-", color="C0")
ax2.semilogy(it[:-1], error_classical_P2P3_fullstab_T, label= r"$k=2$, $m=3$ classical", marker='p', markersize=9, linestyle="--", color="C2")

ax2.set_xticks([0, 2, 4, 6])
ax2.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax2.set_xlabel(r"Refinements in space and time")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"\Big($\int_0^T\|u(t)-u_h(t)\|^2_{L^2(\Omega(t))}dt\Big)^{\frac{1}{2}}$ (log)")
ax2.set_title(r"Time-integrated $L^2$-Error")
ax2.legend()
ax2.grid()
fig.tight_layout()
fig.savefig("myfig14.png")
plt.show()
# Out:
# Convergence rate, last step, T-error:
# 2.8211706173190807
#
#
# Convergence rate, last step, int_0^T-error:
# 1.9851665451675018

# %% [markdown]
# ### Conservation error

# %%
# h = 0.1 and T = 1.5
#error_conservative_P1P1_fullstab = [9.02056e-16, 9.71445e-16, 1.11022e-15, 8.32667e-16, 1.27676e-15, 1.11022e-16, 1.77636e-15, 2.22045e-16, 4.44089e-16, 1.11022e-16, 9.99201e-16, 2.66454e-15, 5.10703e-15, 9.99201e-15, 6.88338e-15, 9.32587e-15, 5.55112e-15, 1.57652e-14, 1.19904e-14, 1.62093e-14, 1.22125e-14, 2.30926e-14, 2.53131e-14, 2.02061e-14, 2.55351e-14, 2.42029e-14, 2.75335e-14, 2.68674e-14, 3.08642e-14, 2.9976e-14, 3.26406e-14, 3.19744e-14, 3.14193e-14, 3.44169e-14, 3.53606e-14, 3.53606e-14, 3.68039e-14, 3.76088e-14, 3.79557e-14, 3.88782e-14, 3.75117e-14, 3.76088e-14, 3.84137e-14, 3.475e-14, 3.76921e-14, 3.85247e-14, 3.57492e-14, 3.87468e-14, 3.54161e-14, 3.78586e-14, 3.27516e-14, 3.37508e-14, 3.4639e-14, 3.13083e-14, 3.04201e-14, 2.66454e-14, 3.13083e-14, 2.81997e-14, 2.57572e-14, 2.39808e-14]  #[6.07153e-16, 9.02056e-16, 4.71845e-16, 8.60423e-16, 3.55271e-15, 3.35842e-15, 1.38778e-16, 4.80171e-15, 5.19029e-15, 2.498e-15, 6.55032e-15, 2.88658e-15, 5.4956e-15, 5.93969e-15, 9.99201e-15, 9.60343e-15, 1.04361e-14, 3.16414e-15, 3.77476e-15, 1.20459e-14, 9.76996e-15, 6.66134e-15, 1.59872e-14, 7.88258e-15, 1.46549e-14, 8.32667e-15, 1.90958e-14, 1.52101e-14, 8.54872e-15, 2.03171e-14, 2.38698e-14, 1.9984e-14, 4.22995e-14, 1.58762e-14, 2.09832e-14, 2.88658e-14, 2.43139e-14, 2.78666e-14, 2.39808e-14, 2.9865e-14, 4.42979e-14, 3.71925e-14, 3.43059e-14, 3.55271e-14, 4.4853e-
ig, ax = plt.subplots(1, 1, figsize=(6, 5))

ax.semilogy(time, error_conservative_P1P1_fullstab, label= r"Conservative method", marker='o', markersize=3, linestyle="-", color="C3")
ax.semilogy(time, error_classical_P1P1_fullstab, label= r"Non-conservative method", marker='s', markersize=3, linestyle="-", color="C0")

#ax.set_xticks([0, 2, 4, 6])
#ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax.set_xlabel(r"$t$")
ax.tick_params(axis='both', which='major')
ax.set_ylabel(r"$e_c(t)$")
ax.set_title(r"Conservation error vs time")
ax.legend(fontsize=18)
fig.tight_layout()
fig.savefig("kite_conservation_error.pdf")
plt.show()



### e_c(T) vs h, T = 0.5, h0 = 0.9, dT0 = 0.25, N=3 time, 5 space, tau=0.1
error_conservative_P1P1_fullstab = [1.554312234475219e-15, 1.77635683940025e-15, 2.886579864025407e-15, 1.110223024625157e-14, 2.664535259100376e-15, 2.930988785010413e-14]
error_classical_P1P1_fullstab = [1.683007627084621e-05, 2.196773348650538e-05, 3.235100988652206e-06, 2.735985729085399e-07, 1.252848711441601e-07, 2.216867245330434e-08]
h = [0.9, 0.45, 0.225, 0.1125, 0.05625, 0.028125]

fig, ax = plt.subplots(1, 1, figsize=(6, 5))

ax.loglog(h, error_conservative_P1P1_fullstab, label= r"Conservative method", marker='o', markersize=3, linestyle="-", color="C3")
ax.loglog(h, error_classical_P1P1_fullstab, label= r"Non-conservative method", marker='s', markersize=3, linestyle="-", color="C0")

#ax.set_xticks([0, 2, 4, 6])
#ax.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax.set_xlabel(r"$h$")
ax.tick_params(axis='both', which='major')
ax.set_ylabel(r"$e_c(T)$")
ax.set_title(r"Conservation error in $T$ vs mesh size")
ax.legend(fontsize=18)
fig.tight_layout()
fig.savefig("kite_conservation_error_vs_h.pdf")
plt.show()

# %% [markdown]
# ### Error vs t

# %%
# T = 0.5, h = 0.225, dT = 0.0625, tau and N varies

# P3 x P3

# N = 7 in time, 9 in space, tau = 0.1
error_conservative_P3P3_fullstab_lowN_lowtau = [4.95704e-05, 9.62147e-05, 0.000137868, 0.000194474, 0.000266155, 0.000273986, 0.000311125, 0.000373032]
time_average_lowN_lowtau = 0.0001503272824447095
# N = 7 in time, 9 in space, tau = 50
error_conservative_P3P3_fullstab_lowN_hightau =  [0.00039106, 0.000752519, 0.00114824, 0.00180648, 0.00280961, 0.00259649, 0.00308465, 0.00400818]
#time_average_lowN_hightau = 
# N = 20 in time, 9 in space, tau = 0.1
error_conservative_P3P3_fullstab_highN_lowtau = [4.9487e-05, 9.62126e-05, 0.000137868, 0.000194082, 0.000266174, 0.000273986, 0.000310253, 0.000374237]
time_average_highN_lowtau = 0.0001502390346740783
# # N = 20 in time, tau = 50
error_conservative_P3P3_fullstab_highN_hightau = [0.000391059, 0.000752519, 0.00114824, 0.00180648, 0.00280961, 0.00259649, 0.00308466, 0.0040082]
time_average_highN_hightau = 0.00147036059692287

# # N = 7 in time, tau = 0.1
error_classical_P3P3_fullstab_lowN_lowtau = [4.94887e-05, 9.62126e-05, 0.000137868, 0.000194086, 0.000266174, 0.000273986, 0.000310292, 0.000374218, ]
time_average_classical = 0.0001502409911876364

t = np.linspace(0, 0.5, 8)

# Conservative scheme
#fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle(r"Changing $\tau$", fontsize=26)

ax1.plot(t, error_conservative_P3P3_fullstab_lowN_lowtau, marker='s', markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'Low $N$, low $\tau$')
ax1.plot(t, error_conservative_P3P3_fullstab_lowN_hightau, marker='s', linestyle=":", color='C3', label=r'Low $N$, high $\tau$')
ax2.plot(t, error_conservative_P3P3_fullstab_highN_lowtau, marker='o', markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C0', label=r'High $N$, low $\tau$')
ax2.plot(t, error_conservative_P3P3_fullstab_highN_hightau, marker='o', linestyle=":", color='C0', label=r'High $N$, high $\tau$')

#ax1.plot(t, time_average_lowN_lowtau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o',markersize=4, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3')
#ax1.plot(t, time_average_lowN_hightau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o', markersize=4, linestyle=":", color='C3')
#ax2.plot(t, time_average_highN_lowtau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o',markersize=4, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C0')
#ax2.plot(t, time_average_highN_hightau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o', markersize=4, linestyle=":", color='C0')

#ax2.plot(t, error_classical_P3P3_fullstab_lowN_lowtau, marker='^', color="C2", linestyle="--")

ax1.set_xlabel(r"$t$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# ax1.set_title(r"C")
ax1.set_ylim(-3e-4, 5e-3)
ax2.set_ylim(-3e-4, 5e-3)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()

fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")

plt.show()



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle(r"Changing $N$", fontsize=26)

ax1.plot(t, error_conservative_P3P3_fullstab_lowN_lowtau, marker='s', markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'Low $N$, low $\tau$')
ax1.plot(t, error_conservative_P3P3_fullstab_highN_lowtau, marker='o', markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C0', label=r'High $N$, low $\tau$')

ax2.plot(t, error_conservative_P3P3_fullstab_lowN_hightau, marker='s', linestyle=":", color='C3', label=r'Low $N$, high $\tau$')
ax2.plot(t, error_conservative_P3P3_fullstab_highN_hightau, marker='o', linestyle=":", color='C0', label=r'High $N$, high $\tau$')

ax1.set_xlabel(r"$t$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# ax1.set_title(r"C")
ax1.set_ylim(-3e-4, 5e-3)
ax2.set_ylim(-3e-4, 5e-3)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()
fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")

plt.show()

# Conservative vs non-conservative
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle(r"Conservative vs non-conservative", fontsize=26)

#ax1.plot(t, error_conservative_P3P3_fullstab_lowN_lowtau, marker='o', markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'Low $N$, low $\tau$')

ax1.plot(t, error_conservative_P3P3_fullstab_highN_lowtau, marker='o', markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C0', label=r'High $N$, low $\tau$')
ax1.plot(t, error_classical_P3P3_fullstab_lowN_lowtau, marker='s', markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color='C3', label=r'Classical')

#ax2.plot(t, error_conservative_P3P3_fullstab_lowN_hightau, marker='o', linestyle=":", color='C3', label=r'Low $N$, high $\tau$')
#ax2.plot(t, error_conservative_P3P3_fullstab_highN_hightau, marker='o', linestyle=":", color='C0', label=r'High $N$, high $\tau$')

ax1.set_xlabel(r"$t$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# ax1.set_title(r"C")
#ax1.set_ylim(-3e-4, 5e-3)
#ax2.set_ylim(-3e-4, 5e-3)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()
fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Error vs t finer mesh

# %%
# T = 0.5, h = 0.05625, dT = 0.015625, tau and N varies

# P3 x P3

# N = 7 in time, 9 in space, tau = 0.1  
error_conservative_P3P3_fullstab_lowN_lowtau =  [3.13509e-08, 7.40073e-08, 2.14423e-07, 1.30918e-07, 5.15156e-07, 2.06152e-07, 2.31186e-07, 2.602e-07, 1.32954e-06, 7.75829e-07, 3.53534e-07, 7.86844e-07, 4.44854e-07, 9.46617e-07, 4.84809e-07, 2.17905e-06, 1.01182e-06, 5.89892e-07, 6.11425e-07, 1.14947e-06, 2.45345e-06, 6.99503e-07, 2.7224e-06, 9.76941e-07, 1.2969e-06, 8.05104e-07, 2.18003e-06, 2.6131e-06, 8.90812e-07, 9.38229e-07, 9.69296e-07, 1.89624e-06]
time_average_lowN_lowtau = 6.889028141848049e-07

# N = 7 in time, 9 in space, tau = 50
error_classical_P3P3_fullstab_lowN_lowtau = [3.13478e-08, 6.52508e-08, 9.9014e-08, 1.30896e-07, 1.63516e-07, 1.89968e-07, 2.27846e-07, 2.60197e-07, 2.93304e-07, 3.36791e-07, 3.52525e-07, 3.80733e-07, 4.1758e-07, 4.55093e-07, 4.8259e-07, 5.19166e-07, 5.61582e-07, 5.82418e-07, 6.1016e-07, 6.36781e-07, 6.94231e-07, 7.02317e-07, 7.35024e-07, 7.54692e-07, 7.62538e-07, 8.06486e-07, 8.17826e-07, 8.6026e-07, 8.89335e-07, 9.01173e-07, 9.37742e-07, 9.96674e-07]
time_average_classical = 4.065362923954936e-07



t = np.linspace(0, 0.5, 32)

# Conservative scheme
#fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle(r"Changing $\tau$", fontsize=26)

ax1.set_title(r"Small $N$")
ax2.set_title(r"Large $N$")
ax1.plot(t, error_conservative_P3P3_fullstab_lowN_lowtau, marker='s', markersize=4, linestyle=":", color='C3', label=r'Small $N$, small $\tau$')
ax1.plot(t, error_conservative_P3P3_fullstab_lowN_hightau, marker='o', markersize=4, linestyle=":", color='C3', label=r'Small $N$, large $\tau$')
ax2.plot(t, error_conservative_P3P3_fullstab_highN_lowtau, marker='s', markersize=4, linestyle=":", color='C0', label=r'Large $N$, small $\tau$')
ax2.plot(t, error_conservative_P3P3_fullstab_highN_hightau, marker='o',markersize=4, linestyle=":", color='C0', label=r'Large $N$, large $\tau$')

#ax1.plot(t, time_average_lowN_lowtau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o',markersize=4, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3')
#ax1.plot(t, time_average_lowN_hightau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o', markersize=4, linestyle=":", color='C3')
#ax2.plot(t, time_average_highN_lowtau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o',markersize=4, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C0')
#ax2.plot(t, time_average_highN_hightau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o', markersize=4, linestyle=":", color='C0')

#ax2.plot(t, error_classical_P3P3_fullstab_lowN_lowtau, marker='^', color="C2", linestyle="--")

ax1.set_xlabel(r"$t$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# ax1.set_title(r"C")
ax1.set_ylim(-1e-7, 6e-6)
ax2.set_ylim(-1e-7, 6e-6)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()

fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")

plt.show()



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle(r"Changing $N$", fontsize=26)
ax1.set_title(r"Small $\tau$")
ax2.set_title(r"Large $\tau$")
ax1.plot(t, error_conservative_P3P3_fullstab_lowN_lowtau, marker='s',markersize=4, linestyle=":", color='C3', label=r'Small $N$, small $\tau$')
ax1.plot(t, error_conservative_P3P3_fullstab_highN_lowtau, marker='s', markersize=4,linestyle=":", color='C0', label=r'Large $N$, small $\tau$')

ax2.plot(t, error_conservative_P3P3_fullstab_lowN_hightau, marker='o', markersize=4,linestyle=":", color='C3', label=r'Small $N$, large $\tau$')
ax2.plot(t, error_conservative_P3P3_fullstab_highN_hightau, marker='o', markersize=4,linestyle=":", color='C0', label=r'Large $N$, large $\tau$')

ax1.set_xlabel(r"$t$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# ax1.set_title(r"C")
ax1.set_ylim(-1e-7, 6e-6)
ax2.set_ylim(-1e-7, 6e-6)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()
fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")

plt.show()


fig, (ax1, ax2) = plt.subplots(1,2,figsize=(11,5))
ax1.set_title(r"Macro vs fullstab")
ax2.set_title(r"Macro vs macro")
ax1.plot(t, error_conservative_P3P3_fullstab_highN_lowtau, marker='s', markersize=4,linestyle=":", color='C0', label=r'Large $N$, small $\tau$')
ax1.plot(t, error_conservative_P3P3_macro_lowN_hightau,marker='o', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'Small $N$, large $\tau$')
ax1.set_xlabel(r"$t$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
ax2.plot(t, error_conservative_P3P3_macro_lowN_lowtau, marker='s', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C0', label=r'Small $N$, small $\tau$')
ax2.plot(t, error_conservative_P3P3_macro_lowN_hightau,marker='o', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'Small $N$, large $\tau$')
ax2.set_xlabel(r"$t$")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
ax1.set_ylim(-1e-7, 6e-6)
ax2.set_ylim(-1e-7, 6e-6)
# ax1.set_title(r"C")
#ax.set_ylim(-1e-7, 6e-6)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()
fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")

plt.show()



# Conservative vs non-conservative
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle(r"Conservative vs non-conservative", fontsize=26)

#ax1.plot(t, error_conservative_P3P3_fullstab_lowN_lowtau, marker='o', markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'Low $N$, low $\tau$')
ax1.plot(t, error_classical_P3P3_fullstab_lowN_lowtau, marker='s',markersize=4, linestyle="--", color='C3', label=r'Non-conservative')
ax1.plot(t, error_conservative_P3P3_fullstab_highN_lowtau, marker='o', markersize=4,linestyle=":", color='C0', label=r'Large $N$, small $\tau$')

ax2.plot(t, error_classical_P3P3_fullstab_lowN_lowtau, marker='s', markersize=4,linestyle="--", color='C3', label=r'Non-conservative')
ax2.plot(t, error_conservative_P3P3_macro_lowN_hightau, marker='o', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'Small $N$, large $\tau$')

ax1.set_xlabel(r"$t$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# ax1.set_title(r"C")
ax1.set_ylim(-1e-7, 3e-6)
ax2.set_ylim(-1e-7, 3e-6)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()
fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")

plt.show()




# Macro with different tau


# N=9, tau=25
error_conservative_P3P3_macro_lowN_tau25 = [2.92723e-08, 5.51224e-08, 8.93473e-08, 1.23399e-07, 1.42437e-07, 1.65923e-07, 2.14065e-07, 2.33372e-07, 2.51598e-07, 2.93465e-07, 3.91622e-07, 3.72725e-07, 3.71099e-07, 4.27663e-07, 4.92901e-07, 5.28792e-07, 5.44091e-07, 5.48876e-07, 5.83385e-07, 6.06682e-07, 5.78736e-07, 1.32489e-06, 6.75278e-07, 8.13777e-07, 7.25608e-07, 9.10032e-07, 9.38444e-07, 8.91424e-07, 7.83586e-07, 8.79699e-07, 9.19208e-07, 8.91843e-07]
time_average_lowN_hightau_macro = 4.043821889947989e-07

# N = 9, tau = 50
error_conservative_P3P3_macro_lowN_tau50 = [3.03061e-08, 5.76016e-08, 9.33781e-08, 1.31221e-07, 1.49176e-07, 1.72541e-07, 2.21866e-07, 2.42704e-07, 2.61507e-07, 3.10994e-07, 4.08807e-07, 3.95531e-07, 3.9056e-07, 4.49247e-07, 5.25873e-07, 5.70298e-07, 5.77531e-07, 5.71275e-07, 6.19951e-07, 6.4539e-07, 6.17772e-07, 1.5752e-06, 7.24722e-07, 7.57413e-07, 7.69399e-07, 9.84444e-07, 1.01124e-06, 9.4957e-07, 8.22851e-07, 9.46878e-07, 9.40717e-07, 9.65467e-07]
time_average_lowN_hightau_macro = 4.33078e-07

# N = 9, tau = 100
error_conservative_P3P3_macro_lowN_tau100 = [3.05983e-08, 5.8198e-08, 9.45895e-08, 1.34344e-07, 1.51589e-07, 1.74046e-07, 2.23792e-07, 2.44886e-07, 2.64819e-07, 3.16772e-07, 4.16667e-07, 4.02007e-07, 3.95231e-07, 4.54113e-07, 5.36728e-07, 5.8632e-07, 5.88814e-07, 5.76578e-07, 6.31474e-07, 6.57571e-07, 6.29592e-07, 1.74228e-06, 7.39733e-07, 7.71891e-07, 7.79315e-07, 1.00942e-06, 1.04013e-06, 9.71227e-07, 8.31298e-07, 9.6626e-07, 9.63888e-07, 9.87753e-07, ]
time_average_lowN_hightau_macro = 4.46644e-07

fig, ax = plt.subplots(1,1,figsize=(6, 5))
fig.suptitle(r"Macro with different $\tau$ and $\delta$, $N=9$", fontsize=26)
ax.plot(t, error_conservative_P3P3_macro_lowN_tau10_delta03, marker='p', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C4', label=r'$\tau=10$, $\delta = 0.3$')
ax.plot(t, error_conservative_P3P3_macro_lowN_tau10_delta05, marker='p', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C5', label=r'$\tau=10$, $\delta = 0.5$')
ax.plot(t, error_conservative_P3P3_macro_lowN_tau25, marker='o', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'$\tau=25$, $\delta = 0.5$')
ax.plot(t, error_conservative_P3P3_macro_lowN_tau50, marker='^', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C2', label=r'$\tau=50$, $\delta = 0.5$')
ax.plot(t, error_conservative_P3P3_macro_lowN_tau100, marker='s', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C0', label=r'$\tau=100$, $\delta = 0.5$')


ax.set_xlabel(r"$t$")
ax.tick_params(axis='both', which='major')
ax.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# ax1.set_title(r"C")
ax.set_ylim(-1e-7, 3e-6)
#ax2.set_ylim(-1e-7, 3e-6)
ax.legend()
#ax2.legend()
ax.grid()
#ax2.grid()
fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")
plt.show()


# error_conservative_P3P3_macro_lowN_tau25_fine = [2.35846e-09, 2.24528e-09, 2.36058e-08, 8.64456e-09, 3.93333e-08, 4.16792e-07, 4.69753e-08, 9.90823e-09, 3.2529e-08, 1.02795e-07, 5.12744e-08, 1.7072e-07, 1.04049e-07, 1.58544e-07, 7.58861e-08, 8.10169e-08, 4.07275e-07, 6.83923e-08, 1.81486e-07, 3.73201e-08, 1.85768e-07, 5.4649e-08, 3.2855e-07, 1.37188e-06, 1.33259e-07, 2.06614e-07, 1.08627e-07, 2.82402e-07, 1.56414e-07, 2.28589e-07, 1.91459e-05, 2.00452e-07, 1.83583e-07, 1.34249e-07, 1.32805e-06, 9.68969e-08, 6.37926e-07, 4.23798e-08, 2.9745e-07, 9.71761e-08, 3.47254e-07, 4.94223e-06, 1.86117e-07, 5.401e-07, 1.95756e-07, 4.16804e-07, 1.67155e-07, 6.05535e-08, 7.13903e-08, 1.87314e-07, 5.10448e-07, 7.29848e-08, 9.57933e-07, 2.09907e-07, 7.77711e-08, 8.52647e-08, 3.58716e-07, 1.24746e-07, 1.23428e-07, 2.11318e-05, 1.81575e-07, 1.04897e-07, 8.81895e-08, 8.24379e-07]
# tfine = np.linspace(0, 0.5, 64)

# fig, ax = plt.subplots(1,1,figsize=(6, 5))
# fig.suptitle(r"Macro with different $\tau$, another refinement", fontsize=26)

# ax.plot(t, error_conservative_P3P3_macro_lowN_tau25, marker='o', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C2', label=r'Small $N$, $\tau=25$')
# ax.plot(tfine, error_conservative_P3P3_macro_lowN_tau25_fine, marker='o', markersize=4,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'Small $N$, $\tau=25$')

# ax.set_xlabel(r"$t$")
# ax.tick_params(axis='both', which='major')
# ax.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# # ax1.set_title(r"C")
# #ax.set_ylim(-1e-7, 3e-6)
# #ax2.set_ylim(-1e-7, 3e-6)
# ax.legend()
# #ax2.legend()
# ax.grid()
# #ax2.grid()
# fig.tight_layout()
# #fig.savefig("ex2_conservative.pdf")
# plt.show()

# %% [markdown]
# ### L2 error vs h

# %%
# N = 3, T = 0.5, tau = 0.05
error_conservative_P1P1_fullstab = [0.1989759065703572, 0.05361097109458719, 0.01438543000825592, 0.003599085848373394, 0.0009043873595060955, 0.0002248503048575394]
error_conservative_P1P1_fullstab_T = [0.1006677083780572, 0.02474100489967533, 0.006523037807333562, 0.001618649361718564, 0.0004052652780911548, 0.0001006445092287986]
conservation_error_conservative_P1P1_fullstab = [6.661338147750939e-16, 7.105427357601002e-15, 9.992007221626409e-15, 3.885780586188048e-14, 1.738609256562995e-13, 3.077538224260934e-13]
cond_conservative_P1P1_fullstab = [4.760708e+03,4.329810e+03,4.294495e+03,4.305562e+03,4.656087e+03,1.421256e+04]
cond_conservative_P1P1_fullstab = [1.090501e+04,9.693815e+03,1.013815e+04,1.050754e+04,1.201996e+04,3.003819e+04]  # condest

# error_conservative_P1P1_macro = 
# error_conservative_P1P1_macro_T =
# cond_conservative_P1P1_macro = 
# cond_conservative_P1P1_macro =  # condest

# # N = 5 space and time, T = 0.5, tau = 0.05
# error_conservative_P2P2_fullstab =
# error_conservative_P2P2_fullstab_T =
# cond_conservative_P2P2_fullstab = 
# cond_conservative_P2P2_fullstab =   # condest

# N = 5 space and time, T = 0.5, tau = 0.05, delta=0.5
error_conservative_P2P2_macro = [0.03419616289984484, 0.003762489553770874, 0.0004868519889486721, 5.907974965614777e-05, 7.754847139116535e-06, 1.002803248713876e-06]
error_conservative_P2P2_macro_T = [0.01488988574033379, 0.001707856134411441, 0.0002177343486143799, 2.643739335060008e-05, 3.325757224965642e-06, 4.260156028806221e-07]
cond_conservative_P2P2_macro = [6.107982e+06,8.159044e+06,1.753955e+07,2.124566e+07,1.018651e+07,4.567273e+07]
cond_conservative_P2P2_macro = [2.386371e+07,2.660831e+07,6.075826e+07,7.720372e+07,3.550963e+07,1.798373e+08] # condest

# N = 5 space and time, T = 0.5, tau = 0.5, delta=0.5
error_conservative_P2P2_macro = [0.06239745329378621, 0.004889288381172733, 0.0005688501293847938, 6.327541449590749e-05, 7.615014922744452e-06, 9.32511772332507e-07]
error_conservative_P2P2_macro_T = [0.02339708210316853, 0.002182021707683239, 0.0002412420712320588, 2.744319157389792e-05, 3.372350355633482e-06, 4.140995449278484e-07]
cond_conservative_P2P2_macro = [8.551447e+06,1.565859e+07,3.948676e+07,3.754433e+07,2.063444e+07,9.015749e+07]
cond_conservative_P2P2_macro = [3.460185e+07,5.659215e+07,1.479255e+08,1.217228e+08,7.666513e+07,2.748338e+08]  # condest

# N = 5 space and time, T = 0.5, tau = 0.1, delta=0.5
error_conservative_P2P2_macro = [0.00432703, 0.000192462, 4.12622e-05, 9.0308e-06, 9.82291e-06]
error_conservative_P2P2_macro_T = [0.00250526, 9.37319e-05, 0.00508497, 2.97023e-06, 1.24573e-05]

# N = 9 time, 5 space, T = 0.5, tau = 0.1, delta = 0.5
error_conservative_P2P2_macro = [0.03974111329509004, 0.003954930383198897, 0.0004992348935860456, 5.946934295040914e-05, 7.41580874652292e-06]
error_conservative_P2P2_macro_T = [0.01641659409415603, 0.001782324908510956, 0.0002210782363267117, 2.655332874965102e-05, 3.317448450364291e-06]

# N = 5 time and space, T = 0.5, tau = 0.1, delta = 0.5
error_conservative_P2P2_macro = [0.03974104095226471, 0.003956195361468989, 0.0004992517043027509, 5.952597010793624e-05, 7.559319559131937e-06]
error_conservative_P2P2_macro_T = [0.01641603499907085, 0.001782333678721166, 0.0002210819842198375, 2.656197649938825e-05, 3.324848968789129e-06]

# N = 5 time and space, T = 0.5, tau = 0.1
error_conservative_P2P2_fullstab = [0.05532198829960861, 0.004814853286650941, 0.0005338771869350154, 6.13990601857685e-05, 7.64997944656389e-06]
error_conservative_P2P2_fullstab_T = [0.02399614128609451, 0.002077500569008253, 0.0002352961517539772, 2.71267001599149e-05, 3.359167662915976e-06]

error_classical_P2P2_fullstab = [0.05532307077400784, 0.004813960375541763, 0.0005338706785400062, 6.131688923940537e-05, 7.495254565787043e-06]
error_classical_P2P2_fullstab_T = [0.02399626546783219, 0.002077468408352892, 0.0002352867750262572, 2.710981909897823e-05, 3.343247248463512e-06]

# N = 5 time and space, T = 0.5, tau = 0.1, delta = 0.3
error_conservative_P2P2_macro = [0.03248538707431325, 0.003740774604723877, 0.0004839819364049025, 5.906191124254753e-05, 7.535027862392649e-06]
error_conservative_P2P2_macro_T = [0.01504767584604897, 0.001688872635709576, 0.0002172223679075363, 2.644476193864028e-05, 3.317002225739229e-06]

error_classical_P2P2_macro = [0.03248604497582768, 0.003739291868951654, 0.0004839640935558316, 5.90049417341686e-05, 7.388210342734851e-06]
error_classical_P2P2_macro_T = [0.01504805062487204, 0.001688857117605521, 0.0002172182225118702, 2.643594270935263e-05, 3.309450894361275e-06]


# T = 0.5, tau = 0.5, N=9
error_conservative_P3P3_fullstab = [0.0201684, 0.000617533, 2.94953e-05, 1.47845e-06, 1.8241e-07]
error_conservative_P3P3_fullstab_T = [0.00799989, 0.000240732, 1.17084e-05, 5.6436e-07, 4.53368e-08]

# T = 0.5, tau = 0.5, N=9
error_conservative_P3P3_fullstab = [0.0201684, 0.000617533, 2.94953e-05, 1.47845e-06, 1.8241e-07]   # last iteration fails because of umfpack
error_conservative_P3P3_fullstab_T = [0.00799989, 0.000240732, 1.17084e-05, 5.6436e-07, 4.53368e-08]

# tau = 0.1, N = 9 in time and space and all elements are integrated with algoim so that on uncut elements it's 81 points not 25 (as it is otherwise)
error_conservative_P3P3_fullstab = [0.0122360506346707, 0.0003737808539915641, 1.956683183668976e-05, 1.260191735236001e-06, 4.086311375953415e-07]
error_conservative_P3P3_fullstab_T = [0.004832359064899349, 0.0001502596614538686, 8.121965911049731e-06, 4.672668817802866e-07, 8.176966404477602e-08]


# # N = 9 space and time, T = 0.5, tau = 0.05
error_conservative_P3P3_macro = [0.00362922, 0.000167539, 1.14627e-05, 6.58857e-07, 1.1733e-07]
error_conservative_P3P3_macro_T = [0.00142823, 8.05744e-05, 5.16023e-06, 4.49995e-07, 1.13737e-07]
#cond_conservative_P3P3_macro = # last inf
#cond_conservative_P3P3_macro = # condest

# N = 9 space and time, T = 0.5, tau = 0.05
error_conservative_P3P3_macro = [0.0038947, 0.00014826, 1.21326e-05, 1.56988e-06]
error_conservative_P3P3_macro_T = [0.00154581, 8.10583e-05, 5.17379e-06, 4.45616e-07]
#cond_conservative_P3P3_macro = # last inf
#cond_conservative_P3P3_macro = # condest

# # T = 0.5, tau = 0.05, N=14, delta = 0.5
error_conservative_P3P3_macro = [0.000147989, 1.21321e-05, 7.68122e-07, 1.74456e-07]
error_conservative_P3P3_macro_T = [8.1025e-05, 5.09974e-06, 3.02165e-07, 3.76098e-08]

# T = 0.5, tau = 1, N=14, delta = 0.5
error_conservative_P3P3_macro = [0.00527704, 0.000169199, 1.57501e-05, ]
error_conservative_P3P3_macro_T = [0.00198708, 0.000139069, 6.45217e-06, ]


# when h=0.028125:
nx = 249
ny = 107


h = [0.45, 0.225, 0.1125, 0.05625, 0.028125, 0.0140625]
dt = [0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625]

# Conservative scheme
#fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle("Conservative scheme", fontsize=26)
ax1.loglog(h, 2.5*np.power(h, 2), linestyle="-", color="black")   
ax1.loglog(h, 7.5e-1*np.power(h, 3), linestyle="-", color="black")   
ax1.loglog(h, 2.5e-1*np.power(h, 4), linestyle="-", color="black")   

ax1.loglog(h, error_conservative_P1P1_fullstab, marker='o', markersize=9, linestyle=":", color="C2")
ax1.loglog(h[:5], error_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
# ax1.loglog(h, error_conservative_P1P1_macro, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax1.loglog(h[:5], error_conservative_P2P2_macro, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")

# tau = 0.5, N=20
error_conservative_P3P3_fullstab = [0.02016841435775182, 0.0006177184787778765, 2.949589623667342e-05, 1.44015847749771e-06, 7.1634476352156e-08]
error_conservative_P3P3_fullstab_T = [0.007999887780597308, 0.0002407195339906577, 1.170625028077713e-05, 5.538211736452714e-07, 2.848783878362371e-08]
#print(convergence_rate(error_conservative_P3P3_fullstab, h[:5]))
#print(convergence_rate(error_conservative_P3P3_fullstab_T, h[:5]))

# tau = 0.5, N=7 but naive adaptive with N=20 on cut elements
error_conservative_P3P3_fullstab = [0.02016842586753676, 0.0006172864066721854, 2.950706032650268e-05, 1.564607265695634e-06, 3.4534855282236e-07]
error_conservative_P3P3_fullstab_T = [0.00799991104968353, 0.0002407476192438616, 1.171312532265542e-05, 5.888672338286437e-07, 7.894525060821001e-08]

# tau = 0.5, N=9 but naive adaptive with N=20 on cut elements (realized that this was not done to the int_In (u, beta * gradv) term and also not force)
error_conservative_P3P3_fullstab = [0.02016841465527545, 0.0006175532161470379, 2.949553831293328e-05, 1.467710666313325e-06, 1.632202930900014e-07]
error_conservative_P3P3_fullstab_T = [0.007999888942277402, 0.0002407314426129182, 1.170760420377677e-05, 5.617075244460524e-07, 4.214744210226388e-08]

# tau = 0.5, N=9 but naive adaptive with N=20 on cut elements (also to the int_In (u, beta * gradv) term but not force)
error_conservative_P3P3_fullstab =  [0.02016841468477248, 0.000617719917808522, 2.949593748957576e-05, 1.440372451935522e-06, 7.167831030480745e-08]
error_conservative_P3P3_fullstab_T =  [0.007999888524965469, 0.000240719442696518, 1.170624224834675e-05, 5.538197022652577e-07, 2.849056055862064e-08]

# tau = 0.5, N=9 in time and space, but N=20 for the RHS
# didn't improve 
error_conservative_P3P3_fullstab = [0.0201684, 0.000617531, 2.94952e-05, 1.4785e-06, 1.82574e-07]
error_conservative_P3P3_fullstab_T = [0.00799988, 0.000240732, 1.17084e-05, 5.64363e-07, 4.53339e-08] 

# T = 0.5, tau = 0.1, N=14
#! mac vscode
error_conservative_P3P3_fullstab = 
error_conservative_P3P3_fullstab_T =


# T = 0.5, tau = 0.1, N=20
error_conservative_P3P3_fullstab = [0.01223605003771489, 0.0003742373214565644, 1.956601974072018e-05, 1.00301769833917e-06, 6.061232272930865e-08]
error_conservative_P3P3_fullstab_T = [0.004832327558830694, 0.0001502390346741854, 8.104385431733954e-06, 4.072767827806983e-07, 2.367701577824175e-08]
condition_number_P3P3_fullstab = [7.505936e+10,5.578367e+10,8.855151e+10,9.853569e+11,3.022954e+11]
#print(convergence_rate(error_conservative_P3P3_fullstab, h[:5]))
#print(convergence_rate(error_conservative_P3P3_fullstab_T, h[:5]))
ax1.loglog(h[:5], error_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C3")
ax2.loglog(h[:5], error_conservative_P3P3_fullstab_T, marker='^', markersize=9, linestyle=":", color="C3")

# T = 0.5, tau = 0.5, N=20, delta = 0.5
# error_conservative_P3P3_macro = [0.00552914, 0.000173776, 1.65945e-05, 7.94512e-07, 4.65565e-08]
# error_conservative_P3P3_macro_T = [0.00118365, 0.000103242, 3.27351e-06, 1.73739e-07, 1.9259e-08]
# ax1.loglog(h[:5], error_conservative_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")
# ax2.loglog(h[:5], error_conservative_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")

# T = 0.5, tau = 50, N=9 
error_conservative_P3P3_macro = [0.00666703, 0.000199474, 2.09852e-05, 9.65467e-07, 5.185286253127099e-08]      
error_conservative_P3P3_macro_T = [0.00238119, 0.00037071, 8.48811e-06, 4.33078e-07, 2.232786224673695e-08]

# T = 0.5, tau = 100, N=9 
error_conservative_P3P3_macro = [0.006762306916845246, 0.0002039405887298556, 2.145118011419113e-05, 9.877527527546494e-07, 5.262522547333666e-08]
error_conservative_P3P3_macro_T = [0.002412161889281498, 0.0004190088951240055, 8.659740782038019e-06, 4.466436126117099e-07, 2.263107847197029e-08]

# N = 10, tau = 10, delta = 0.5 
error_conservative_P3P3_macro = [0.006207646322210996, 0.0001860942822342113, 1.904536716920308e-05, 8.843901122300703e-07, 4.98510397684518e-08]
error_conservative_P3P3_macro_T = [0.002243304923427555, 0.0002419442353551644, 7.75075292932194e-06, 3.891279763700688e-07, 2.121908876583533e-08]

# N = 9, tau = 10, delta = 0.5
error_conservative_P3P3_macro = [0.00620765, 0.00018604, 1.90455e-05, 8.84683e-07]
error_conservative_P3P3_macro_T = [0.0022433, 0.000241944, 7.75074e-06, 3.89189e-07]

# N = 9, tau = 10, delta = 0.3
error_conservative_P3P3_macro = [0.003270011965347297, 0.0001683729240335924, 1.315277005737627e-05, 7.349350690559678e-07, 4.751394457549026e-08]
error_conservative_P3P3_macro_T = [0.001567392517657676, 8.099172071863181e-05, 5.380135699128577e-06, 3.069209271783663e-07, 1.809743012875411e-08]

# N = 9, tau = 1, delta = 0.3
#! 606444.pts-4.ross (data_conservative.dat)
# error_conservative_P3P3_macro = 
# error_conservative_P3P3_macro_T =


ax1.loglog(h[:5], error_conservative_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")
ax2.loglog(h[:5], error_conservative_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")


nb_active_elements = [21, 76, 280, 1071, 4078]

#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$h$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(T))}$")
#ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax1.grid()



ax2.loglog([],[], label=r"$\mathcal{O}(h^{k+1})$", linestyle="-", color="black")
ax2.loglog([],[], label=r"$\mathcal{O}(h^{-2})$", linestyle="-.", color="black")
ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$m=1, k=0$")
ax2.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax2.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax2.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
#ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle=(0, (5,7)), color="black",label=r"Non-conservative Scheme")
#ax2.loglog([],[], linestyle=":", color="black", label=r"Conservative Scheme")
#ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

ax2.loglog(h, 2.5*np.power(h, 2), linestyle="-", color="black")   
ax2.loglog(h, 7.5e-1*np.power(h, 3), linestyle="-", color="black")   
ax2.loglog(h, 2.5e-1*np.power(h, 4), linestyle="-", color="black")   

ax2.loglog(h, error_conservative_P1P1_fullstab_T, marker='o', markersize=9, linestyle=":", color="C2")
ax2.loglog(h[:5], error_conservative_P2P2_fullstab_T, marker='s', markersize=9, linestyle=":", color="C0")
#ax2.loglog(h[:5], error_conservative_P3P3_fullstab_T, marker='^', markersize=9, linestyle=":", color="C3")

# ax2.loglog(h, error_conservative_P1P1_macro_T, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax2.loglog(h[:5], error_conservative_P2P2_macro_T, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
#ax2.loglog(h[:5], error_conservative_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")


# ax2.loglog(h, 6.5*np.power(h, 2), linestyle="-", color="black")   
# ax2.loglog(h, 1.5*np.power(h, 3), linestyle="-", color="black")  
# ax2.loglog(h, 1.5*np.power(h, 4), linestyle="-", color="black")  

# ax2.loglog(h, error_conservative_P1P1_fullstab_T, marker='o', markersize=9, linestyle=":", color="C2")
# ax2.loglog(h, error_conservative_P2P2_fullstab_T, marker='s', markersize=9, linestyle=":", color="C0")
# ax2.loglog(h, error_conservative_P3P3_fullstab_T, marker='^', markersize=9, linestyle=":", color="C3")

# ax2.loglog(h, error_conservative_P1P1_macro_T, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
# ax2.loglog(h, error_conservative_P2P2_macro_T, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
# ax2.loglog(h, error_conservative_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")

ax2.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
# ax2.set_xlabel(r"$h$")
# ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"$\|u_h-u\|_{L^2(L^2(\Omega(t)), 0, T)}$ (log)")
# #ax2.set_title(r"Conservative scheme")
# #ax2.legend()
ax2.grid()

#handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")
plt.show()



# Non-conservative scheme

# T = 0.5, tau = 0.05, N=9
error_classical_P3P3_fullstab = [0.008954326513606092, 0.0002845539391912771, 1.575842447096622e-05, 8.429293634984765e-07, 4.630676309155364e-08]
error_classical_P3P3_fullstab_T = [0.003563336160906122, 0.0001178071111986499, 6.746843781991671e-06, 3.536620415046541e-07, 1.989369514434076e-08]

#! 606157.pts-4.ross: tau = 0.1, N=9
# error_classical_P3P3_fullstab = 
# error_classical_P3P3_fullstab_T =

# T = 0.5, tau = 0.1, N=9 space and time
error_classical_P3P3_macro = [0.004351765637564267, 0.0001537047372854674, 1.322741252523503e-05, 6.769254226415405e-07, 3.991561775041458e-08]
error_classical_P3P3_macro_T = [0.001692956566057534, 9.16651428739156e-05, 5.490144973844466e-06, 2.99105526525753e-07, 1.782467294327645e-08]

#fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle("Non-conservative scheme", fontsize=26)
ax1.loglog(h, 2.5*np.power(h, 2), linestyle="-", color="black")   
ax1.loglog(h, 7.5e-1*np.power(h, 3), linestyle="-", color="black")   
ax1.loglog(h, 2.5e-1*np.power(h, 4), linestyle="-", color="black")   

# ax1.loglog(h, error_classical_P1P1_fullstab_T, marker='o', markersize=9, linestyle="--", color="C2")
ax1.loglog(h[:5], error_classical_P2P2_fullstab_T, marker='s', markersize=9, linestyle="--", color="C0")
ax1.loglog(h[:5], error_classical_P3P3_fullstab, marker='^', markersize=9, linestyle="--", color="C3")

# ax1.loglog(h, error_classical_P1P1_macro_T, marker='o', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax1.loglog(h[:5], error_classical_P2P2_macro_T, marker='s', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax1.loglog(h[:5], error_classical_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")


#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$h$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(T))}$")
#ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax1.grid()



ax2.loglog([],[], label=r"$\mathcal{O}(h^{k+1})$", linestyle="-", color="black")
ax2.loglog([],[], label=r"$\mathcal{O}(h^{-2})$", linestyle="-.", color="black")
ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$m=1, k=0$")
ax2.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax2.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax2.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
#ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle=(0, (5,7)), color="black",label=r"Non-conservative Scheme")
#ax2.loglog([],[], linestyle=":", color="black", label=r"Conservative Scheme")
#ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

ax2.loglog(h, 2.5*np.power(h, 2), linestyle="-", color="black")   
ax2.loglog(h, 7.5e-1*np.power(h, 3), linestyle="-", color="black")   
ax2.loglog(h, 2.5e-1*np.power(h, 4), linestyle="-", color="black")   

# ax2.loglog(h, error_classical_P1P1_fullstab_T, marker='o', markersize=9, linestyle="--", color="C2")
ax2.loglog(h[:5], error_classical_P2P2_fullstab_T, marker='s', markersize=9, linestyle="--", color="C0")
ax2.loglog(h[:5], error_classical_P3P3_fullstab_T, marker='^', markersize=9, linestyle="--", color="C3")

# ax2.loglog(h, error_classical_P1P1_macro_T, marker='o', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax2.loglog(h[:5], error_classical_P2P2_macro_T, marker='s', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax2.loglog(h[:5], error_classical_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")

ax2.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax2.set_xlabel(r"$h$")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"$\|u_h-u\|_{L^2(L^2(\Omega(t)), 0, T)}$ (log)")
# #ax2.set_title(r"Conservative scheme")
# #ax2.legend()
ax2.grid()

#handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
#fig.savefig("ex2_conservative.pdf")
plt.show()
# Out:
#   File "<ipython-input-26-519f4ab4bab6>", line 138
#     error_conservative_P3P3_fullstab =
#                                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Fig 1: Error vs h

# %%
# # N = 3, T = 0.5, tau = 0.1
# error_conservative_P1P1_fullstab = [0.2036572547450206, 0.05580141017126896, 0.01489701843184913, 0.003684845396220872, 0.0009157601140102803]
# error_conservative_P1P1_macro = [0.1890004564172002, 0.05177097945981452, 0.01400918423917278, 0.003547926684717089, 0.0008973069663870141]

# # N = 5 time and space, T = 0.5, tau = 0.1
# error_conservative_P2P2_fullstab = [0.05532198829960861, 0.004814853286650941, 0.0005338771869350154, 6.13990601857685e-05, 7.64997944656389e-06]
# error_conservative_P2P2_fullstab_T = [0.02399614128609451, 0.002077500569008253, 0.0002352961517539772, 2.71267001599149e-05, 3.359167662915976e-06]

# # N = 5 time and space, T = 0.5, tau = 0.1, delta = 0.3
# error_conservative_P2P2_macro = [0.03248538707431325, 0.003740774604723877, 0.0004839819364049025, 5.906191124254753e-05, 7.535027862392649e-06]
# error_conservative_P2P2_macro_T = [0.01504767584604897, 0.001688872635709576, 0.0002172223679075363, 2.644476193864028e-05, 3.317002225739229e-06]


# # T = 0.5, tau = 0.1, N=14
# #error_conservative_P3P3_fullstab = [0.01223605165955336, 0.0003743094870741799, 1.956671914709339e-05, 1.028686617516824e-06, 9.871221420066537e-08]
# #error_conservative_P3P3_fullstab_T = [0.00483236401471855, 0.0001502336949655485, 8.105133128041171e-06, 4.12177828310638e-07, 3.174318977819827e-08]

# # T = 0.5, tau = 0.1, N=20
# error_conservative_P3P3_fullstab = [0.01223605003771489, 0.0003742373214565644, 1.956601974072018e-05, 1.00301769833917e-06, 6.061232272930865e-08]
# error_conservative_P3P3_fullstab_T = [0.004832327558830694, 0.0001502390346741854, 8.104385431733954e-06, 4.072767827806983e-07, 2.367701577824175e-08]

# # N = 9, tau = 10, delta = 0.3
# error_conservative_P3P3_macro = [0.003270011965347297, 0.0001683729240335924, 1.315277005737627e-05, 7.349350690559678e-07, 4.751394457549026e-08]
# error_conservative_P3P3_macro_T = [0.001567392517657676, 8.099172071863181e-05, 5.380135699128577e-06, 3.069209271783663e-07, 1.809743012875411e-08]

# # N = 9, tau = 1, delta = 0.3
# #error_conservative_P3P3_macro = [0.002804344867264101, 0.0001602697916708528, 1.127468321958945e-05, 7.327197265796529e-07, 1.541346965464494e-07]
# #error_conservative_P3P3_macro_T = [0.001474432175426397, 7.712458807098434e-05, 4.857380559882613e-06, 2.948364533081128e-07, 2.819059958580974e-08]


# # Non-conservative scheme
# # N = 3, T = 0.5, tau = 0.1
# error_classical_P1P1_fullstab = [0.2036761840583297, 0.05580359396887409, 0.01489803386451458, 0.003684823911604735, 0.0009157579024818542]
# error_classical_P1P1_macro = [0.1890240812352349, 0.05177159276387305, 0.01401059715356351, 0.003547981608777298, 0.0008973295766417942]

# # N = 5, T = 0.5, tau = 0.1
# error_classical_P2P2_fullstab = [0.05532307077400784, 0.004813960375541763, 0.0005338706785400062, 6.131688923940537e-05, 7.495254565787043e-06]
# error_classical_P2P2_fullstab_T = [0.02399626546783219, 0.002077468408352892, 0.0002352867750262572, 2.710981909897823e-05, 3.343247248463512e-06]

# error_classical_P2P2_macro = [0.03248604497582768, 0.003739291868951654, 0.0004839640935558316, 5.90049417341686e-05, 7.388210342734851e-06]
# error_classical_P2P2_macro_T = [0.01504805062487204, 0.001688857117605521, 0.0002172182225118702, 2.643594270935263e-05, 3.309450894361275e-06]

# # N=9, T = 0.5, tau = 0.1
# error_classical_P3P3_fullstab = [0.0122360523962978, 0.0003742071204774354, 1.956610167972593e-05, 9.966712328011701e-07, 5.246367934567297e-08]
# error_classical_P3P3_fullstab_T = [0.004832328281027372, 0.0001502414321968989, 8.104596582809958e-06, 4.065365246810671e-07, 2.203647545044289e-08]

# error_classical_P3P3_macro = [0.004351765637564267, 0.0001537047372854674, 1.322741252523503e-05, 6.769254226415405e-07, 3.991561775041458e-08]
# error_classical_P3P3_macro_T = [0.001692956566057534, 9.16651428739156e-05, 5.490144973844466e-06, 2.99105526525753e-07, 1.782467294327645e-08]

### same but tau=1

# # N = 3, T = 0.5, tau = 1
# error_conservative_P1P1_fullstab =
# error_conservative_P1P1_macro = 

# N = 5 time and space, T = 0.5, tau = 1
#! 3876.pts-2.ross
error_conservative_P2P2_fullstab = 
error_conservative_P2P2_fullstab_T =

# N = 5 time and space, T = 0.5, tau = 1, delta = 0.5
#! 4580.pts-2.ross
error_conservative_P2P2_macro = 
error_conservative_P2P2_macro_T = 

# T = 0.5, tau = 1, N=14
error_conservative_P3P3_fullstab = [0.02362089494433691, 0.0007192657938423051, 3.330955436434394e-05, 1.659704024142447e-06, 8.271660751762331e-08]
error_conservative_P3P3_fullstab_T = [0.009356126704956304, 0.0002807778236574651, 1.336314155942735e-05, 6.291052141543864e-07, 3.22324817302957e-08]

# N = 9, tau = 10, delta = 0.5
error_conservative_P3P3_macro = [0.006207646446422916, 0.0001860400955407854, 1.904546353455876e-05, 8.846823226303256e-07, 5.185338651997404e-08]
error_conservative_P3P3_macro_T = [0.002243303198766888, 0.0002419442144058373, 7.75074388451726e-06, 3.891894374624838e-07, 2.12942073092919e-08]


# Non-conservative scheme
# N = 3, T = 0.5, tau = 1
# error_classical_P1P1_fullstab = 
# error_classical_P1P1_macro = 

# # N = 5, T = 0.5, tau = 1
# error_classical_P2P2_fullstab = 
# error_classical_P2P2_fullstab_T = 

# error_classical_P2P2_macro = 
# error_classical_P2P2_macro_T = 

# N=9, T = 0.5, tau = 1

#! 83788.pts-11.ross
error_classical_P3P3_fullstab = 
error_classical_P3P3_fullstab_T =

#! 83976.pts-10.ross
error_classical_P3P3_macro = 
error_classical_P3P3_macro_T = 



h = [0.45, 0.225, 0.1125, 0.05625, 0.028125]
dt = [0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625]


# Both non-conservative and conservative
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
#fig.suptitle("Non-conservative scheme", fontsize=26)
ax1.loglog(h, 2.5*np.power(h, 2), linestyle="-", color="black")   
ax1.loglog(h, 7.5e-1*np.power(h, 3), linestyle="-", color="black")   
ax1.loglog(h, 2.5e-1*np.power(h, 4), linestyle="-", color="black")   

#ax1.loglog(h, error_conservative_P1P1_fullstab, marker='o', markersize=9, linestyle=":", color="C2")
#ax1.loglog(h, error_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
ax1.loglog(h, error_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C3")

#ax1.loglog(h, error_conservative_P1P1_macro, marker='o', markersize=9, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C2")
#ax1.loglog(h, error_conservative_P2P2_macro, marker='s', markersize=9, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C0")
ax1.loglog(h, error_conservative_P3P3_macro, marker='^', markersize=9, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")


#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$h$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(T))}$")
ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax1.grid()

ax2.loglog([],[], label=r"$\mathcal{O}(h^{k+1})$", linestyle="-", color="black")
ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax2.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax2.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

ax2.loglog(h, 2.5*np.power(h, 2), linestyle="-", color="black")   
ax2.loglog(h, 7.5e-1*np.power(h, 3), linestyle="-", color="black")   
ax2.loglog(h, 2.5e-1*np.power(h, 4), linestyle="-", color="black")   

#ax2.loglog(h, error_classical_P1P1_fullstab, marker='o', markersize=9, linestyle="--", color="C2")
#ax2.loglog(h, error_classical_P2P2_fullstab, marker='s', markersize=9, linestyle="--", color="C0")
ax2.loglog(h, error_classical_P3P3_fullstab, marker='^', markersize=9, linestyle="--", color="C3")

#ax2.loglog(h, error_conservative_P1P1_macro, marker='o', markersize=9, markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C2")
#ax2.loglog(h, error_conservative_P2P2_macro, marker='s', markersize=9, markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C0")
ax2.loglog(h, error_conservative_P3P3_macro, marker='^', markersize=9, markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")


ax2.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax2.set_xlabel(r"$h$")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(T))}$")
ax2.set_title(r"Non-conservative scheme")
# #ax2.legend()
ax2.grid()

#handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
#fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
fig.savefig("ex2_error.pdf")
plt.show()
# Out:
# /usr/lib/python3/dist-packages/numpy/ma/core.py:6717: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %% [markdown]
# ### Fig 2: Error vs t

# %%
# T = 0.5, h = 0.05625, dT = 0.015625, tau and N varies

# P3 x P3

# N = 7 in time, 9 in space, tau = 0.1  
error_conservative_P3P3_fullstab_lowN_lowtau =  [3.13509e-08, 7.40073e-08, 2.14423e-07, 1.30918e-07, 5.15156e-07, 2.06152e-07, 2.31186e-07, 2.602e-07, 1.32954e-06, 7.75829e-07, 3.53534e-07, 7.86844e-07, 4.44854e-07, 9.46617e-07, 4.84809e-07, 2.17905e-06, 1.01182e-06, 5.89892e-07, 6.11425e-07, 1.14947e-06, 2.45345e-06, 6.99503e-07, 2.7224e-06, 9.76941e-07, 1.2969e-06, 8.05104e-07, 2.18003e-06, 2.6131e-06, 8.90812e-07, 9.38229e-07, 9.69296e-07, 1.89624e-06]
time_average_lowN_lowtau = 6.889028141848049e-07

# N = 7 in time, 9 in space, tau = 50
error_conservative_P3P3_fullstab_lowN_hightau = [1.1451e-07, 2.64826e-07, 4.04385e-07, 5.33194e-07, 6.7498e-07, 7.91858e-07, 9.18053e-07, 1.03938e-06, 1.20214e-06, 1.50545e-06, 1.45773e-06, 1.51276e-06, 1.91172e-06, 1.98665e-06, 1.98801e-06, 2.17334e-06, 2.67432e-06, 2.58064e-06, 2.55183e-06, 2.5928e-06, 3.32692e-06, 3.19707e-06, 3.1888e-06, 4.01028e-06, 3.56077e-06, 3.58793e-06, 3.54142e-06, 4.43178e-06, 4.22159e-06, 4.02298e-06, 5.12364e-06, 5.28007e-06]
time_average_lowN_hightau = 1.895873602347001e-06

# N = 20 in time, 9 in space, tau = 0.1
# # N = 7 in time, tau = 0.1 
error_classical_P3P3_fullstab_lowN_lowtau = [3.13478e-08, 6.52508e-08, 9.9014e-08, 1.30896e-07, 1.63516e-07, 1.89968e-07, 2.27846e-07, 2.60197e-07, 2.93304e-07, 3.36791e-07, 3.52525e-07, 3.80733e-07, 4.1758e-07, 4.55093e-07, 4.8259e-07, 5.19166e-07, 5.61582e-07, 5.82418e-07, 6.1016e-07, 6.36781e-07, 6.94231e-07, 7.02317e-07, 7.35024e-07, 7.54692e-07, 7.62538e-07, 8.06486e-07, 8.17826e-07, 8.6026e-07, 8.89335e-07, 9.01173e-07, 9.37742e-07, 9.96674e-07]
time_average_classical = 4.065362923954936e-07

# N = 9, tau = 0.1, delta = 0.3
error_conservative_P3P3_macro_lowN_lowtau_delta03 =  [2.32024e-08, 6.58102e-08, 1.24949e-07, 9.23278e-08, 3.81933e-07, 1.58083e-07, 1.67057e-07, 1.82705e-07, 7.04937e-07, 5.62855e-07, 2.50152e-07, 4.59214e-07, 3.17909e-07, 5.61015e-07, 3.28466e-07, 1.34204e-06, 5.67698e-07, 3.92692e-07, 4.10006e-07, 8.0494e-07, 9.0217e-07, 4.68886e-07, 9.14842e-07, 7.12625e-07, 7.0192e-07, 5.31012e-07, 1.99069e-06, 1.60905e-06, 5.86358e-07, 6.50871e-07, 6.33077e-07, 1.22873e-06]


t = np.linspace(0, 0.5, 32)

# Conservative scheme
#fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
#fig.suptitle(r"Changing $\tau$", fontsize=26)

ax1.set_title(r"Full stabilization")
ax2.set_title(r"Macro stabilization")
ax1.plot(t, error_conservative_P3P3_fullstab_lowN_lowtau, marker='.', markersize=7, linestyle=":", color='black', label=r'$N_t=9$, $\tau = 0.1$')
ax1.plot(t, error_conservative_P3P3_fullstab_lowN_hightau, marker='p', markersize=5, linestyle=":", color='c', label=r'$N_t=9$, $\tau = 10$')
ax1.plot(t, error_conservative_P3P3_fullstab_highN_lowtau, marker='^', markersize=5, linestyle=":", color='C3', label=r'$N_t=20$, $\tau = 0.1$')
#ax2.plot(t, error_conservative_P3P3_fullstab_highN_hightau, marker='o',markersize=4, linestyle=":", color='C0', label=r'Large $N$, large $\tau$')
ax2.plot(t, error_conservative_P3P3_macro_lowN_lowtau_delta03, marker='.', markersize=7,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='black', label=r'$N_t=9$, $\tau=0.1$')
ax2.plot(t, error_conservative_P3P3_macro_lowN_tau10_delta03 ,marker='^', markersize=7,markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3', label=r'$N_t=9$, $\tau=10$')


#ax1.plot(t, time_average_lowN_lowtau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o',markersize=4, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C3')
#ax1.plot(t, time_average_lowN_hightau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o', markersize=4, linestyle=":", color='C3')
#ax2.plot(t, time_average_highN_lowtau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o',markersize=4, markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color='C0')
#ax2.plot(t, time_average_highN_hightau*np.ones(np.shape(error_conservative_P3P3_fullstab_lowN_lowtau)), marker='o', markersize=4, linestyle=":", color='C0')

#ax2.plot(t, error_classical_P3P3_fullstab_lowN_lowtau, marker='^', color="C2", linestyle="--")

ax1.set_xlabel(r"$t$")
ax2.set_xlabel(r"$t$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(t))}$")
# ax1.set_title(r"C")
ax1.set_ylim(-1e-7, 3.5e-6)
ax2.set_ylim(-1e-7, 3.5e-6)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()

fig.tight_layout()
fig.savefig("ex2_error_vs_t.pdf")

plt.show()

# %% [markdown]
# ### Fig 3: Conservation vs t

# %%
### Conservation error
# h=0.4, dt=5h/18, T=2, tau = 0.1, delta = 0.3

# N=3 in time and 3 in space
ec_conservative_macro = [3.33067e-16, 3.33067e-16, 7.77156e-16, 3.33067e-16, 1.77636e-15, 5.10703e-15, 5.9952e-15, 2.22045e-15, 2.88658e-15, 4.44089e-15, 5.77316e-15, 2.66454e-15, 3.21965e-15, 3.9968e-15, 6.55032e-15, 5.44009e-15, 5.44009e-15, 5.11738e-15]
ec_classical_macro = [3.84596e-07, 1.16032e-06, 1.37399e-06, 1.39905e-06, 1.7513e-06, 2.23703e-06, 1.29807e-06, 8.40889e-07, 3.4789e-06, 1.33206e-06, 6.93027e-06, 5.32098e-05, 9.02961e-05, 6.43315e-05, 6.27791e-05, 6.03108e-05, 5.96145e-05, 5.94398e-05]


# N=5 in time and 5 in space
ec_conservative_macro_P2P2 = [1.66533e-16, 4.996e-16, 2.44249e-15, 3.77476e-15, 3.33067e-16, 3.77476e-15, 2.22045e-16, 2.66454e-15, 4.44089e-16, 6.66134e-16, 1.33227e-15, 3.33067e-15, 4.44089e-16, 2.44249e-15, 8.88178e-16, 2.60902e-15, 2.41474e-15, 2.9989e-15]
ec_classical_macro_P2P2 =  [2.42378e-10, 9.59485e-11, 4.78378e-11, 5.99678e-10, 5.01666e-09, 4.85589e-09, 4.4289e-09, 6.14507e-09, 1.30423e-08, 5.07582e-09, 7.16684e-08, 1.37944e-06, 5.08322e-06, 2.5392e-06, 2.42654e-06, 2.34005e-06, 2.28994e-06, 2.27367e-06]

# N=9 in time and 9 in space
ec_conservative_macro_P3P3 = [3.72757e-14, 1.91513e-14, 1.19016e-13, 2.54796e-13, 3.80251e-13, 8.50431e-13, 1.08447e-12, 1.54787e-12, 1.64557e-12, 1.61271e-12, 2.43716e-12, 2.68008e-12, 3.2282e-12, 3.54838e-12, 3.22076e-12, 3.24735e-12, 3.52618e-12, 3.61005e-12]
ec_classical_macro_P3P3 = [4.86948e-11, 4.6475e-11, 4.64724e-11, 4.43329e-11, 2.20062e-10, 2.21123e-10, 2.21417e-10, 2.09399e-10, 6.52522e-10, 6.52623e-10, 6.61269e-10, 1.59764e-09, 3.59845e-08, 1.05272e-08, 9.88796e-09, 9.245e-09, 9.01002e-09, 8.93577e-09]

times = np.linspace(0,1,18)
#times = [0, 0.0333333, 0.0666667, 0.1, 0.133333, 0.166667, 0.2, 0.233333, 0.266667, 0.3, 0.333333, 0.366667, 0.4, 0.433333, 0.466667, 0.5, 0.533333, 0.566667, 0.6, 0.633333, 0.666667, 0.7, 0.733333, 0.766667, 0.8, 0.833333, 0.866667, 0.9, 0.933333, 0.966667]

fig, ax = plt.subplots(1, 1, figsize=(6, 5))

ax.semilogy([],[], linestyle="--", color="black",label=r"Non-conservative Scheme")
ax.semilogy([],[], linestyle=":", color="black", label=r"Conservative Scheme")
ax.semilogy([],[], linestyle="None", label=" ")
ax.semilogy([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax.semilogy([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax.semilogy([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
ax.semilogy([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full Stabilization")
ax.semilogy([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro Stabilization")
ax.semilogy(times, ec_conservative_macro, marker='o', markersize=5,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax.semilogy(times, ec_classical_macro,   marker='o', markersize=5,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax.semilogy(times, ec_conservative_macro_P2P2, marker='s', markersize=5,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax.semilogy(times, ec_classical_macro_P2P2,   marker='s', markersize=5,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax.semilogy(times, ec_conservative_macro_P3P3, marker='^', markersize=5,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3")
ax.semilogy(times, ec_classical_macro_P3P3,   marker='^', markersize=5,linestyle="--",  markeredgewidth=0.8, markerfacecolor="None", color="C3")
ax.semilogy([],[], linestyle="None", label=" ")
ax.tick_params(axis='both', which='major', labelsize=18)

handles, labels = [a for a in ax.get_legend_handles_labels()]
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)
#ax7.legend(handles=[Rey,III,circle],prop={'size': 18},frameon=False)
#ax7.legend(prop={'size': 18},frameon=False)
ax.set_xlabel(r"$t$", fontsize=20)
ax.set_ylabel(r"$e_c(t)$", fontsize=18)
#ax7.set_title(r"Classical scheme")
#plt.grid()
plt.tight_layout()
plt.show()
fig.savefig("ex2_conservation_vs_t.pdf")

# %% [markdown]
# ### Fig 4: Conservation vs h

# %%
# N = 3, T = 0.1, tau = 0.1
error_conservative_P1P1_macro = 
error_classical_P1P1_macro = 

# N = 5 space and time, T = 0.1, tau = 0.1
error_conservative_P2P2_macro = 
error_classical_P2P2_macro =

# N = 9 space and time, T = 0.1, tau = 0.1 
error_conservative_P3P3_macro =
error_classical_P3P3_macro =

h = [0.2, 0.1, 0.05, 0.025, 0.0125]
dt = [0.1, 0.03333333333333333, 0.01666666666666667, 0.008333333333333333, 0.004166666666666667]
ns_active_mesh = [8, 19, 51, 180, 639]

fig, ax = plt.subplots(1, 1, figsize=(7, 5))
#fig.suptitle("Conservative scheme", fontsize=26)
# ax.loglog(h, 5e-4*np.power(h, 2), linestyle="-", color="black")   
# ax.loglog(h, 7.5e-5*np.power(h, 3), linestyle="-", color="black")   
# ax.loglog(h, 1.6e-5*np.power(h, 6), linestyle="-", color="black")  

# ax.loglog(h, error_conservative_P1P1_fullstab, marker='o', markersize=9, linestyle=":", color="C2")
# ax.loglog(h, error_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
# ax.loglog(h, error_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C3")

ax.loglog(h, error_conservative_P1P1_macro, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax.loglog(h, error_conservative_P2P2_macro, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax.loglog(h, error_conservative_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")

# ax.loglog(h, error_classical_P1P1_fullstab, marker='o', markersize=9, linestyle="--", color="C2")
# ax.loglog(h, error_classical_P2P2_fullstab, marker='s', markersize=9, linestyle="--", color="C0")
# ax.loglog(h, error_classical_P3P3_fullstab, marker='^', markersize=9, linestyle="--", color="C3")

ax.loglog(h, error_classical_P1P1_macro, marker='o', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax.loglog(h, error_classical_P2P2_macro, marker='s', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax.loglog(h, error_classical_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")

#ax.loglog([],[], label=r"$\mathcal{O}(h^{k+1})$", linestyle="-", color="black")
ax.semilogy([],[], linestyle="--", color="black",label=r"Non-conservative scheme")
ax.semilogy([],[], linestyle=":", color="black", label=r"Conservative scheme")
ax.loglog([],[], linestyle="None", label=" ")
#ax.loglog([],[], linestyle="None", label=" ")
#ax.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$m=1, k=0$")
ax.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
#ax.loglog([],[], linestyle="None", label=" ")
#ax.loglog([],[], linestyle=(0, (5,7)), color="black",label=r"Non-conservative Scheme")
#ax.loglog([],[], linestyle=":", color="black", label=r"Conservative Scheme")
#ax.loglog([],[], linestyle="None", label=" ")
ax.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
#ax.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax.set_xlabel(r"$h$")
ax.tick_params(axis='both', which='major')
ax.set_ylabel(r"$e_c(T)$")
#ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax.grid()

#handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
#fig.savefig("ex2_conservation_vs_h.pdf")
plt.show()
