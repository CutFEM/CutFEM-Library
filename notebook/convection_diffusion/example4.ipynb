# %% [markdown]
# ### Dependencies

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.ticker import FormatStrFormatter
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

new_rc_paramas = {
    'text.usetex' : True,
    'figure.dpi' : 180,
    'text.latex.preamble' : r'\usepackage{libertine}'r'\usepackage{libertinust1math}',
    'font.family' : 'Linux Libertine',
    'axes.titlesize' : 22,
    'axes.labelsize' : 18,
    'xtick.labelsize' : 16,
    'ytick.labelsize' : 16,
    'xtick.direction' : 'in',
    'ytick.direction' : 'in',
    'xtick.top' : True,
    'ytick.right' : True,
    'legend.fontsize' : 'large',
    'axes.linewidth' : 1.2,
    'savefig.bbox' : 'tight',
    'image.aspect' : 'equal',
}

import matplotlib.pyplot as plt

mpl.rcParams.update(new_rc_paramas)

import numpy as np

def convergence_rate(errors, mesh_sizes):
    if len(errors) < 2 or len(mesh_sizes) < 2 or len(errors) != len(mesh_sizes):
        raise ValueError("At least two errors and mesh sizes are required.")

    # Take logarithm of errors and mesh sizes
    log_errors = np.log(errors)
    log_mesh_sizes = np.log(mesh_sizes)

    # Compute differences between consecutive elements
    delta_errors = np.diff(log_errors)
    delta_mesh_sizes = np.diff(log_mesh_sizes)

    # Compute convergence rate
    convergence_rates = delta_errors / delta_mesh_sizes

    return convergence_rates
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### $L^2$-Error vs $h$, $\Delta t_n \propto h$

# %%
# # N = 5, T = 0.5, tau = 0.05          (N = 7, T = 0.5, tau = 0.05)
# error_conservative_P1P1_fullstab =
# error_conservative_P1P1_fullstab_T =


# error_classical_P1P1_fullstab = 
# error_classical_P1P1_fullstab_T =

# #error_classical_P1P1_macro = 
# #error_conservative_P1P1_macro =

# N = 7 in space and time, tau = 0.1
error_conservative_P2P2_fullstab = [0.003661722251396929, 0.0004157331403973508, 4.557661769096709e-05, 5.456389317584864e-06, 6.744956685273418e-07]
error_conservative_P2P2_fullstab_T = [0.0006900876615609585, 7.872294105818729e-05, 8.414702564814634e-06, 1.00511657895516e-06, 1.241570029806028e-07]

error_classical_P2P2_fullstab = [0.00366171688171117, 0.0004157306504167714, 4.55769723219188e-05, 5.456389665036856e-06, 6.744842726410375e-07]
error_classical_P2P2_fullstab_T = [0.0006900894157750941, 7.872287023774213e-05, 8.414699274969319e-06, 1.005116216930911e-06, 1.241564740703128e-07]

# N = 9 in space and time, tau = 0.05   
error_conservative_P3P3_fullstab = [0.0779237, 0.0630368, 0.0320476, 0.00569697, 0.00019029, 1.00327e-05]
error_conservative_P3P3_fullstab_T = [0.0388657, 0.0364102, 0.0217731, 0.00308962, 9.67429e-05, 5.00926e-06]
nb_active_elements = [1, 2, 4, 14, 42, 141]

## redoing it with same mesh and parameters as ex 1
error_conservative_P3P3_fullstab =  [0.0007733267389085305, 3.944527193378036e-05, 2.095652114554757e-06, 1.111457987035771e-07, 6.154491864659668e-09]   
error_conservative_P3P3_fullstab_T = [0.0001650352827701687, 7.227773224579689e-06, 3.939654006352852e-07, 2.063042386049433e-08, 1.120181278635073e-09]
nb_active_elements = [19, 51, 180, 639, 2445]

## redoing it with N=14 in time and N=9 in space to see if it changes a bit
error_conservative_P3P3_fullstab = [0.0007733241274613985, 3.943489811023344e-05, 2.096374572096125e-06, 1.111464151213407e-07, 5.843888376366272e-09]
error_conservative_P3P3_fullstab_T = [0.0001650357023440617, 7.227861577019356e-06, 3.939606532976902e-07, 2.062137770184982e-08, 1.093318823618836e-09]

# 
error_conservative_P3P3_macro = [0.0002852242057050011, 1.958025693910464e-05, 1.453894763508361e-06, 8.202060172044111e-08, 5.609898685692824e-09]
error_conservative_P3P3_macro_T = [5.576456491247124e-05, 3.8232217863465e-06, 2.621200490365664e-07, 1.484690241897204e-08, 9.340986240820974e-10]

# classical macro running on ross screen
error_classical_P3P3_macro = [0.0002852254799354335, 1.956695991020238e-05, 1.454664695256517e-06, 8.201785586596275e-08, 4.809433979197614e-09]
error_classical_P3P3_macro_T = [5.576417773547609e-05, 3.823326616412731e-06, 2.621122182754157e-07, 1.481912727513621e-08, 8.774004891728859e-10]

error_classical_P3P3_fullstab = [0.0007733220487607762, 3.943828478499677e-05, 2.096311207235933e-06, 1.111473252553515e-07, 5.805804531330547e-09]
error_classical_P3P3_fullstab_T = [0.0001650350776441196, 7.227797472529099e-06, 3.939548302307005e-07, 2.062045356719164e-08, 1.091856055527401e-09]

h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

# h = [0.9, 0.45, 0.225, 0.1125, 0.05625, 0.028125, 0.0140625]
# dT = [0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625]


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))

ax1.loglog(h, 6.5*np.power(h, 2), linestyle="--", color="black")   
ax1.loglog(h, 1.5*np.power(h, 3), linestyle="--", color="black")   
ax1.loglog(h, 1.5*np.power(h, 4),label=r"$\mathcal{O}(h^{k+1})$", linestyle="--", color="black")   

# ax1.loglog(h, error_conservative_P1P1_fullstab, marker='o', markersize=9, linestyle=":", color="C3")
# ax1.loglog(h, error_classical_P1P1_fullstab, label= r"$k=m=1$", marker='o', markersize=9, linestyle="-", color="C3")

ax1.loglog(h, error_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
ax1.loglog(h, error_classical_P2P2_fullstab, label= r"$k=m=2$", marker='s', markersize=9, linestyle="-", color="C0")

ax1.loglog(h, error_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C2")
ax1.loglog(h, error_conservative_P3P3_macro, marker='^', markersize=9, linestyle="-", color="C2")

ax1.loglog(h, error_classical_P3P3_fullstab, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="C2")
ax1.loglog(h, error_classical_P3P3_macro, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="black")

#ax1.set_ylim(1e-4, 2)
#ax1.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$h$ (log)")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u(T)-u_h(T)\|_{L^2(\Omega(T))}$ (log)")
ax1.set_title(r"$\|e_h(T)\|_{L^2(\Omega(T))}$ vs $h$")
ax1.legend()
ax1.grid()

ax2.loglog(h, 6.5*np.power(h, 2), linestyle="--", color="black")   
ax2.loglog(h, 1.5*np.power(h, 3), linestyle="--", color="black")   
ax2.loglog(h, 1.5*np.power(h, 4),label=r"$\mathcal{O}(h^{k+1})$", linestyle="--", color="black")   

# ax2.loglog(h, error_conservative_P1P1_fullstab_T, marker='o', markersize=9, linestyle=":", color="C3")
# ax2.loglog(h, error_classical_P1P1_fullstab_T, label= r"$k=m=1$", marker='o', markersize=9, linestyle="-", color="C3")

ax2.loglog(h, error_conservative_P2P2_fullstab_T, marker='s', markersize=9, linestyle=":", color="C0")
ax2.loglog(h, error_classical_P2P2_fullstab_T, label= r"$k=m=2$", marker='s', markersize=9, linestyle="-", color="C0")

ax2.loglog(h, error_conservative_P3P3_fullstab_T, marker='^', markersize=9, linestyle=":", color="C2")
ax2.loglog(h, error_conservative_P3P3_macro_T, marker='^', markersize=9, linestyle=":", color="C2")

ax2.loglog(h, error_classical_P3P3_fullstab_T, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="C2")
ax2.loglog(h, error_classical_P3P3_macro_T, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="black")

ax2.set_xlabel(r"$h$ (log)")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"\Big($\int_0^T\|u(t)-u_h(t)\|^2_{L^2(\Omega(t))}dt\Big)^{\frac{1}{2}}$ (log)")
ax2.set_title(r"$\|e_h(T)\|_{L^2(L^2(\Omega(T)), 0, T)}$ vs $h$")
ax2.legend()
ax2.grid()
fig.tight_layout()
plt.show()

# %% [markdown]
# ### SUPG stabilization

# %%
# N = 9, T = 0.1, tau = 0.1, C = 0.01, tau = Ch^2/D
error_conservative_P1P1_fullstab_supg = [0.01441308241863339, 0.004382505929225502, 0.001152783763947432, 0.0002813440046461488, 6.885031853425374e-05]
error_conservative_P1P1_fullstab_T_supg = [0.002898526967319163, 0.0008397945902723725, 0.0002262159031695026, 5.692588479471846e-05, 1.413867802891474e-05]


# error_classical_P1P1_fullstab = 
# error_classical_P1P1_fullstab_T =

# #error_classical_P1P1_macro = 
# #error_conservative_P1P1_macro =

# N = 7 in time and N = 5 in time, tau = 0.1, C = 0.1
error_conservative_P2P2_fullstab_supg =  [0.007534708047667745, 0.003797095806668335, 0.0013553855735468, 0.0003931972477989363, 0.0001033169580704304]
error_conservative_P2P2_fullstab = [0.005679393214784688, 0.0005686962639261706, 5.072947976962038e-05, 5.618909552375272e-06, 6.79716924358323e-07]

# Ch^3/D
error_conservative_P2P2_fullstab_supg = [0.005221222580651568, 0.0005415320508619565, 5.603243775864756e-05, 7.135627354585082e-06, 9.16217259363095e-07]

# C = 0.01, tau_supg = Ch^2/D
#error_conservative_P2P2_fullstab_supg = ### mac    suboptimal



# error_classical_P2P2_fullstab = 
# error_classical_P2P2_fullstab_T = 

error_conservative_P3P3_fullstab = [0.0007733241274613985, 3.943489811023344e-05, 2.096374572096125e-06, 1.111464151213407e-07, 5.843888376366272e-09]
error_conservative_P3P3_fullstab_T = [0.0001650357023440617, 7.227861577019356e-06, 3.939606532976902e-07, 2.062137770184982e-08, 1.093318823618836e-09]

# Ch^3/D, C = 0.1
error_conservative_P3P3_fullstab_supg =  [0.00159577, 0.000274722] # not optimal
error_conservative_P3P3_fullstab_T_supg = [0.000193994, 1.75813e-05]

# Ch^4/D, C = 0.1
error_conservative_P3P3_fullstab_supg = ### mac (looked good but expected since we scale with h^4)
error_conservative_P3P3_fullstab_T_supg = ### mac (looked good)



# error_classical_P3P3_fullstab = 
# error_classical_P3P3_fullstab_T = 


nb_active_elements = [19, 51, 180, 639, 2445]
h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

# h = [0.9, 0.45, 0.225, 0.1125, 0.05625, 0.028125, 0.0140625]
# dT = [0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625]


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))

ax1.loglog(h, 6.5*np.power(h, 2), linestyle="--", color="black")   
ax1.loglog(h, 1.5*np.power(h, 3), linestyle="--", color="black")   
ax1.loglog(h, 1.5*np.power(h, 4),label=r"$\mathcal{O}(h^{k+1})$", linestyle="--", color="black")   

ax1.loglog(h, error_conservative_P1P1_fullstab_supg, marker='o', markersize=9, linestyle=":", color="C3")
# ax1.loglog(h, error_classical_P1P1_fullstab, label= r"$k=m=1$", marker='o', markersize=9, linestyle="-", color="C3")

ax1.loglog(h, error_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
ax1.loglog(h, error_conservative_P2P2_fullstab_supg, marker='s', markersize=9, linestyle=":", color="black")
#ax1.loglog(h, error_classical_P2P2_fullstab, label= r"$k=m=2$", marker='s', markersize=9, linestyle="-", color="C0")

#ax1.loglog(h, error_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C2")
#ax1.loglog(h, error_classical_P3P3_fullstab, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="C2")

#ax1.set_ylim(1e-4, 2)
#ax1.set_yticks([1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$h$ (log)")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u(T)-u_h(T)\|_{L^2(\Omega(T))}$ (log)")
ax1.set_title(r"$\|e_h(T)\|_{L^2(\Omega(T))}$ vs $h$")
ax1.legend()
ax1.grid()

ax2.loglog(h, 6.5*np.power(h, 2), linestyle="--", color="black")   
ax2.loglog(h, 1.5*np.power(h, 3), linestyle="--", color="black")   
ax2.loglog(h, 1.5*np.power(h, 4),label=r"$\mathcal{O}(h^{k+1})$", linestyle="--", color="black")   

ax2.loglog(h, error_conservative_P1P1_fullstab_T_supg, marker='o', markersize=9, linestyle=":", color="C3")
# ax2.loglog(h, error_classical_P1P1_fullstab_T, label= r"$k=m=1$", marker='o', markersize=9, linestyle="-", color="C3")

ax2.loglog(h, error_conservative_P2P2_fullstab_T, marker='s', markersize=9, linestyle=":", color="C0")
ax2.loglog(h, error_classical_P2P2_fullstab_T, label= r"$k=m=2$", marker='s', markersize=9, linestyle="-", color="C0")

ax2.loglog(h, error_conservative_P3P3_fullstab_T, marker='^', markersize=9, linestyle=":", color="C2")
ax2.loglog(h, error_classical_P3P3_fullstab_T, label= r"$k=m=3$", marker='^', markersize=9, linestyle="-", color="C2")

ax2.set_xlabel(r"$h$ (log)")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"\Big($\int_0^T\|u(t)-u_h(t)\|^2_{L^2(\Omega(t))}dt\Big)^{\frac{1}{2}}$ (log)")
ax2.set_title(r"$\|e_h(T)\|_{L^2(L^2(\Omega(T)), 0, T)}$ vs $h$")
ax2.legend()
ax2.grid()
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Fig 1 (error and condition number vs tau)

# %%
# h = 0.01, lobatto n = 3, T = 0.1, dT = h/3

# full stab
error_conservative_fullstab = [0.01374909338694775, 0.02028087511452978, 0.05071426967937235, 0.1211660436540989, 0.1246424477383307, 0.1246785938972344]
cond_conservative_fullstab = [3.322068e+04, 1.9759e+03, 8.0674e+04, 7.8635e+06, 7.8611e+08, 7.8611e+10]
nnz_fullstab = 10476

# macro, delta = 0.5
error_conservative_macro = [0.01370219242379861, 0.01695036425405704, 0.01984859712296505, 0.01992700885676314, 0.01992780956253752, 0.01992782592818599]
cond_conservative_macro = [5.2143e+04, 3.9790e+03, 1.8324e+05, 1.8220e+07, 1.8219e+09, 1.8219e+11]
nnz_macro = 8148

tau = [1e-2, 1e0, 1e2, 1e4, 1e6, 1e8]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
ax1.loglog(tau, error_conservative_fullstab, marker='o', markersize=9,linestyle=":", color="C2")
ax1.loglog(tau, error_conservative_macro,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax1.set_xlabel(r"$\tau$", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$", fontsize=18)

ax2.loglog(tau, cond_conservative_fullstab, marker='o', markersize=9, linestyle=":", color="C2")
ax2.loglog(tau, cond_conservative_macro,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax2.loglog(tau, tau,  marker='None', linestyle="None")
ax2.loglog([],[], linestyle=":",  marker='o', markersize=9, color="C2", label=r"Full Stabilization")
ax2.loglog([],[], linestyle=":",  marker='o', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Macro Stabilization")
ax2.set_xlabel(r"$\tau$", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"Condition number", fontsize=18)
ax2.set_ylim(1e2, 1e13)
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower center', ncols=4, bbox_to_anchor=(0.5, -0.1), fontsize=18, frameon=False)
plt.tight_layout()
plt.show()
fig.savefig("tau.pdf")

# %% [markdown]
# ### Fig 2 (Error, condition number and nnz vs macro-element parameter $\delta$.)

# %%
# h = 0.05
# tau = 0.1
# T = 0.5

error_conservative_macro = [0.01393203831042351, 0.01403133357947935, 0.01438852983149721, 0.01434730601212494, 0.01483255520932963]
cond_conservative_macro = [7.6526e+03, 7.7731e+03, 6.6442e+03, 6.651073e+03, 5.4599e+03]
nnz_macro = [7548, 7812, 8148, 8412, 8916]

delta = [0.1, 0.3, 0.5, 0.7, 0.9]

error_conservative_fullstab = 0.01484810715616916*np.ones(np.size(error_conservative_macro))
cond_conservative_fullstab = 3.7445e+03*np.ones(np.size(error_conservative_macro))
nnz_fullstab = 10476*np.ones(np.size(error_conservative_macro))

# vs delta

# tau = 1
error_conservative_macro = [0.0148875585318452, 0.01535306177018599, 0.01695036425405704, 0.01679887121241459, 0.0194834195579471]
cond_conservative_macro = [7.6799e+03, 7.4708e+03, 3.9790e+03, 3.9891e+03, 3.3071e+03]

error_conservative_fullstab = 0.02028087511452978*np.ones(np.size(error_conservative_macro))
cond_conservative_fullstab = 1.9759e+03*np.ones(np.size(error_conservative_macro))

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 3.5))
ax1.semilogy(delta, error_conservative_fullstab, marker='o', markersize=9,linestyle=":", color="C2")
ax1.semilogy(delta, error_conservative_macro,  marker='o', markersize=9, linestyle=":",  markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax1.set_xlabel(r"$\delta$", fontsize=18)
lbs = ['0.1', '0.3', '0.5', '0.7', '0.9']
ylbs = ['0.014', '0.017', '0.02']
ax1.set_xticks(delta)
ax1.set_xticklabels(lbs)
#ax1.set_yticks(error_conservative_macro)
#ax1.set_yticklabels(['0.014', '0.017', '0.021'])
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$", fontsize=18)
ax1.set_ylim(1.4e-2, 2.1e-2)
#ax1.grid()
#ax1.set_yticklabels(ylbs)
#ax1.set_yticks(np.arange(len(ylbs)), labels=ylbs)

ax2.semilogy(delta, cond_conservative_fullstab, marker='o', markersize=9,linestyle=":", color="C2")
ax2.semilogy(delta, cond_conservative_macro,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
#ax2.semilogy(delta, delta,  marker='None', linestyle="None")
ax2.semilogy([],[], marker='o', markersize=9,linestyle=":", color="C2", label=r"Full Stabilization")
ax2.semilogy([],[], linestyle=":",  marker='o', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Macro Stabilization")
ax2.set_xlabel(r"$\delta$", fontsize=18)
ax2.set_ylim(1e3, 1e4)
ax2.set_xticks(delta)
ax2.set_xticklabels(lbs)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"Condition number", fontsize=18)
#ax2.set_ylim(1e2, 1e13)
#ax2.grid()

ax3.semilogy(delta, nnz_fullstab, marker='o', markersize=9,linestyle=":", color="C2")
ax3.semilogy(delta, nnz_macro,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax3.set_xlabel(r"$\delta$", fontsize=18)
ax3.set_ylim(7e3, 1.1e4)
ax3.set_xticks(delta)
ax3.set_xticklabels(lbs)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"nnz", fontsize=18)
#ax3.set_ylim(7e4, 9e4)
#ax3.grid()

handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower center', ncols=4, bbox_to_anchor=(0.5, -0.2), fontsize=24, frameon=False)
plt.tight_layout()
plt.show()
fig.savefig("delta.pdf")

# %% [markdown]
# ### Fig 3 & 4 (L2 error vs h, $\Delta t\propto h$)

# %%
# N = 3, T = 0.1, tau = 0.1
error_conservative_P1P1_fullstab = [0.01478231459813854, 0.004584507143848305, 0.001232770488421235, 0.0003072697147647453, 7.637178750569465e-05]
error_conservative_P1P1_fullstab_T = [0.002911706800682409, 0.0008429388564984161, 0.0002266723366432542, 5.696941271241575e-05, 1.41378586570234e-05]
cond_conservative_P1P1_fullstab = [3.666556e+03,3.417327e+03,2.717351e+03,2.631912e+03,2.698476e+03]
cond_conservative_P1P1_fullstab = [1.034829e+04,9.622791e+03,8.246727e+03,8.662026e+03,1.049645e+04]    # condest

error_conservative_P1P1_macro = [0.01419680842893955, 0.004308247322845774, 0.001178738050516635, 0.0002974305588951472, 7.513361202660758e-05]
error_conservative_P1P1_macro_T = [0.002786493576364393, 0.0007966512310471381, 0.000216242003025269, 5.519576660902119e-05, 1.389805500071881e-05]
cond_conservative_P1P1_macro = [5.102171e+03,5.984966e+03,7.101262e+03,7.173139e+03,9.191115e+03]
cond_conservative_P1P1_macro = [1.459951e+04,1.552434e+04,1.854831e+04,1.897201e+04,2.488507e+04]       # condest

# N = 5 space and time, T = 0.1, tau = 0.1
error_conservative_P2P2_fullstab = [0.003661649892366458, 0.0004157426986583834, 4.557753289307536e-05, 5.456395647878288e-06, 6.74572242305911e-07]
error_conservative_P2P2_fullstab_T = [0.0006900731355038032, 7.872291876772556e-05, 8.414717573646344e-06, 1.005122380689424e-06, 1.241626736071863e-07]
cond_conservative_P2P2_fullstab = [3.078390e+06,2.669940e+06,2.989109e+06,2.670744e+06,2.895928e+06] 
cond_conservative_P2P2_fullstab = [1.604917e+07,1.201281e+07,1.286484e+07,1.167238e+07,1.432510e+07]    # condest

error_conservative_P2P2_macro = [0.003044126485008009, 0.0003445106266658112, 4.304428256363866e-05, 5.368458779372457e-06, 6.709745805268017e-07]
error_conservative_P2P2_macro_T = [0.0005515504228810702, 6.364347694403665e-05, 7.927152308373696e-06, 9.875102400857908e-07, 1.234535064365488e-07]
cond_conservative_P2P2_macro = [8.640299e+06,1.346417e+07,2.220411e+07,1.907610e+07,2.932035e+07]
cond_conservative_P2P2_macro = [3.097655e+07,5.274193e+07,9.081671e+07,7.062570e+07,1.015531e+08]   # condest

# N = 9 space and time, T = 0.1, tau = 0.1 
error_conservative_P3P3_macro = [0.0003286145789864599, 2.317873857585272e-05, 1.652329234666599e-06, 9.131111607067583e-08, 5.198268324382907e-09]
error_conservative_P3P3_macro_T = [6.470636199645798e-05, 5.083436066447569e-06, 3.072080409759252e-07, 1.642726137683071e-08, 9.416086748263895e-10]
cond_conservative_P3P3_macro = [5.533763e+12,5.972447e+12,3.736875e+13,2.877701e+13,5.377952e+13]



nb_active_elements = [19, 51, 180, 639, 2445]
h = [0.1, 0.05, 0.025, 0.0125, 0.00625]
dt = [0.03333333333333333, 0.01666666666666667, 0.008333333333333333, 0.004166666666666667, 0.002083333333333333]

# Conservative scheme
#fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle("Conservative scheme", fontsize=26)
ax1.loglog(h, 6.5*np.power(h, 2), linestyle="-", color="black")   
ax1.loglog(h, 7.5*np.power(h, 3), linestyle="-", color="black")   
ax1.loglog(h, 1.6e1*np.power(h, 4), linestyle="-", color="black")   

ax1.loglog(h, error_conservative_P1P1_fullstab, marker='o', markersize=9, linestyle=":", color="C2")
ax1.loglog(h, error_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
ax1.loglog(h, error_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C3")

ax1.loglog(h, error_conservative_P1P1_macro, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax1.loglog(h, error_conservative_P2P2_macro, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax1.loglog(h, error_conservative_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")


#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$h$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(T))}$")
#ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax1.grid()



ax2.loglog([],[], label=r"$\mathcal{O}(h^{k+1})$", linestyle="-", color="black")
ax2.loglog([],[], label=r"$\mathcal{O}(h^{-2})$", linestyle="-.", color="black")
ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$m=1, k=0$")
ax2.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax2.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax2.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
#ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle=(0, (5,7)), color="black",label=r"Non-conservative Scheme")
#ax2.loglog([],[], linestyle=":", color="black", label=r"Conservative Scheme")
#ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

# ax2.loglog(h, 6.5*np.power(h, 2), linestyle="-", color="black")   
# ax2.loglog(h, 1.5*np.power(h, 3), linestyle="-", color="black")  
# ax2.loglog(h, 1.5*np.power(h, 4), linestyle="-", color="black")  

# ax2.loglog(h, error_conservative_P1P1_fullstab_T, marker='o', markersize=9, linestyle=":", color="C2")
# ax2.loglog(h, error_conservative_P2P2_fullstab_T, marker='s', markersize=9, linestyle=":", color="C0")
# ax2.loglog(h, error_conservative_P3P3_fullstab_T, marker='^', markersize=9, linestyle=":", color="C3")

# ax2.loglog(h, error_conservative_P1P1_macro_T, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
# ax2.loglog(h, error_conservative_P2P2_macro_T, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
# ax2.loglog(h, error_conservative_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")

# ax2.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
# ax2.set_xlabel(r"$h$")
# ax2.tick_params(axis='both', which='major')
# ax2.set_ylabel(r"$\|u_h-u\|_{L^2(L^2(\Omega(t)), 0, T)}$ (log)")
# #ax2.set_title(r"Conservative scheme")
# #ax2.legend()
ax2.grid()

ax2.loglog(h, 5e10*np.power(h, -2), linestyle='-.', color="black")
ax2.loglog(h, cond_conservative_P1P1_fullstab, marker='o', markersize=9, linestyle=":", color="C2")
ax2.loglog(h, cond_conservative_P1P1_macro, marker='o', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C2")
ax2.loglog(h, cond_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
ax2.loglog(h, cond_conservative_P2P2_macro, marker='s', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C0")
ax2.loglog(h, cond_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C3")
ax2.loglog(h, cond_conservative_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")
ax2.set_ylabel(r"Condition number")

#handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
fig.savefig("ex1_conservative.pdf")
plt.show()

# %%
# N = 3, T = 0.1, tau = 0.1
error_classical_P1P1_fullstab = [0.01478107879815117, 0.004583985587342613, 0.001232794377537122, 0.0003072690878593782, 7.637138727607397e-05]
error_classical_P1P1_fullstab_T = [0.002911772543995446, 0.0008429210596088035, 0.0002266708077503673, 5.696926736614751e-05, 1.413781989995621e-05]
cond_classical_P1P1_fullstab = [3.665690e+03,3.417156e+03,2.718471e+03,2.632032e+03,2.698708e+03]
cond_classical_P1P1_fullstab = [1.036305e+04,9.621933e+03,8.250896e+03,8.660962e+03,1.049815e+04]   # condest

error_classical_P1P1_macro = [0.01419575461227519, 0.004307574257403844, 0.00117876732853406, 0.0002974299359696547, 7.513319446357158e-05]
error_classical_P1P1_macro = [0.01527579169177289, 0.004732543614709416, 0.001309566521252538, 0.0003155824952884997, 7.775615254200689e-05]
error_classical_P1P1_macro_T = [0.003013452618240267, 0.0008885928651715513, 0.0002400809938591215, 5.843348138255627e-05, 1.434611834710408e-05]
cond_classical_P1P1_macro = [9.115885e+03,1.033628e+04,1.309221e+04,1.354321e+04,1.773129e+04]

error_classical_P2P2_fullstab = [0.009466817296278591, 0.0009800604751164167, 8.260429890172787e-05, 7.142089371026179e-06, 7.54337404405622e-07]
error_classical_P2P2_fullstab_T = [0.001849047127835454, 0.0002048480986910321, 1.548825751706679e-05, 1.350317366139168e-06, 1.407996213479325e-07]
cond_classical_P2P2_fullstab = [2.370899e+07,1.741912e+07,2.014817e+07,2.889073e+07,2.584181e+07]

error_classical_P2P2_macro = [0.005035074904254212, 0.0004490660197432296, 4.770928390790985e-05, 5.581923452942685e-06, 6.824240123794086e-07]
error_classical_P2P2_macro_T = [0.0008744643262581655, 8.265343076488971e-05, 8.808708132004626e-06, 1.025217196016359e-06, 1.255284631575392e-07]
cond_classical_P2P2_macro = [1.020894e+08,1.061056e+08,3.282848e+08,2.577960e+08,3.797654e+08]

error_classical_P3P3_fullstab = [0.001607805693900732, 7.523922839838919e-05, 3.508187884615816e-06, 1.701266798751057e-07, 8.077917317173492e-09]
error_classical_P3P3_fullstab_T = [0.0003591406797695414, 1.40052440097501e-05, 6.644504754774897e-07, 3.276332670643885e-08, 1.590760546416569e-09]
cond_classical_P3P3_fullstab = [2.696430e+11,2.758266e+11,2.981213e+11,1.156706e+12,5.810620e+11]

error_classical_P3P3_macro = [0.0003286153884423253, 2.317320704557577e-05, 1.652513962463271e-06, 9.13104080197594e-08, 5.162789462215603e-09]
error_classical_P3P3_macro_T = [6.470631216230719e-05, 5.083461211850269e-06, 3.072073556377345e-07, 1.642518645536902e-08, 9.385009051350931e-10]
cond_classical_P3P3_macro = [5.533759e+12,5.972444e+12,3.736881e+13,2.877697e+13,5.377945e+13]   # condest matlab


nb_active_elements = [19, 51, 180, 639, 2445]
h = [0.1, 0.05, 0.025, 0.0125, 0.00625]
dt = [0.03333333333333333, 0.01666666666666667, 0.008333333333333333, 0.004166666666666667, 0.002083333333333333]

# Conservative scheme
#fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle("Non-conservative scheme", fontsize=26)
ax1.loglog(h, 6.5*np.power(h, 2), linestyle="-", color="black")   
ax1.loglog(h, 7.5*np.power(h, 3), linestyle="-", color="black")   
ax1.loglog(h, 1.6e1*np.power(h, 4), linestyle="-", color="black")  

ax1.loglog(h, error_classical_P1P1_fullstab, marker='o', markersize=9, linestyle="--", color="C2")
ax1.loglog(h, error_classical_P2P2_fullstab, marker='s', markersize=9, linestyle="--", color="C0")
ax1.loglog(h, error_classical_P3P3_fullstab, marker='^', markersize=9, linestyle="--", color="C3")

ax1.loglog(h, error_classical_P1P1_macro, marker='o', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax1.loglog(h, error_classical_P2P2_macro, marker='s', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax1.loglog(h, error_classical_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")


#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$h$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(T))}$")
#ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax1.grid()

ax2.loglog([],[], label=r"$\mathcal{O}(h^{k+1})$", linestyle="-", color="black")
ax2.loglog([],[], label=r"$\mathcal{O}(h^{-2})$", linestyle="-.", color="black")
ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$m=1, k=0$")
ax2.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax2.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax2.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
#ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle=(0, (5,7)), color="black",label=r"Non-conservative Scheme")
#ax2.loglog([],[], linestyle=":", color="black", label=r"Conservative Scheme")
#ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

# ax2.loglog(h, 6.5*np.power(h, 2), linestyle="-", color="black")   
# ax2.loglog(h, 1.5*np.power(h, 3), linestyle="-", color="black")  
# ax2.loglog(h, 1.5*np.power(h, 4), linestyle="-", color="black")  

# ax2.loglog(h, error_classical_P1P1_fullstab_T, marker='o', markersize=9, linestyle="--", color="C2")
# ax2.loglog(h, error_classical_P2P2_fullstab_T, marker='s', markersize=9, linestyle="--", color="C0")
# ax2.loglog(h, error_classical_P3P3_fullstab_T, marker='^', markersize=9, linestyle="--", color="C3")

# ax2.loglog(h, error_classical_P1P1_macro_T, marker='o', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
# ax2.loglog(h, error_classical_P2P2_macro_T, marker='s', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
# ax2.loglog(h, error_classical_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")

# ax2.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
# ax2.set_xlabel(r"$h$")
# ax2.tick_params(axis='both', which='major')
# ax2.set_ylabel(r"$\|e_h\|_{L^2(L^2(\Omega(t)), 0, T)}$ (log)")
# #ax2.set_title(r"Conservative scheme")
# #ax2.legend()
ax2.grid()

ax2.loglog(h, 5e10*np.power(h, -2), linestyle='-.', color="black")
ax2.loglog(h, cond_classical_P1P1_fullstab, marker='o', markersize=9, linestyle="--", color="C2")
ax2.loglog(h, cond_classical_P1P1_macro, marker='o', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C2")
ax2.loglog(h, cond_classical_P2P2_fullstab, marker='s', markersize=9, linestyle="--", color="C0")
ax2.loglog(h, cond_classical_P2P2_macro, marker='s', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C0")
ax2.loglog(h, cond_classical_P3P3_fullstab, marker='^', markersize=9, linestyle="--", color="C3")
ax2.loglog(h, cond_classical_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")

ax2.set_ylabel(r"Condition number")
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
fig.savefig("ex1_classical.pdf")
plt.show()

# %% [markdown]
# ### Fig 5 & 6 (L2 error vs $\Delta t$)

# %%
# # N = 3, T = 0.1, tau = 0.1

# # h = 0.05
# error_conservative_P1P1_fullstab = [0.01099740667466852, 0.004843456742970172, 0.004505514218185881, 0.004617305899005452, 0.004610606735937283]
# error_conservative_P1P1_fullstab_T = [0.002848916121380614, 0.001150745741146911, 0.0008637351875444198, 0.0008362211441558564, 0.0008318432424380853]

# error_conservative_P1P1_macro = [0.01080907381212882, 0.004637588310415898, 0.004218319521091085, 0.004344111511083415, 0.004368349093710602]
# error_conservative_P1P1_macro_T = [0.002836994857373457, 0.001134089402322757, 0.0008239481411338265, 0.0007925630975870264, 0.0007861042236641225]

# error_conservative_P2P2_fullstab = [0.002258632221253671, 0.0004489373321680597, 0.0004104237854823215, 0.0004166735443270838, 0.000409592565988039]
# error_conservative_P2P2_fullstab_T = [0.0003840081510253496, 9.853462124860278e-05, 7.90910728765844e-05, 7.799712716880637e-05, 7.718637658927503e-05]


# # h = 0.01
# error_conservative_P1P1_fullstab = [0.01000145065516267, 0.00236242396656852, 0.0005033361832854627, 0.0001804290344868673, 0.000189877242440273]
# error_conservative_P1P1_fullstab_T = [0.002791675497926007, 0.0007916634312521905, 0.0002154637944559358, 6.7019993902202e-05, 3.918912890392832e-05]

# # delta = 0.5
# error_conservative_P1P1_macro = [0.01000097287117225, 0.002363217210512905, 0.0005059168646748713, 0.0001780127170349956, 0.0001855690757376462]
# error_conservative_P1P1_macro_T = [0.002792404681335729, 0.0007916571753969656, 0.0002152983434773993, 6.647898363252176e-05, 3.826858262873804e-05]

# Conservative scheme
#fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle("Conservative scheme", fontsize=26)
ax1.loglog(dt, 7.5e-1*np.power(dt, 2), linestyle="-", color="black")   
ax1.loglog(dt, 9.7e-1*np.power(dt, 3), linestyle="-", color="black")   
ax1.loglog(dt, 1.5e-0*np.power(dt, 4), linestyle="-", color="black")  

ax1.loglog(dt, error_conservative_P1P1_fullstab, marker='o', markersize=9, linestyle=":", color="C2")
ax1.loglog(dt, error_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
ax1.loglog(dt, error_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C3")

ax1.loglog(dt, error_conservative_P1P1_macro, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax1.loglog(dt, error_conservative_P2P2_macro, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax1.loglog(dt, error_conservative_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")


#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$\Delta t_n$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(T))}$")
#ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax1.grid()



ax2.loglog([],[], label=r"$\mathcal{O}(\Delta t_n^{k+1})$", linestyle="-", color="black")
ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$m=1, k=0$")
ax2.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax2.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax2.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
#ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle=(0, (5,7)), color="black",label=r"Non-conservative Scheme")
#ax2.loglog([],[], linestyle=":", color="black", label=r"Conservative Scheme")
#ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

ax2.loglog(dt, 7.5e-1*np.power(dt, 2), linestyle="-", color="black")   
ax2.loglog(dt, 9.7e-1*np.power(dt, 3), linestyle="-", color="black")   
ax2.loglog(dt, 1.5e-0*np.power(dt, 4), linestyle="-", color="black")  

ax2.loglog(dt, error_conservative_P1P1_fullstab_T, marker='o', markersize=9, linestyle=":", color="C2")
ax2.loglog(dt, error_conservative_P2P2_fullstab_T, marker='s', markersize=9, linestyle=":", color="C0")
ax2.loglog(dt, error_conservative_P3P3_fullstab_T, marker='^', markersize=9, linestyle=":", color="C3")

ax2.loglog(dt, error_conservative_P1P1_macro_T, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax2.loglog(dt, error_conservative_P2P2_macro_T, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax2.loglog(dt, error_conservative_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")

ax2.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax2.set_xlabel(r"$\Delta t_n$")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"$\|u_h-u\|_{L^2(L^2(\Omega(t)), 0, T)}$")
#ax2.set_title(r"Conservative scheme")
#ax2.legend()
ax2.grid()

#handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
fig.savefig("ex1_conservative_dt.pdf")
plt.show()

# %%
# # N = 3, T = 0.1, tau = 0.1

# # h = 0.05
# error_classical_P1P1_fullstab = [0.01106055778399646, 0.004844427407055414, 0.004504549467233983, 0.004617208388257401, 0.004610606112270191]
# error_classical_P1P1_fullstab_T = [0.002846069105086777, 0.001150478269684369, 0.0008637027937015753, 0.000836224453413337, 0.0008318426269552548]

# # h = 0.01
# error_classical_P1P1_fullstab = [0.01014546474522648, 0.002383193565830155, 0.0005032751264260043, 0.0001803013930018851, 0.0001898738080294157]
# error_classical_P1P1_fullstab_T = [0.002780885203390571, 0.0007908514794964156, 0.0002153899379840488, 6.701253634051477e-05, 3.91882074751412e-05]

# # h = 0.05
# error_classical_P1P1_macro = [0.01086944345183625, 0.004637935051008573, 0.004216969964335182, 0.004344036113753419, 0.004368360749331153]
# error_classical_P1P1_macro_T = [0.002834070245759348, 0.001133730637152302, 0.000823910446631597, 0.0007925691908227258, 0.0007861034607778639]

# # h = 0.01
# error_classical_P1P1_macro = [0.01014473733728456, 0.002383751075844734, 0.0005058872409153137, 0.0001778464803776839, 0.0001855643568384113]
# error_classical_P1P1_macro_T = [0.002781448089146915, 0.0007908437551926771, 0.0002152260942708448, 6.647089215177817e-05, 3.826783807577211e-05]

# # N = 5 space and time, T = 0.1, tau = 0.1
ig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 5))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))
fig.suptitle("Non-conservative scheme", fontsize=26)

ax1.loglog(dt, 7.5e-1*np.power(dt, 2), linestyle="-", color="black")   
ax1.loglog(dt, 9.7e-1*np.power(dt, 3), linestyle="-", color="black")   
ax1.loglog(dt, 1.5e-0*np.power(dt, 4), linestyle="-", color="black")  

ax1.loglog(dt, error_classical_P1P1_fullstab, marker='o', markersize=9, linestyle="--", color="C2")
ax1.loglog(dt, error_classical_P2P2_fullstab, marker='s', markersize=9, linestyle="--", color="C0")
ax1.loglog(dt, error_classical_P3P3_fullstab, marker='^', markersize=9, linestyle="--", color="C3")

ax1.loglog(dt, error_classical_P1P1_macro, marker='o', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax1.loglog(dt, error_classical_P2P2_macro, marker='s', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax1.loglog(dt, error_classical_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")


#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
ax1.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax1.set_xlabel(r"$\Delta t_n$")
ax1.tick_params(axis='both', which='major')
ax1.set_ylabel(r"$\|u_h-u\|_{L^2(\Omega(T))}$")
#ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax1.grid()

ax2.loglog([],[], label=r"$\mathcal{O}(\Delta t_n^{k+1})$", linestyle="-", color="black")
ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$m=1, k=0$")
ax2.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax2.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax2.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
#ax2.loglog([],[], linestyle="None", label=" ")
#ax2.loglog([],[], linestyle=(0, (5,7)), color="black",label=r"Non-conservative Scheme")
#ax2.loglog([],[], linestyle=":", color="black", label=r"Conservative Scheme")
#ax2.loglog([],[], linestyle="None", label=" ")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax2.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

ax2.loglog(dt, 7.5e-1*np.power(dt, 2), linestyle="-", color="black")   
ax2.loglog(dt, 9.7e-1*np.power(dt, 3), linestyle="-", color="black")   
ax2.loglog(dt, 1.5e-0*np.power(dt, 4), linestyle="-", color="black")  

ax2.loglog(dt, error_classical_P1P1_fullstab_T, marker='o', markersize=9, linestyle="--", color="C2")
ax2.loglog(dt, error_classical_P2P2_fullstab_T, marker='s', markersize=9, linestyle="--", color="C0")
ax2.loglog(dt, error_classical_P3P3_fullstab_T, marker='^', markersize=9, linestyle="--", color="C3")

ax2.loglog(dt, error_classical_P1P1_macro_T, marker='o', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax2.loglog(dt, error_classical_P2P2_macro_T, marker='s', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax2.loglog(dt, error_classical_P3P3_macro_T, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")

ax2.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax2.set_xlabel(r"$\Delta t_n$")
ax2.tick_params(axis='both', which='major')
ax2.set_ylabel(r"$\|u_h-u\|_{L^2(L^2(\Omega(t)), 0, T)}$")
#ax2.set_title(r"Conservative scheme")
#ax2.legend()
ax2.grid()

#handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
handles, labels = [(a + b) for a, b in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels())]
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
fig.savefig("ex1_classical_dt.pdf")
plt.show()
# Out:
# /usr/lib/python3/dist-packages/numpy/ma/core.py:6717: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %% [markdown]
# ### Fig 7 (Conservation error vs time)

# %%
### Conservation error
# h=0.1, dt=h/3, T=1

# N=3 in time and 5 in space
],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full Stabilization")
ax7.semilogy([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro Stabilization")

ax7.semilogy(times, ec_conservative_fullstab, marker='o', markersize=5,linestyle=":", color="C2")
ax7.semilogy(times, ec_conservative_macro, marker='o', markersize=5,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax7.semilogy(times, ec_classical_fullstab,   marker='o', markersize=5,linestyle="--", color="C2")
ax7.semilogy(times, ec_classical_macro,   marker='o', markersize=5,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")

ax7.semilogy(times, ec_conservative_fullstab_P2P2, marker='s', markersize=5,linestyle=":", color="C0")
ax7.semilogy(times, ec_conservative_macro_P2P2, marker='s', markersize=5,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax7.semilogy(times, ec_classical_fullstab_P2P2,   marker='s', markersize=5,linestyle="--", color="C0")
ax7.semilogy(times, ec_classical_macro_P2P2,   marker='s', markersize=5,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")

ax7.semilogy(times, ec_conservative_fullstab_P3P3, marker='^', markersize=5,linestyle=":", color="C3")
ax7.semilogy(times, ec_conservative_macro_P3P3, marker='^', markersize=5,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3")
ax7.semilogy(times, ec_classical_fullstab_P3P3,   marker='^', markersize=5,linestyle="--", color="C3")
ax7.semilogy(times, ec_classical_macro_P3P3,   marker='^', markersize=5,linestyle="--",  markeredgewidth=0.8, markerfacecolor="None", color="C3")

ax7.semilogy([],[], linestyle="None", label=" ")
ax7.tick_params(axis='both', which='major', labelsize=18)

# ax8.semilogy(times[1:], nnz_conservative_fullstab_P0P1[1:], marker='^', markersize=5,linestyle=":", color="C0")
# ax8.semilogy(times[1:], nnz_conservative_macro_P0P1[1:], marker='^', markersize=5,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
# ax8.semilogy(times[1:], nnz_classical_fullstab_P0P1[1:],   marker='^', markersize=5,linestyle=(0, (5,7)), color="C0")
# ax8.semilogy(times[1:], nnz_classical_macro_P0P1[1:],   marker='^', markersize=5,linestyle=(0, (5,7)),  markeredgewidth=0.8, markerfacecolor="None", color="C0")

ax8.semilogy(times, nnz_conservative_fullstab, marker='o', markersize=5,linestyle="None", color="C2")
ax8.semilogy(times, nnz_conservative_macro, marker='o', markersize=5,linestyle="None", markeredgewidth=0.8, markerfacecolor="None", color="C2")
# ax8.semilogy(times[1:], nnz_classical_fullstab[1:],   marker='o', markersize=5,linestyle=(0, (5,7)), color="C2")
# ax8.semilogy(times[1:], nnz_classical_macro[1:],   marker='o', markersize=5,linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C2")

ax8.semilogy(times, nnz_conservative_fullstab_P2P2, marker='s', markersize=5,linestyle="None", color="C0")
ax8.semilogy(times, nnz_conservative_macro_P2P2, marker='s', markersize=5,linestyle="None", markeredgewidth=0.8, markerfacecolor="None", color="C0")
# ax8.semilogy(times[1:], nnz_classical_fullstab_P2P2[1:],   marker='s', markersize=5,linestyle=(0, (5,7)), color="C3")
# ax8.semilogy(times[1:], nnz_classical_macro_P2P2[1:],   marker='s', markersize=5,linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C3")

ax8.semilogy(times, nnz_conservative_fullstab_P3P3, marker='^', markersize=5,linestyle="None", color="C3")
ax8.semilogy(times, nnz_conservative_macro_P3P3, marker='^', markersize=5,linestyle="None", markeredgewidth=0.8, markerfacecolor="None", color="C3")

ax8.set_xlabel(r"$t$", fontsize=18)
ax8.tick_params(axis='both', which='major', labelsize=17)
ax8.set_ylabel(r"nnz", fontsize=18)

handles, labels = [(a + b) for a, b in zip(ax7.get_legend_handles_labels(), ax8.get_legend_handles_labels())]
fig7.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)
#ax7.legend(handles=[Rey,III,circle],prop={'size': 18},frameon=False)
#ax7.legend(prop={'size': 18},frameon=False)
ax7.set_xlabel(r"$t$", fontsize=20)
ax7.set_ylabel(r"$e_c(t)$", fontsize=18)
#ax7.set_title(r"Classical scheme")
#plt.grid()
plt.tight_layout()
plt.show()
fig7.savefig("ex1_conservation_vs_t.pdf")

# %% [markdown]
# ### Fig 8 (Conservation error vs h)

# %%
# N = 3, T = 0.1, tau = 0.1
error_conservative_P1P1_fullstab = [2.42861286636753e-17, 4.336808689942018e-17, 1.179611963664229e-16, 4.649058915617843e-16, 1.406860739017191e-15]
error_conservative_P1P1_macro = [3.295974604355933e-17, 1.908195823574488e-17, 8.153200337090993e-17, 2.42861286636753e-16, 7.91033905045424e-16]

error_classical_P1P1_fullstab = [7.157159454177983e-06, 8.010902515752372e-07, 5.427185001752322e-08, 1.18156549735321e-08, 5.002258607333943e-10]
error_classical_P1P1_macro = [7.157159454183187e-06, 1.534130544926515e-06, 1.163607055570948e-07, 1.11966455933199e-08, 1.108641733971183e-09]

# N = 5 space and time, T = 0.1, tau = 0.1
error_conservative_P2P2_fullstab = [1.006139616066548e-16, 1.07552855510562e-16, 2.844946500601964e-16, 3.087807787238717e-16, 9.055256544598933e-16]
error_conservative_P2P2_macro = [1.647987302177967e-16, 1.561251128379126e-17, 6.938893903907228e-17, 5.551115123125783e-17, 4.614364446098307e-16]

error_classical_P2P2_fullstab = [3.18529674163924e-06, 7.519655413450177e-08, 8.551563016739872e-10, 4.13852754149735e-11, 1.071356545145896e-12]
error_classical_P2P2_macro = [3.185296741989654e-06, 5.133510255599105e-08, 4.607544571572086e-10, 2.88306808982064e-11, 2.37853139961608e-13]

# N = 9 space and time, T = 0.1, tau = 0.1 
error_conservative_P3P3_fullstab = [1.925543058334256e-15, 4.230990557907433e-15, 1.19747961546679e-14, 3.393119119010635e-14, 9.524152300155464e-14]
error_conservative_P3P3_macro = [3.552713678800501e-15, 2.381775332516156e-15, 2.491062911502695e-15, 6.833075771872643e-15, 2.312039448781888e-14]

error_classical_P3P3_fullstab = [3.014977524046919e-07, 9.872984495923331e-10, 7.346942325348049e-11, 5.298938371423034e-13, 4.565618716423359e-14]
error_classical_P3P3_macro = [3.014977528938839e-07, 1.572312212719251e-09, 9.876384952922646e-11, 1.133511687290145e-12, 8.491471414906471e-15]

h = [0.2, 0.1, 0.05, 0.025, 0.0125]
dt = [0.1, 0.03333333333333333, 0.01666666666666667, 0.008333333333333333, 0.004166666666666667]
ns_active_mesh = [8, 19, 51, 180, 639]

fig, ax = plt.subplots(1, 1, figsize=(7, 5))
#fig.suptitle("Conservative scheme", fontsize=26)
# ax.loglog(h, 5e-4*np.power(h, 2), linestyle="-", color="black")   
# ax.loglog(h, 7.5e-5*np.power(h, 3), linestyle="-", color="black")   
# ax.loglog(h, 1.6e-5*np.power(h, 6), linestyle="-", color="black")  

# ax.loglog(h, error_conservative_P1P1_fullstab, marker='o', markersize=9, linestyle=":", color="C2")
# ax.loglog(h, error_conservative_P2P2_fullstab, marker='s', markersize=9, linestyle=":", color="C0")
# ax.loglog(h, error_conservative_P3P3_fullstab, marker='^', markersize=9, linestyle=":", color="C3")

ax.loglog(h, error_conservative_P1P1_macro, marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax.loglog(h, error_conservative_P2P2_macro, marker='s', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax.loglog(h, error_conservative_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle=":", color="C3")

# ax.loglog(h, error_classical_P1P1_fullstab, marker='o', markersize=9, linestyle="--", color="C2")
# ax.loglog(h, error_classical_P2P2_fullstab, marker='s', markersize=9, linestyle="--", color="C0")
# ax.loglog(h, error_classical_P3P3_fullstab, marker='^', markersize=9, linestyle="--", color="C3")

ax.loglog(h, error_classical_P1P1_macro, marker='o', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2")
ax.loglog(h, error_classical_P2P2_macro, marker='s', markersize=9, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax.loglog(h, error_classical_P3P3_macro, marker='^', markersize=9,  markeredgewidth=0.8, markerfacecolor="None", linestyle="--", color="C3")

#ax.loglog([],[], label=r"$\mathcal{O}(h^{k+1})$", linestyle="-", color="black")
ax.semilogy([],[], linestyle="--", color="black",label=r"Non-conservative scheme")
ax.semilogy([],[], linestyle=":", color="black", label=r"Conservative scheme")
ax.loglog([],[], linestyle="None", label=" ")
#ax.loglog([],[], linestyle="None", label=" ")
#ax.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$m=1, k=0$")
ax.loglog([],[], linestyle="None",  marker='o', markersize=9, color="C2", label=r"$m = k = 1$")
ax.loglog([],[], linestyle="None",  marker='s', markersize=9, color="C0", label=r"$m = k = 2$")
ax.loglog([],[], linestyle="None",  marker='^', markersize=9, color="C3", label=r"$m = k = 3$")
#ax.loglog([],[], linestyle="None", label=" ")
#ax.loglog([],[], linestyle=(0, (5,7)), color="black",label=r"Non-conservative Scheme")
#ax.loglog([],[], linestyle=":", color="black", label=r"Conservative Scheme")
#ax.loglog([],[], linestyle="None", label=" ")
ax.loglog([],[], linestyle="None",  marker='p', markersize=9, color="black", label=r"Full stabilization")
ax.loglog([],[], linestyle="None",  marker='p', markersize=9, markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"Macro stabilization")

#ax1.set_ylim(1e-4, 2)
#ax1.set_xticks([0, 2, 4, 6])
#ax.set_yticks([1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e0])
ax.set_xlabel(r"$h$")
ax.tick_params(axis='both', which='major')
ax.set_ylabel(r"$e_c(T)$")
#ax1.set_title(r"Conservative scheme")
#ax1.legend()
ax.grid()

#handles, labels = [(a + b + c) for a, b, c in zip(ax1.get_legend_handles_labels(), ax2.get_legend_handles_labels(), ax3.get_legend_handles_labels())]
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncols=3, bbox_to_anchor=(0.5, -0.25), fontsize=18, frameon=False)

fig.tight_layout()
fig.savefig("ex1_conservation_vs_h.pdf")
plt.show()
