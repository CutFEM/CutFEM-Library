# %% [markdown]
# ### Dependencies

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.ticker import FormatStrFormatter




new_rc_paramas = {
    'text.usetex' : True,
    'figure.dpi' : 180,
    'text.latex.preamble' : r'\usepackage{libertine}'r'\usepackage{libertinust1math}',
    'font.family' : 'Linux Libertine',
    'axes.titlesize' : 22,
    'axes.labelsize' : 18,
    'xtick.labelsize' : 16,
    'ytick.labelsize' : 16,
    'xtick.direction' : 'in',
    'ytick.direction' : 'in',
    'xtick.top' : True,
    'ytick.right' : True,
    'legend.fontsize' : 'large',
    'axes.linewidth' : 1.2,
    'savefig.bbox' : 'tight',
    'image.aspect' : 'equal',
}

Oh2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^2)$')
Oh3 = mlines.Line2D([], [], color='black', linestyle="-.", label=r'$\mathcal{O}(h^3)$')
Oh1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h)$')
Ohneg2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-2})$')
Ohneg1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-1})$')
Odt = mlines.Line2D([], [], color='black', linestyle="--", label=r'$\mathcal{O}(\Delta t)$')
Odt2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(\Delta t^2)$')
tau1 = mlines.Line2D([], [], color='C4', linestyle="--", label=r'$\tau_0 = \tau_1 = 1$')
tau10neg4 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-4}$')
tau10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-3}$')
tau3x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-3}$')
tau5x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-3}$')
tau3x10neg4 = mlines.Line2D([], [], color='C2', linestyle="-.", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-4}$')
tau5x10neg4 = mlines.Line2D([], [], color='C3', linestyle=":", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-4}$')

conservative = mlines.Line2D([0], [0], marker='None', color='black', linestyle=":", label='Conservative')
classical = mlines.Line2D([0], [0], marker='None', color='black', linestyle=(0, (5,7)), label='Non-conservative')


space = mlines.Line2D([0], [0], marker='None', color='None', linestyle="None", label=' ')

circle = mlines.Line2D([0], [0], marker='o', color='black', 
                          markersize=9, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label='Full stabilization.')
                          
star = mlines.Line2D([], [], color='black', marker='*',
                          markersize=9,linestyle="None",
                        markeredgewidth=0.8, markerfacecolor="None", 
                        label='Macro stabilization.')

triangle = mlines.Line2D([0], [0], marker='^', color='black', 
                          markersize=9, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label='Macro stab. 2')


import matplotlib.pyplot as plt

mpl.rcParams.update(new_rc_paramas)

import numpy as np

# %% [markdown]
# ### Algoim Macro Elements for Example 1 in $\Omega_2(t)$

# %%
# lobatto n = 3
error_conservative_macro_delta15 = [0.0005083036943417957, 0.0001041572503012073, 2.704988033238446e-05, 9.3214636511445e-06, 4.139373908007093e-06]
cond_conservative_macro_delta15 = [1.642745e+04,3.025526e+04,7.336477e+04,6.990101e+04,1.318173e+05]

error_conservative_macro_delta25 = [0.0004430155553690387, 0.0001064060253906849, 2.641723858696051e-05, 7.337435067209021e-06, 2.114838019193669e-06]
cond_conservative_macro_delta25 = [4.864001e+03,3.037693e+04,3.625720e+04,3.571910e+04,4.336070e+04]

error_conservative_macro_delta35 = [0.0004882411223772802, 0.0001196861368739547, 2.749052336806732e-05, 6.644321236579788e-06, 1.709131695731834e-06]
cond_conservative_macro_delta35 = [4.864001e+03,6.171986e+03,2.544229e+04,3.068008e+04,5.316586e+04]

error_conservative_macro_delta45 = [0.0004937173849398305, 0.0001270288548904007, 2.945846310812286e-05, 7.063698893314527e-06, 1.739277744547838e-06, 4.712125284395784e-07]
cond_conservative_macro_delta45 = [4.582753e+03,6.521774e+03,1.075183e+04,1.666408e+04,2.577515e+04,2.700659e+04]



error_conservative_macro_delta55 = [0.0007348433719843927, 0.0001630191392272121, 3.846601567428292e-05, 8.722586551811542e-06, 2.021395171006223e-06]
cond_conservative_macro_delta55 = [7.967986e+03,6.708618e+03,9.397701e+03,1.091592e+04,1.561492e+04]

error_conservative_fullstab = [0.0007123315579090115, 0.0002847726538512608, 7.869672315869045e-05, 1.573397156537949e-05, 2.718622393560964e-06, 5.528222758824228e-07]
cond_conservative_fullstab = [1.504660e+03,1.496376e+03,2.590093e+03,3.867161e+03,5.177409e+03,8.583036e+03]

error_conservative_nostab =  [0.0004783494562826891, 0.0003340059441213348, 0.0001638776632282611, 3.201780976494205e-05, 1.846952841125305e-05]
cond_conservative_nostab = [6.511181e+10,2.805460e+10,9.879292e+09,7.782458e+09,1.339445e+10]


# lobatto n = 5
error_conservative_macro_delta45 = [0.0004914900242349075, 0.0001272072714700174, 2.926047148045771e-05, 6.98915129312607e-06, 1.64596351373866e-06, 3.978889976228828e-07]
cond_conservative_macro_delta45 = [4.586770e+03,6.499359e+03,1.094736e+04,1.678335e+04,2.651047e+04,2.777270e+04]

error_conservative_fullstab = [0.0007084109577294917, 0.0002853422198596909, 7.815782488454483e-05, 1.571670125079932e-05, 2.665715164075652e-06, 5.120043313356002e-07]
cond_conservative_fullstab = [1.497357e+03,1.494088e+03,2.583932e+03,3.865588e+03,5.171223e+03,8.581516e+03]

error_classical_macro_delta45 = [0.0004914937082401845, 0.0001270191556400225, 2.92630534760044e-05, 6.943451828758867e-06, 1.645930783210118e-06, 3.978962542493911e-07]
cond_classical_macro_delta45 = [4.586759e+03,6.499569e+03,1.094736e+04,1.678335e+04,2.651047e+04,2.777270e+04]

error_classical_fullstab = [0.0007085944832910808, 0.000285596816354344, 7.81638419833073e-05, 1.562127674572579e-05, 2.662768571432827e-06, 5.12143610217265e-07]
cond_classical_fullstab = [1.497415e+03,1.494066e+03,2.583938e+03,3.865588e+03,5.171205e+03,8.581505e+03]

error_conservative_nostab = [0.0003969049910816554, 0.0002387213508667271, 2.616433883316788e-05, 6.567913614977389e-06, 2.791008773137022e-06, 2.008436367967455e-06]
cond_conservative_nostab = [1.028094e+10,4.475876e+09,9.686223e+09,1.011999e+10,1.343581e+10]



# # tau_1 = 1         now with delta = 0.25 #before: 0.16

# error_conservative_macro_tau1 =
# cond_conservative_macro_tau1 = 

# error_conservative_fullstab_tau1 = [0.0009364108052585252, 0.0004371109731207386, 0.0002302883200645334, 6.68953767898245e-05, 1.379131946761409e-05]
# cond_conservative_fullstab_tau1 = [5.149097e+03,6.439635e+03,1.379601e+04,2.355408e+04,4.158197e+04]

# error_classical_macro_tau1 =
# cond_classical_macro_tau1 = 

# error_classical_fullstab_tau1 = [0.000934536885776026, 0.000437211926165526, 0.0002302178307462694, 6.688763650852186e-05, 1.378455389436093e-05]
# cond_classical_fullstab_tau1 = [5.139246e+03,6.423246e+03,1.375407e+04,2.347779e+04,4.143196e+04]


h = [0.1, 0.05, 0.025, 0.0125, 0.00625, 0.003125]

fig2, ax2 = plt.subplots()

ax2.loglog(h, 2.3e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

# tau_1 = 0.1!!!!
#ax2.loglog(h[:-1], error_conservative_macro_delta25,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Conservative, Macro, $\delta = 0.25$")
#ax2.loglog(h[:-1], error_conservative_macro_delta35,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, Macro, $\delta = 0.35$")
#ax2.loglog(h, error_conservative_macro_delta45,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\delta = 0.45$")
#ax2.loglog(h, [0.0004430301060520253, 0.0001053572933216873, 2.586062280713e-05, 6.375456627268446e-06, 1.559143661815161e-06, 3.8668299315665e-07],  marker='*', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro, $\delta = 0.45$")
#ax2.loglog(h[:-1], error_conservative_macro_delta55,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, $\delta = 0.55$")
ax2.loglog(h, error_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, Fullstab")
ax2.loglog(h, error_conservative_macro_delta45,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\delta = 0.45$")

ax2.loglog(h, error_classical_fullstab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, Fullstab")
ax2.loglog(h, error_classical_macro_delta45,  marker='*', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro, $\delta = 0.45$")
#ax2.loglog(h, error_conservative_macro_tau1,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\tau_1 = 1$")
#ax2.loglog(h, error_conservative_fullstab_tau1,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab, $\tau_1=1$")

#ax2.loglog(h, error_classical_macro_tau1,  marker='*', markersize=9,linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\tau_1 = 1$")
#ax2.loglog(h, error_classical_fullstab_tau1,  marker='o', markersize=9,linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab, $\tau_1=1$")

#ax2.loglog(h, error_conservative_macro_tau100,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, $\tau_1 = 100$")

ax2.loglog(h, error_conservative_nostab,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, $\tau_1 = 10^{-10}$")

ax2.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)

ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$ (log)", fontsize=18)

plt.show()


fig3, ax3 = plt.subplots()

ax3.loglog(h, 3e3*np.power(h, -1), label=r"$\mathcal{O}(h^{-1})$", linestyle="-", color="black")
#ax3.loglog(h[:-1], cond_conservative_macro_delta25,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Conservative, Macro, $\delta = 0.25$")
#ax3.loglog(h[:-1], cond_conservative_macro_delta35,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, Macro, $\delta = 0.35$")
#ax3.loglog(h, [4.718446e+03,2.721822e+04,3.725454e+04,4.379777e+04,9.451697e+04,7.838001e+04],  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\delta = 0.45$")
#ax3.loglog(h[:-1], cond_conservative_macro_delta55,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, $\delta = 0.55$")
ax3.loglog(h, cond_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, Fullstab")
ax3.loglog(h, cond_conservative_macro_delta45,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\delta = 0.45$")
ax3.loglog(h, cond_classical_fullstab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Non-conservative, Fullstab")
ax3.loglog(h, cond_classical_macro_delta45,  marker='*', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro, $\delta = 0.45$")
# ax3.loglog(h, cond_conservative_macro_tau1,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\tau_1 = 1$")
# ax3.loglog(h, cond_conservative_fullstab_tau1,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab, $\tau_1=1$")
ax3.loglog(h[:-1], cond_conservative_nostab,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, $\tau_1=10^{-10}$")
ax3.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=18)

plt.show()

## lobatto n = 5

# h = 0.1
error_conservative_macro = [0.000503642339840926, 0.0005996666770837609, 0.0006064282242955262, 0.0006064550744038289, 0.000606455570128522]
error_conservative_fullstab = [0.0007084109577294917, 0.000934386708173512, 0.0009833544319392306, 0.0009839125324041574, 0.00098392013696398]


# h = 0.01
error_conservative_macro = [3.928958344562194e-06, 3.994867989111051e-06, 4.012065406957286e-06, 4.014379608770794e-06, 4.014403373285402e-06, 4.012837984807765e-06]
error_conservative_fullstab = [3.962539497046841e-06, 8.883736132282541e-06, 4.155859863225636e-05, 0.0002381264747404122, 0.0003207396120021357, 0.000323936404083884]

## lobatto n = 3

# h = 0.01 
#error_conservative_macro = [1.151392394719073e-05, 6.857887562371036e-06, 6.594414767734322e-06, 6.576130963459241e-06, 6.575965587928303e-06, 6.573705893065514e-06]
#error_conservative_fullstab = [9.817109022098271e-06, 8.962478126839986e-06, 4.157551920233434e-05, 0.0002381277367677911, 0.000320739605403683, 0.0003239254935696488]

# h = 0.01 but delta = 0.35 (before 0.16)
error_conservative_macro = [1.805124534456366e-05, 4.338933685289478e-06, 4.327866132946055e-06, 4.327962524335847e-06, 4.37620028968515e-06]
error_conservative_fullstab = [1.447210684583562e-05, 8.962478126839986e-06, 0.0002381277367677911, 0.0003235014690570733, 0.0003239559001116965]

# now delta = 0.45
error_conservative_macro = [1.874491043972901e-05, 4.417294919665167e-06, 4.456473310189015e-06, 4.45667164058271e-06, 4.581064673646328e-06]

error_classical_fullstab = [3.929207121312616e-06, 8.885074504513804e-06, 0.0002381284728858286, 0.0003235018721697053, 0.0003239558262918547]
error_classical_macro = [3.926866400519074e-06, 4.178960674866573e-06, 4.24835426467937e-06, 4.248521859686887e-06, 4.305785821216077e-06]

# delta = 0.45 
error_classical_macro = [3.927208173408457e-06, 4.31979733360364e-06, 4.427273599076659e-06, 4.427526469599231e-06, 4.571504729285549e-06]

cond_conservative_fullstab = [1.7405e+04, 3.9217e+03, 1.5387e+06, 5.5201e+08]

## lobatto n = 5 again (but now with new c and delta=0.45)

# h = 0.01 

error_conservative_macro = []
error_classical_macro = []

error_conservative_fullstab = []
error_classical_fullstab = []

cond_conservative_macro = []
cond_conservative_fullstab = [1.7405e+04, 3.9217e+03, 1.5387e+06, 5.5201e+08]





# triangles and non-conservative
#error_conservative_macro = [8.63948e-06, 1.15101e-05, 1.2451e-05, 1.25864e-05, 1.25878e-05, 1.26031e-05]
#error_conservative_fullstab = [8.81019e-06, 2.8546e-05, 0.000154933, 0.00287611, 0.0034671, 0.0034717]

# c = [0.001, 0.1, 1, 100, 10000, 10000000]
# c = [0.0001, 0.1, 100, 100000, 100000000]
# fig4, ax4 = plt.subplots()
# ax4.loglog(c, error_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab")
# ax4.loglog(c, error_conservative_macro,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro")
# ax4.loglog(c, error_classical_fullstab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Fullstab")
# ax4.loglog(c, error_classical_macro,  marker='*', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro")
# #ax2.loglog(c, error_conservative_nostab,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, No stab")
# #ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
# ax4.legend(handles=[circle, star, space, conservative, classical], prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
# ax4.set_xlabel(r"$\tau_1$ (log)", fontsize=18)
# ax4.tick_params(axis='both', which='major', labelsize=17)
# ax4.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$", fontsize=18)

# plt.show()
# Out:
# findfont: Font family ['Linux Libertine'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### AlgoimMacroElementPartition

# %%
error_conservative_macro_delta25 = [0.0006489591498537173, 0.0001763952293398959, 3.958314564405918e-05, 9.086541434192159e-06, 2.491095440683779e-06, 6.3185500727115e-07]
cond_conservative_macro_delta25 = [2.283963e+04,6.708618e+03,2.426874e+06,1.456376e+05,1.400298e+06,2.950925e+06]


error_conservative_fullstab = [0.0007123315579090115, 0.0002847726538512608, 7.869672315869045e-05, 1.573397156537949e-05, 2.718622393560964e-06, 5.528222758824228e-07]
cond_conservative_fullstab = [1.504660e+03,1.496376e+03,2.590093e+03,3.867161e+03,5.177409e+03,8.583036e+03]

error_conservative_nostab =  [0.0004783494562826891, 0.0003340059441213348, 0.0001638776632282611, 3.201780976494205e-05, 1.846952841125305e-05]
cond_conservative_nostab = [6.511181e+10,2.805460e+10,9.879292e+09,7.782458e+09,1.339445e+10]


h = [0.1, 0.05, 0.025, 0.0125, 0.00625, 0.003125]

fig2, ax2 = plt.subplots()

ax2.loglog(h, 2.3e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

# tau_1 = 0.1!!!!
ax2.loglog(h, error_conservative_macro_delta25,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Conservative, Macro, $\delta = 0.25$")
# ax2.loglog(h[:-1], error_conservative_macro_delta35,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, Macro, $\delta = 0.35$")
# ax2.loglog(h, error_conservative_macro_delta45,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\delta = 0.45$")
# ax2.loglog(h[:-1], error_conservative_macro_delta55,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, $\delta = 0.55$")

ax2.loglog(h, error_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, Fullstab")
ax2.loglog(h[:-1], error_conservative_nostab,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, $\tau_1 = 10^{-10}$")

ax2.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)

ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$ (log)", fontsize=18)

plt.show()


fig3, ax3 = plt.subplots()

ax3.loglog(h, 3e3*np.power(h, -1), label=r"$\mathcal{O}(h^{-1})$", linestyle="-", color="black")
ax3.loglog(h, cond_conservative_macro_delta25,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"Conservative, Macro, $\delta = 0.25$")
# ax3.loglog(h[:-1], cond_conservative_macro_delta35,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, Macro, $\delta = 0.35$")
# ax3.loglog(h, cond_conservative_macro_delta45,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, $\delta = 0.45$")
# ax3.loglog(h[:-1], cond_conservative_macro_delta55,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, $\delta = 0.55$")
ax3.loglog(h, cond_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, Fullstab")

ax3.loglog(h[:-1], cond_conservative_nostab,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"Conservative, $\tau_1=10^{-10}$")
ax3.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=18)

plt.show()

# %% [markdown]
# ### Higher order macro

# %%
error_conservative_fullstab_P2_P2 =[0.0001494488616173083, 3.881628420615635e-05, 5.486702405086791e-06, 3.405538587243277e-07, 3.529888636817087e-08]
cond_conservative_fullstab_P2_P2 = [9.363431e+06,1.648957e+07,3.287586e+07,4.932920e+07,7.457605e+07]

error_conservative_macro_delta45_P2_P2 = [3.681434970627714e-05, 3.959554991322784e-06, 4.33963202003749e-07, 4.405980891975698e-08, 8.078673628510773e-09]
cond_conservative_macro_delta45_P2_P2 = [7.854238e+07,3.351243e+08,5.195198e+08,6.953168e+08,1.306586e+09]

error_conservative_macro_delta45_tau100_P2_P2 = [3.781502359094419e-05, 4.009960412229689e-06, 3.964119427074606e-07, 4.221449769983625e-08, 4.273556115714899e-09]
cond_conservative_macro_delta45_tau100_P2_P2 = [2.767550e+10,3.308026e+11,5.141940e+11,6.904360e+11,1e100]

error_conservative_nostab_P2_P2 =  [9.834096382125155e-05, 0.0002842620509485111, 5.883419484511151e-05, 9.913740752163413e-06]
cond_conservative_nostab_P2_P2 = [3.258768e+12,1.247742e+12,1.168398e+12,1.264501e+12]


h = [0.1, 0.05, 0.025, 0.0125, 0.00625, 0.003125]

fig2, ax2 = plt.subplots()

ax2.loglog(h, 2.3e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax2.loglog(h, 1.3e-1*np.power(h, 3), label=r"$\mathcal{O}(h^{3})$", linestyle="--", color="black")

# tau_1 = 0.1!!!!
ax2.loglog(h[:-1], error_conservative_fullstab_P2_P2,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Fullstab, P2 \& P2")
ax2.loglog(h[:-1], error_conservative_macro_delta45_P2_P2,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, P2 \& P2")
ax2.loglog(h[:-2], error_conservative_nostab_P2_P2,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, $\tau_1 = 10^{-10}$")

ax2.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)

ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$ (log)", fontsize=18)

plt.show()


fig3, ax3 = plt.subplots()

ax3.loglog(h, 3e7*np.power(h, -1), label=r"$\mathcal{O}(h^{-1})$", linestyle="-", color="black")
ax3.loglog(h[:-1], cond_conservative_fullstab_P2_P2,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Fullstab, P2 \& P2")
ax3.loglog(h[:-1], cond_conservative_macro_delta45_P2_P2,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, P2 \& P2")
ax3.loglog(h[:-2], cond_conservative_nostab_P2_P2,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, $\tau_1 = 10^{-10}$")
ax3.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=18)

plt.show()

# lobatto n = 5
# delta = 0.45
# tau1 = tau2 = c
# h = 0.05

error_conservative_fullstab = [5.945256023424691e-06, 4.912132205587452e-05, 3.881628420615635e-05, 0.0001791217635223409, 0.0002043873906895748, 0.0002030034464092415]
error_conservative_macro = [8.029795423494367e-05, 3.959554991322784e-06, 4.009960412229689e-06, 4.010072629585349e-06, 6.99434585453863e-06]

# h = 0.02
#error_conservative_fullstab = []
error_conservative_macro = [6.888488658758108e-06, 1.686817946912889e-06, 2.037511217897777e-07, 1.882261057388554e-07, 1.892615710049251e-07, 1.279402397649567e-05]

cond_conservative_macro = [5.975333e+09, 9.126988e+07, 4.883852e+08, 4.846404e+11]

c = [0.0000001, 0.0001, 0.1, 100, 100000, 100000000]
fig4, ax4 = plt.subplots()
ax4.loglog(c, error_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab")
ax4.loglog(c, error_conservative_macro,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro")
#ax4.loglog(c, error_classical_fullstab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Fullstab")
#ax4.loglog(c, error_classical_macro,  marker='*', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro")

#ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.legend(handles=[circle, star, space, conservative, classical], prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$\tau_1$ (log)", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
ax4.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$", fontsize=18)

plt.show()

fig4, ax4 = plt.subplots()
#ax4.loglog(c, error_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab")
ax4.loglog(c[:-2], cond_conservative_macro,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro")
#ax4.loglog(c, error_classical_fullstab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Fullstab")
#ax4.loglog(c, error_classical_macro,  marker='*', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro")

#ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.legend(handles=[circle, star, space, conservative, classical], prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$\tau_1$ (log)", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
ax4.set_ylabel(r"$\kappa(A)$", fontsize=18)
ax4.set_title("Condition number")
plt.show()

# %% [markdown]
# ### Lehrenfeld

# %%
# tau1 = 0.1, delta = 0.45, T = 0.1, dT=h/3, lobatto n = 3

error_classical_fullstab_P1_P1_triangle = [0.0177501, 0.00504338, 0.000853509, 0.00019618]

error_classical_fullstab_P1_P1 = [0.007246484133300689, 0.00191756048208525, 0.000424504645076593, 9.373499464790237e-05]

error_classical_macro_P1_P1 = [0.005944050326102871, 0.001455882110481181, 0.0003169599859593553, 7.093162161892951e-05]

error_conservative_macro_P1_P1 = [0.005949555664928154, 0.001457822763725043, 0.0003174109067827549, 7.10173163398134e-05]
cond_conservative_macro_P1_P1 = [5.890716e+03,8.121445e+03,9.096187e+03,1.595067e+04]

error_conservative_fullstab_P1_P1 = [0.007256628410166797, 0.001918602729740654, 0.0004237825664487267, 9.336452663910533e-05]
cond_conservative_fullstab_P1_P1 = [1.562131e+03,2.100298e+03,3.085536e+03,4.524502e+03]

error_conservative_fullstab_tau001_P1_P1 = [0.004350971363264012, 0.001238635932196278, 0.0002938299510706111, 6.831078025379198e-05]
cond_conservative_fullstab_tau001_P1_P1 =  [2.303341e+03,1.379509e+03,1.301435e+03,1.389918e+03]

error_conservative_macro_delta45_tau001_P1_P1 = [0.004013062428163693, 0.001030994355725068, 0.0002436646029235399, 5.763474141534377e-05] 
cond_conservative_macro_delta45_tau001_P1_P1 = [1.392875e+04,7.426573e+03,7.247858e+03,6.397695e+03]

error_conservative_macro_delta25_P1_P1 = [0.003906148125491827, 0.0009329082796694752, 0.000219182395996888, 5.266370279848355e-05]
cond_conservative_macro_delta25_P1_P1 = [1.039571e+04,1.864114e+04,2.953098e+04,4.857477e+04]

# lobatto n = 5, tau1=tau2=0.1, delta=0.45, FE velocity order 2, T=0.1, dT=h/3
#error_conservative_fullstab_P2_P2 = 
#cond_conservative_fullstab_P2_P2 = 

error_conservative_macro_P2_P2 = [0.0007512933982319611, 7.771593703950497e-05, 7.739419671584353e-06, 8.260337498397686e-07]
cond_conservative_macro_P2_P2 = [1.592495e+08,2.923620e+08,3.979959e+08,6.584332e+08]



# error_conservative_macro_delta45_P2_P2 = 
# cond_conservative_macro_delta45_P2_P2 = 

# error_conservative_nostab_P2_P2 =
# cond_conservative_nostab_P2_P2 = 


h = [0.1, 0.05, 0.025, 0.0125, 0.00625]

fig2, ax2 = plt.subplots()

ax2.loglog(h, 1.3e-0*np.power(h, 2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax2.loglog(h, 2.e-0*np.power(h, 3), label=r"$\mathcal{O}(h^{3})$", linestyle="--", color="black")

# tau_1 = 0.1!!!!
#ax2.loglog(h, error_classical_fullstab_P1_P1_triangle,  marker='^', markersize=9,linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Non-conservative, Fullstab, P1 \& P1")
ax2.loglog(h[:-1], error_classical_fullstab_P1_P1,  marker='o', markersize=9,linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Fullstab, P1 \& P1")
ax2.loglog(h[:-1], error_classical_macro_P1_P1,  marker='*', markersize=9,linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro, P1 \& P1")
ax2.loglog(h[:-1], error_conservative_fullstab_P1_P1,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab, P1 \& P1")
ax2.loglog(h[:-1], error_conservative_macro_P1_P1,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, P1 \& P1")

ax2.loglog(h, [0.009611670457651008, 0.003294295634077012, 0.0007753076622001856, 0.000187150892594853, 3.924310614724924e-05]
)
#ax2.loglog(h[:-1], error_conservative_fullstab_P2_P2,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Fullstab, P2 \& P2")
ax2.loglog(h[:-1], error_conservative_macro_P2_P2,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, P2 \& P2")


#ax2.loglog(h, error_conservative_macro_delta45_P2_P2,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, P2 \& P2")
#ax2.loglog(h, error_conservative_nostab_P2_P2,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, $\tau_1 = 10^{-10}$")

ax2.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)

ax2.set_xlabel(r"$h$ (log)", fontsize=18)
ax2.tick_params(axis='both', which='major', labelsize=17)
ax2.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$ (log)", fontsize=18)

plt.show()


fig3, ax3 = plt.subplots()

ax3.loglog(h, 1e3*np.power(h, -1), label=r"$\mathcal{O}(h^{-1})$", linestyle="-", color="black")
ax3.loglog(h, cond_conservative_fullstab_P1_P1,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab, P1 \& P1")
ax3.loglog(h, cond_conservative_macro_P1_P1,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, P1 \& P1")

#ax3.loglog(h[:-1], cond_conservative_fullstab_P2_P2,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Fullstab, P2 \& P2")
ax3.loglog(h, cond_conservative_macro_P2_P2,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"Conservative, Macro, P2 \& P2")


ax3.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=18)

plt.show()

# lobatto n = 3
# h = 0.02

error_conservative_fullstab = [0.0001539942071760586, 0.0002617828549046339, 0.0006850232800127838, 0.001370711660838134, 0.001420674608426807]
error_conservative_macro = [0.0001691793028352262, 0.0001929518025286517, 0.0002069990652553203, 0.0002070157820398528, 0.0002069959076191617]


# P2 & P2 
# n = 5
# h = 0.02
# tau_2 = 0.1


cond_conservative_macro = [0., 1.730830e+04, 1.496388e+07, 1.496171e+10, 1e100]

c = [0.0001, 0.1, 100, 100000, 100000000]
fig4, ax4 = plt.subplots()
ax4.loglog(c, error_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab")
ax4.loglog(c, error_conservative_macro,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro")
#ax4.loglog(c, error_classical_fullstab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Fullstab")
#ax4.loglog(c, error_classical_macro,  marker='*', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro")

#ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.legend(handles=[circle, star, space, conservative, classical], prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$\tau_1$ (log)", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
ax4.set_ylabel(r"$\|u(T)-u_h(T)\|_{\Omega(T)}$", fontsize=18)

# plt.show()

# fig4, ax4 = plt.subplots()
# #ax4.loglog(c, error_conservative_fullstab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab")
# ax4.loglog(c[:-2], cond_conservative_macro,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro")
# #ax4.loglog(c, error_classical_fullstab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Fullstab")
# #ax4.loglog(c, error_classical_macro,  marker='*', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro")

# #ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
# ax4.legend(handles=[circle, star, space, conservative, classical], prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
# ax4.set_xlabel(r"$\tau_1$ (log)", fontsize=18)
# ax4.tick_params(axis='both', which='major', labelsize=17)
# ax4.set_ylabel(r"$\kappa(A)$", fontsize=18)
# ax4.set_title("Condition number")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-ee3cb1a04f0c> in <module>
#      73
#      74 ax3.loglog(h, 1e3*np.power(h, -1), label=r"$\mathcal{O}(h^{-1})$", linestyle="-", color="black")
# ---> 75 ax3.loglog(h, cond_conservative_fullstab_P1_P1,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Fullstab, P1 \& P1")
#      76 ax3.loglog(h, cond_conservative_macro_P1_P1,  marker='*', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro, P1 \& P1")
#      77
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in loglog(self, *args, **kwargs)
#    1798         self.set_yscale('log', **dy)
#    1799
# -> 1800         l = self.plot(*args, **kwargs)
#    1801         return l
#    1802
#
# ...

# %% [markdown]
# ### Kite

# %%
# T = 0.1

P1P1macro = 
P2P2macro = [0.003709778045244454, 0.0004316397897184473, 4.075755829072724e-05]

# %% [markdown]
# ### How to choose stabilization?

# %%
error_conservative_fullstab = [2.701011567025199e-05, 1.447210144540149e-05, 8.962351343872785e-06, 0.0002381289739391848, 0.0003235018543894887, 0.0003239571740911489]
cond_conservative_fullstab = [1.461763e+07, 1.740499e+04, 3.921728e+03, 1.538674e+06, 5.520072e+08]  # last inf

error_conservative_macro = [2.722757587156617e-05, 1.874490734468409e-05, 4.417350322913139e-06, 4.456535100383226e-06, 4.456707195952116e-06, 4.589379445178644e-06]
cond_conservative_macro = [2.941805e+07, 1.005426e+05, 1.576030e+04, 1.491848e+07, 1.491767e+10]     # last inf

error_classical_fullstab = [3.926530123286841e-06, 3.929240197057279e-06, 8.885089210390989e-06, 0.0002381284607139589, 0.0003235018785731644, 0.0003239525640264248]
cond_classical_fullstab = [1.461472e+07, 1.734075e+04, 3.919320e+03, 1.536805e+06, 5.520072e+08]     # last inf

error_classical_macro = [3.926444659946656e-06, 3.927241266393924e-06, 4.319827760057842e-06, 4.427303177741356e-06, 4.42753248369591e-06, 4.554366155042759e-06]
cond_classical_macro= [2.939656e+07, 9.806948e+04, 1.538307e+04, 1.455776e+07, 1.455697e+10]

c = [0.0000001, 0.0001, 0.1, 100, 100000, 100000000]


plt.show()

fig4, ax4 = plt.subplots()
ax4.loglog(c, error_conservative_fullstab,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Full Stabilization")
ax4.loglog(c, error_conservative_macro,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro Stabilization")
ax4.loglog(c, error_classical_fullstab,  marker='o', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Full Stabilization")
ax4.loglog(c, error_classical_macro,  marker='*', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro Stabilization")
ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.legend(handles=[circle, star, space, conservative, classical], prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$\tau_1$ (log)", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
#ax4.set_ylabel(r"$\kappa(A)$", fontsize=18)
ax4.set_ylabel(r"$L^2$-error", fontsize=18)
plt.show()

fig4, ax4 = plt.subplots()
ax4.loglog(c[:-1], cond_conservative_fullstab,  marker='o', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Full Stabilization")
ax4.loglog(c[:-1], cond_conservative_macro,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro Stabilization")
ax4.loglog(c[:-1], cond_classical_fullstab,  marker='o', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Full Stabilization")
ax4.loglog(c[:-1], cond_classical_macro,  marker='*', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro Stabilization")
ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.legend(handles=[circle, star, space, conservative, classical], prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$\tau_1$ (log)", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
#ax4.set_ylabel(r"$\kappa(A)$", fontsize=18)
ax4.set_ylabel("Condition number", fontsize=18)
plt.show()

# %% [markdown]
# ### Compare macro condition

# %%
# Variant without 2*
error_classical_macro_v2_045 = [0.0004430301060519964, 0.0001053572933217157, 2.586062280712555e-05]
cond_classical_macro_v2_045 = [4.718446e+03,2.721822e+04,3.725454e+04]

# Variant with 2*
error_classical_macro_v1_045 = [0.0004914321430422929, 0.0001270137845406155, 2.926455407386133e-05]
cond_classical_macro_v1_045 = [4.566908e+03,6.405223e+03,1.090971e+04]

error_classical_macro_v2_055 = [0.0004506161934467038, 0.0001101307232444534, 2.600501227906741e-05]
cond_classical_macro_v2_055 = [4.718446e+03,5.973772e+03,3.839314e+04]

error_classical_macro_v2_065 = [0.0004506161934467038, 0.0001150471253189149, 2.678269203934903e-05]
cond_classical_macro_v2_065 = [4.718446e+03,5.957027e+03,2.431718e+04]

# h = 0.025
error_classical_macro = [2.586062280712555e-05, 2.600501227906741e-05, 2.678269203934903e-05, 2.764138030193021e-05]
cond_classical_macro = [3.725454e+04, 3.839314e+04, 2.431718e+04, 2.431718e+04]


error_conservative_macro = [2.707926163413911e-05, 2.714069073834678e-05, 2.630960547050216e-05, 2.647799894694435e-05, 2.7063728189197e-05, 2.792032778233736e-05, 2.899234688849826e-05, 3.313773344428664e-05]
cond_conservative_macro = [7.336477e+04, 7.3365e+04, 3.518304e+04, 3.625720e+04, 2.544229e+04, 2.544229e+04, 1.771762e+04, 9.642823e+03]
nnz_conservative_macro = [22692, 22788, 23268, 23580, 23772, 23844, 24228, 24780]

error_conservative_fullstab = 7.869672315869515e-05*np.ones(np.size(error_conservative_macro))
cond_conservative_fullstab = 2.590093e+03*np.ones(np.size(error_conservative_macro))
nnz_conservative_fullstab = 29148*np.ones(np.size(error_conservative_macro))

h = [0.1, 0.05, 0.025]
delta = [0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95]

plt.show()

fig4, ax4 = plt.subplots()
ax4.plot(delta, error_conservative_fullstab, linestyle=":", color="C0", label=r"Conservative, Full Stabilization")
ax4.plot(delta, error_conservative_macro,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro Stabilization")


#ax4.loglog(c, error_classical_fullstab,  marker='o', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Full Stabilization")
#ax4.loglog(c, error_classical_macro,  marker='*', markersize=9, linestyle=(0, (5,7)), markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Non-conservative, Macro Stabilization")
ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$\delta$ ", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
ax4.set_title(r"$h=0.025$, $\tau_1 = 0.1$", fontsize=18)
ax4.set_ylabel(r"$L^2$-error", fontsize=18)
plt.show()

fig4, ax4 = plt.subplots()
ax4.plot(delta, cond_conservative_fullstab, linestyle=":", color="C0", label=r"Conservative, Full Stabilization")
ax4.plot(delta, cond_conservative_macro,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro Stabilization")
ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$\delta$ ", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
#ax4.set_ylabel(r"$\kappa(A)$", fontsize=18)
ax4.set_ylabel("Condition number", fontsize=18)
ax4.set_title(r"$h=0.025$, $\tau_1 = 0.1$", fontsize=18)
plt.show()

fig4, ax4 = plt.subplots()
ax4.plot(delta, nnz_conservative_fullstab, linestyle=":", color="C0", label=r"Conservative, Full Stabilization")
ax4.plot(delta, nnz_conservative_macro,  marker='*', markersize=9, linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Conservative, Macro Stabilization")
ax4.legend(prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax4.set_xlabel(r"$\delta$ ", fontsize=18)
ax4.tick_params(axis='both', which='major', labelsize=17)
#ax4.set_ylabel(r"$\kappa(A)$", fontsize=18)
ax4.set_ylabel("Number of non-zero elements", fontsize=18)
ax4.set_title(r"$h=0.025$, $\tau_1 = 0.1$", fontsize=18)
plt.show()
