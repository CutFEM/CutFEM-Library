# %% [markdown]
# ### Dependencies for plotting

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
from matplotlib.ticker import FormatStrFormatter




new_rc_paramas = {
    'text.usetex' : True,
    'figure.dpi' : 180,
    'text.latex.preamble' : r'\usepackage{libertine}'r'\usepackage{libertinust1math}',
    'font.family' : 'Linux Libertine',
    'axes.titlesize' : 22,
    'axes.labelsize' : 18,
    'xtick.labelsize' : 16,
    'ytick.labelsize' : 16,
    'xtick.direction' : 'in',
    'ytick.direction' : 'in',
    'xtick.top' : True,
    'ytick.right' : True,
    'legend.fontsize' : 'large',
    'axes.linewidth' : 1.2,
    'savefig.bbox' : 'tight',
    'image.aspect' : 'equal',
}

Oh2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^2)$')
Oh3 = mlines.Line2D([], [], color='black', linestyle="-.", label=r'$\mathcal{O}(h^3)$')
Oh1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h)$')
Ohneg2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-2})$')
Ohneg1 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(h^{-1})$')
Odt = mlines.Line2D([], [], color='black', linestyle="--", label=r'$\mathcal{O}(\Delta t)$')
Odt2 = mlines.Line2D([], [], color='black', linestyle="-", label=r'$\mathcal{O}(\Delta t^2)$')
tau1 = mlines.Line2D([], [], color='C4', linestyle="--", label=r'$\tau_0 = \tau_1 = 1$')
tau10neg4 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-4}$')
tau10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 1\cdot 10^{-3}$')
tau3x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-3}$')
tau5x10neg3 = mlines.Line2D([], [], color='C0', linestyle="-", label=r'$\tau_0 = \tau_1 = 5\cdot 10^{-3}$')
tau3x10neg4 = mlines.Line2D([], [], color='C2', linestyle="-.", label=r'$\tau_0 = \tau_1 = 3\cdot 10^{-4}$')
pressure = mlines.Line2D([], [], color='black', linestyle=":", label=r'$\|p-p_h\|_{\Omega}$')
velocity = mlines.Line2D([], [], color='black', linestyle="-.", label=r'$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$')

pentagon = mlines.Line2D([0], [0], marker='p', color='C3', 
                          markersize=8, markerfacecolor="None", 
                          linestyle="none", markeredgewidth=0.8,
                           label=r'$(\tau_W, \tau_A, \tau_B) = (1,0,1)$')
                          
circle = mlines.Line2D([], [], color='C0', marker='o',
                          markersize=8,linestyle="none",
                        markeredgewidth=0.8, markerfacecolor="None", 
                        label=r'$(\tau_W, \tau_A, \tau_B) = (1,1,1)$')

square = mlines.Line2D([0], [0], marker='s', color='black', 
                          markersize=8, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label='No stabilization')

triangle = mlines.Line2D([0], [0], marker='^', color='C2', 
                          markersize=8, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label=r'$(\tau_W, \tau_A, \tau_B) = (0.1,0.1,0.1)$')

star = mlines.Line2D([0], [0], marker='*', color='C6', 
                          markersize=8, markerfacecolor="None", 
                          linestyle="none", markeredgewidth=0.8,
                           label=r'$(\tau_W, \tau_A, \tau_B) = (1,1,0)$')

point = mlines.Line2D([0], [0], marker='.', color='C7', 
                          markersize=8, markerfacecolor="None", 
                          linestyle="none", markeredgewidth=0.8,
                           label=r'$(\tau_W, \tau_A, \tau_B) = (0.1,0.1,0.1)$')

pentagon_WM = mlines.Line2D([0], [0], marker='p', color='C3', 
                          markersize=8, markerfacecolor="None", 
                          linestyle="none", markeredgewidth=0.8,
                           label=r'$(\tau_W, \tau_M, \tau_B) = (1,0,1)$')
                          
circle_WM = mlines.Line2D([], [], color='C0', marker='o',
                          markersize=8,linestyle="none",
                        markeredgewidth=0.8, markerfacecolor="None", 
                        label=r'$(\tau_W, \tau_M, \tau_B) = (1,1,1)$')


triangle_WM = mlines.Line2D([0], [0], marker='^', color='C2', 
                          markersize=8, markerfacecolor="None", 
                          linestyle="None", markeredgewidth=0.8,
                           label=r'$(\tau_W, \tau_M, \tau_B) = (0,1,1)$')

space = mlines.Line2D([0], [0], marker='None', color='None', linestyle="None", label=' ')


import matplotlib.pyplot as plt

mpl.rcParams.update(new_rc_paramas)

import numpy as np

# %% [markdown]
# ### Maxwell 3D

# %%
# with vorticity stabilization and wpen = 1, upen = 1, ppen=1

err_p = [0.0201388, 0.0251869, 0.0129137, 0.00372079]
err_u = [0.062554, 0.0484212, 0.0238988, 0.0113719]
err_divu = [7.55573e-11, 8.34617e-10, 1.0637e-09, 1.97206e-09]
err_maxdivu = [1.71906e-09, 3.33349e-08, 1.5754e-07, 1.15883e-06] 
cond_number = [1.521116e+05,3.419230e+05,1.715404e+06,2.711482e+07]

# without vorticity stabilization and upen = 0.1, ppen = 1
err_p_3 = [0.0176412, 0.0109108, 0.00450397, 0.00179333]
err_u_3 = [0.0528327, 0.0349755, 0.0198814, 0.0103674]
cond_number_3 = [1.233447e+05,5.400735e+05,2.032317e+07,2.934217e+10]

# without vorticity stabilization and upen = ppen = 0.1
err_p_2 = [0.024481, 0.0121677, 0.00444813, 0.00167673]
err_u_2 = [0.0528327, 0.0349755, 0.0198814, 0.0103674]
err_divu_2 = [4.47335e-11, 1.68139e-09, 9.19111e-09, 8.08039e-08, ]
err_maxdivu_2 = [7.37923e-10, 6.77035e-08, 2.02617e-06, 2.71465e-05]
cond_number_2 = [9.529418e+04,4.961090e+05,2.037089e+07,2.934168e+10]

# without vorticity stabilization and upen = 0.01, ppen = 1
err_p_4 = [0.0157434, 0.00945835, 0.00403232, 0.00172567]
err_u_4 = [0.0472681, 0.032896, 0.0194196, 0.0102524]
cond_number_4 = [1.184514e+05,3.295130e+05,1.006783e+07,1.125472e+10]

# only pressure stabilization, ppen = 1
err_p_5 = [0.0153654, 0.00928882, 0.00399431, 0.00172095]
err_u_5 = [0.0469492, 0.0328276, 0.0194016, 0.0102483]
cond_number_5 = [1.308133e+05,3.418812e+05,9.174706e+06,1.006492e+10]


# no stabilization
err_p_nostab = [0.0208265, 0.00900187, 0.00363455, 0.00155802]
err_u_nostab = [0.0469492, 0.0328276, 0.0194016, 0.0102483]
cond_number_nostab = [3.156896e+04,1.667733e+05,6.791587e+06,8.970445e+09]

h = [0.25, 0.125, 0.0625, 0.03125]


fig1, ax1 = plt.subplots()

ax1.loglog(h, 5.7e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="-", color="black")
#ax1.loglog(h, 1.7e-1*np.power(h, 1.5), label=r"$\mathcal{O}(h^{1.5})$", linestyle="--", color="black")


ax1.loglog(h, err_p_nostab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$\|p-p_h\|_{\Omega}$, no stab.")
ax1.loglog(h, err_u_nostab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, no stab.")


ax1.loglog(h, err_p,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\|p-p_h\|_{\Omega}$, vorticity stab. $\tau=1$")
ax1.loglog(h, err_u,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, vorticity stab. $\tau=1$")

ax1.loglog(h, err_p_3,  marker='^', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|p-p_h\|_{\Omega}$, no vorticity stab. $\tau=1$")
ax1.loglog(h, err_u_3,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, no vorticity stab. $\tau=1$")

ax1.loglog(h, err_p_2,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\|p-p_h\|_{\Omega}$, no vorticity stab. $\tau=0.1$")
ax1.loglog(h, err_u_2,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, no vorticity stab. $\tau=0.1$")



ax1.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.set_xlabel(r"$h$ (log)", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$L^2$ error (log)", fontsize=22)
#ax1.set_title(r"Laplace-Beltrami, $\tau = 10^{-6}$")

plt.show()

plt.show()

fig3, ax3 = plt.subplots()

ax3.loglog(h, 5e4*np.power(h, -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

ax3.loglog(h, cond_number_nostab,  marker='s', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"No stabilization")
ax3.loglog(h, cond_number,  marker='s', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"Vorticity stabilization, $\tau=1$")
ax3.loglog(h, cond_number_3,  marker='s', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"No vorticity stabilization, $\tau=1$")
ax3.loglog(h, cond_number_2,  marker='s', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"No vorticity stabilization, $\tau=0.1$")

ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
#ax3.set_title(r"Laplace-Beltrami, $n=5$")

plt.show()

# %% [markdown]
# ### New

# %%
# with tau_b = tau_m = 2

err_p = [0.0168986, 0.0341345, 0.0260528, 0.0300673, 0.0353194, 0.0265804, 0.0203418]
conv_p = [0, -3.15078, 1.4819, -0.929697, -0.640602, 0.988102, 0.929832]
err_u = [0.0656233, 0.0693274, 0.0697078, 0.0646975, 0.0543107, 0.0411106, 0.0287427]
conv_u = [0, -0.246075, -0.0300161, 0.483878, 0.696345, 0.967927, 1.24402]
err_divu = [4.30709e-10, 5.42856e-10, 7.00595e-10, 1.72128e-09, 3.44868e-09, 6.74017e-09, 2.54761e-08]
err_maxdivu = [5.39791e-09, 1.36091e-08, 4.01743e-08, 4.20592e-08, 1.23689e-07, 3.1789e-07, 3.43122e-06]

cond_number = [1.420931e+06,1.859207e+08,6.473442e+07,1.311642e+07,4.284394e+07,1.335506e+09,3.071633e+08]

# with tau_b = tau_m = 10

err_p_10 = [0.0134087, 0.0659062, 0.041097, 0.0536474, 0.0743852, 0.0629384, 0.0567248]
err_u_10 = [0.0671411, 0.0755013, 0.0799189, 0.0790723, 0.0732916, 0.0626564, 0.0472291]


cond_number_10 = [7.440718e+06,9.217876e+08,3.190284e+08,6.472003e+07,2.107236e+08,6.585132e+09,1.517366e+09]

# with tau_b = 10,  tau_m = 1

err_p_10_1 = [0.0133728, 0.0226366, 0.0147898, 0.0155607, 0.016405, 0.012402, 0.00946466]
err_u_10_1 = [0.0639983, 0.0652103, 0.0625879, 0.0565958, 0.0464017, 0.0346688, 0.0246754]


cond_number_10_1 = [1.245865e+06,1.331252e+08,3.932394e+07,7.667515e+06,2.231000e+07,6.811121e+08,1.558884e+08]


cond_number_grad1_1 = [8.286123e+05,9.800265e+07,3.360951e+07,6.902994e+06,2.214421e+07,6.866439e+08,1.569771e+08]

cond_vet_ej = [3.666642e+04,4.544982e+06,1.657510e+06,3.390629e+05,1.164179e+06,3.409199e+07,7.947142e+06]

# no stabilization

err_p_nostab = [0.0208265, 0.0177537, 0.0133361, 0.0106377, 0.00791351, 0.00542441, 0.00363455]
conv_p_nostab = [0, 0.71539, 1.5693, 1.46658, 1.17713, 1.31277, 1.39189]
err_u_nostab = [0.0469492, 0.0465057, 0.0402482, 0.035473, 0.0307726, 0.0251594, 0.0194016]
conv_u_nostab = [0, 0.042533, 0.792608, 0.819286, 0.565623, 0.700045, 0.903344]
err_divu_nostab = [1.01133e-13, 1.2947e-12, 2.12316e-13, 2.99988e-13, 4.2683e-13, 6.19827e-13, 1.49123e-12]
err_maxdivu_nostab = [2.74314e-12, 4.19917e-11, 2.75513e-11, 1.13829e-11, 1.98881e-11, 7.04716e-11, 1.15534e-10]

cond_number_nostab = [3.156896e+04,4.282796e+06,1.500820e+06,3.055490e+05,9.862238e+05,2.866183e+07,6.728758e+06]



h = [0.25, 0.2, 0.166667, 0.142857, 0.111111, 0.0833333, 0.0625]


fig1, ax1 = plt.subplots()

ax1.loglog(h, 5.7e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="-", color="black")
#ax1.loglog(h, 1.7e-1*np.power(h, 1.5), label=r"$\mathcal{O}(h^{1.5})$", linestyle="--", color="black")


ax1.loglog(h, err_p_nostab,  marker='o', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$\|p-p_h\|_{\Omega}$, no stab.")
ax1.loglog(h, err_u_nostab,  marker='o', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, no stab.")


ax1.loglog(h, err_p,  marker='^', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\|p-p_h\|_{\Omega}$, $\tau_m = 2$, $\tau_b=2$")
ax1.loglog(h, err_u,  marker='^', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_m = 2$, $\tau_b=2$")

ax1.loglog(h, err_p_10,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\|p-p_h\|_{\Omega}$, $\tau_m = 10$, $\tau_b=10$")
ax1.loglog(h, err_u_10,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_m = 10$, $\tau_b=10$")

ax1.loglog(h, err_p_10_1,  marker='p', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|p-p_h\|_{\Omega}$, $\tau_m = 1$, $\tau_b=10$")
ax1.loglog(h, err_u_10_1,  marker='p', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_m = 1$, $\tau_b=10$")

# ax1.loglog(h, err_p_2,  marker='s', markersize=9,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\|p-p_h\|_{\Omega}$, no vorticity stab. $\tau=0.1$")
# ax1.loglog(h, err_u_2,  marker='s', markersize=9,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, no vorticity stab. $\tau=0.1$")



ax1.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.set_xlabel(r"$h$ (log)", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$L^2$ error (log)", fontsize=22)
#ax1.set_title(r"Laplace-Beltrami, $\tau = 10^{-6}$")

plt.show()

plt.show()

fig3, ax3 = plt.subplots()

ax3.loglog(h, 5e4*np.power(h, -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")

ax3.loglog(h, cond_number_nostab,  marker='o', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"No stabilization")
ax3.loglog(h, cond_number,  marker='^', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\tau_m = 2$, $\tau_b=2$")
ax3.loglog(h, cond_number_10,  marker='s', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\tau_m = 10$, $\tau_b=10$")
ax3.loglog(h, cond_number_10_1,  marker='p', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\tau_m = 1$, $\tau_b=10$")
ax3.loglog(h, cond_number_grad1_1,  marker='.', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C4", label=r"$\tau_m = 1$, $\tau_b=1$, grad")

ax3.loglog(h, cond_vet_ej,  marker='o', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C5", label=r"$\tau_m = 1$, $\tau_b=1$, grad, new")
ax3.loglog(h, [8.435613e+05,4.448783e+06,5.354979e+06,6.407626e+06,1.790478e+07,6.542653e+07,1.607294e+08])
ax3.loglog(h, [1.575224e+05,2.908963e+05,2.497853e+05,2.948541e+05,4.985262e+05,9.194046e+05,1.719363e+06])
ax3.loglog(h, [1.475096e+05,2.820819e+05,2.429229e+05,2.871412e+05,4.969748e+05,9.124616e+05,1.711971e+06])
ax3.loglog(h, [3.977042e+05,8.527469e+05,7.193134e+05,8.493811e+05,1.389568e+06,2.382889e+06,4.831461e+06])
ax3.loglog(h, [1.571666e+05,3.337833e+05,2.803035e+05,3.162584e+05,5.284650e+05,9.025491e+05,1.816080e+06])
#ax3.loglog(h, cond_number_3,  marker='s', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"No vorticity stabilization, $\tau=1$")
#ax3.loglog(h, cond_number_2,  marker='s', markersize=9,linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"No vorticity stabilization, $\tau=0.1$")

ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
#ax3.set_title(r"Laplace-Beltrami, $n=5$")

plt.show()

# %% [markdown]
# ### WA vs WM

# %%
# WA (tau_w = 1, tau_a = 1, tau_b = 1) using MUMPS and multiplying gradients with normals
err_p_1_1 = [0.0195292, 0.0168481, 0.0147977, 0.0124166, 0.00953696, 0.0067073, 0.00435223, 0.00279986, 0.00186902, 0.00130255]
conv_p_1_1 = [0, 0.6618, 0.711725, 1.13808, 1.04993, 1.2235, 1.50342, 1.38519, 1.30308, 1.15594]
err_u_1_1 = [0.0641396, 0.0709332, 0.0582292, 0.0490933, 0.0371042, 0.0272369, 0.0202511, 0.0148252, 0.0109877, 0.00809336]
conv_u_1_1 = [0, -0.451169, 1.08244, 1.10713, 1.11411, 1.07466, 1.03018, 0.979353, 0.965807, 0.978744]
err_divu_1_1 = [8.69038e-12, 8.74367e-11, 1.32116e-11, 7.26132e-12, 7.5488e-12, 1.01667e-11, 2.64643e-11, 3.14044e-11, 1.24169e-10, 1.46478e-10]
err_maxdivu_1_1 = [2.31202e-10, 1.98761e-09, 2.80373e-10, 1.74932e-10, 3.2858e-10, 2.02562e-09, 2.99129e-09, 4.36662e-09, 4.68815e-08, 3.90893e-08]

cond_1_1 = [1.571666e+05,3.337833e+05,2.639236e+05,3.160619e+05,5.284650e+05,9.025491e+05,1.816080e+06,6.058549e+06,2.025950e+07]

cond_1_1_no_normals = [3.977042e+05,5.865007e+05,7.193134e+05,8.546102e+05,1.399911e+06,2.382889e+06,4.831461e+06,1.618201e+07,5.425371e+07]

# tau_w = 0, tau_a = 1, tau_b = 1 (with normals)
err_p_0_1 = [0.0176356, 0.0171689, 0.0144006, 0.0116416, 0.00914584, 0.00657317, 0.00428594, 0.00278742, 0.00186689, 0.00130182] 
conv_p_0_1 = [0, 0.120215, 0.964367, 1.37976, 0.96008, 1.14815, 1.48656, 1.35098, 1.2924, 1.1541]
err_u_0_1 = [0.0470754, 0.0466411, 0.0403194, 0.0355174, 0.0307964, 0.0251697, 0.0194051, 0.0145296, 0.010887, 0.00806108]
conv_u_0_1 = [0, 0.0415347, 0.798855, 0.822638, 0.567516, 0.701317, 0.904146, 0.908607, 0.930546, 0.962065]
err_divu_0_1 = [6.82386e-12, 7.05296e-12, 1.26354e-11, 8.22133e-12, 1.20973e-12, 7.32408e-12, 1.57669e-11, 2.61498e-11, 2.33162e-10, 1.7441e-10]
err_maxdivu_0_1 = [1.46438e-10, 1.38732e-10, 2.89006e-10, 2.3878e-10, 3.59872e-11, 4.60943e-10, 9.74847e-10, 3.21186e-09, 6.55016e-08, 4.60786e-08]

cond_0_1 = [7.399181e+06,5.608747e+10,1.148477e+10,6.014761e+07,2.779700e+08,7.862016e+10,2.250535e+09,2.260446e+14,3277916128976213]


# tau_w = 1, tau_a = 0, tau_b = 1 (with normals)
err_p_1_0 = [0.0153654, 0.0148211, 0.012336, 0.010483, 0.00813868, 0.00590945, 0.00399431, 0.00266499, 0.00182035, 0.00128631]
conv_p_1_0 = [0, 0.161638, 1.00661, 1.05593, 1.0072, 1.1126, 1.36151, 1.27074, 1.22897, 1.11165]
err_u_1_0 = [0.436646, 0.777784, 0.285016, 0.310791, 0.195435, 0.16308, 0.182391, 0.100346, 0.0191166, 0.0393971]
conv_u_1_0 = [0, -2.58724, 5.50622, -0.561632, 1.84588, 0.629117, -0.389022, 1.87636, 5.34592, -2.31497]
err_divu_1_0 = [5.03754e-11, 1.87497e-10, 9.62592e-11, 7.02312e-11, 2.42427e-11, 5.28796e-11, 1.19148e-10, 7.42762e-11, 5.93589e-10, 1.11177e-09]
err_maxdivu_1_0 = [1.6336e-09, 3.62084e-09, 5.93249e-09, 3.19974e-09, 2.53009e-09, 6.3316e-09, 6.64882e-08, 2.37724e-08, 7.6969e-07, 7.33641e-07]

cond_1_0 = [2.869564e+04,4.537517e+05,1.405402e+05,6.911242e+04,2.045268e+05,2.600378e+05,1.531035e+06,1.071195e+07,3.720318e+07]

# WM (tau_w = 1, tau_m = 1, tau_b = 1) using MUMPS and NOT multiplying gradients with normals in stabilization
cond_1_1_WM = [1.475096e+05,2.793697e+05,2.429229e+05,2.872018e+05,4.871706e+05,9.124616e+05,1.711971e+06,5.935091e+06,2.089975e+07]

# tau_w = 1, tau_a = 1, tau_b = 0 (with normals)

# constant scaling of RT0, and multiplied with area on Nedelec0
cond_areascaling = [1.753386e+04,5.801982e+04,5.050987e+04,4.626100e+04,8.215779e+04,1.702760e+05,2.698480e+05,4.501790e+05,9.496245e+05]   
cond_areascaling_server = [5.214379e+03,1.041961e+04,1.648186e+04,9.655067e+03,1.707983e+04,4.224569e+04,4.938552e+04,9.802580e+04,1.969532e+05,3.169334e+05]


# No stabilization

err_p_nostab = [0.0208265, 0.0177537, 0.0133361, 0.0106377, 0.00791351, 0.00542441, 0.00363455, 0.00241873, 0.00167539, 0.00118135]
conv_p_nostab = [0, 0.71539, 1.5693, 1.46658, 1.17713, 1.31277, 1.39189, 1.27881, 1.18392, 1.11849]
err_u_nostab = [0.0469492, 0.0465057, 0.0402482, 0.035473, 0.0307726, 0.0251594, 0.0194016, 0.0145285, 0.0108867, 0.00806098]
conv_u_nostab = [0, 0.042533, 0.792608, 0.819286, 0.565623, 0.700045, 0.903344, 0.908278, 0.930405, 0.962011]
err_divu_nostab = [1.01133e-13, 1.2947e-12, 2.12316e-13, 2.99988e-13, 4.2683e-13, 6.19827e-13, 1.49123e-12, 2.84577e-12, 1.59936e-10, 2.4399e-11]
err_maxdivu_nostab = [2.74314e-12, 4.19917e-11, 2.75513e-11, 1.13829e-11, 1.98881e-11, 7.04716e-11, 1.15534e-10, 4.20176e-10, 7.8186e-08, 1.13778e-08]

cond_nostab = [3.156896e+04,4.262547e+06,1.528720e+06,3.055490e+05,9.862238e+05,2.859979e+07,6.728758e+06,5.423217e+09,3.721401e+10]

h = [0.25, 0.2, 0.166667, 0.142857, 0.111111, 0.0833333, 0.0625, 0.0454545, 0.0333333, 0.0243902]


fig1, ax1 = plt.subplots()

ax1.loglog(h, 5.7e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="-", color="black")

ax1.loglog(h, err_p_nostab,  marker='s', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$\|p-p_h\|_{\Omega}$, no stab.")
ax1.loglog(h, err_u_nostab,  marker='s', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, no stab.")
ax1.loglog(h, err_p_1_1,  marker='o', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\|p-p_h\|_{\Omega}$, $\tau_W = \tau_A = \tau_B = 1$")
ax1.loglog(h, err_u_1_1,  marker='o', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_W = \tau_A = \tau_B = 1$")
# ax1.loglog(h, err_p_0_1,  marker='^', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|p-p_h\|_{\Omega}$, $\tau_W = 0,\ \tau_A = \tau_B = 1$")
# ax1.loglog(h, err_u_0_1,  marker='^', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_W = 0,\ \tau_A = \tau_B = 1$")
# ax1.loglog(h, err_p_1_0,  marker='p', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\|p-p_h\|_{\Omega}$, $\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
# ax1.loglog(h, err_u_1_0,  marker='p', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
# ax1.loglog(h, err_p_1_1_0,  marker='*', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C6", label=r"$\|p-p_h\|_{\Omega}$, $\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
# ax1.loglog(h, err_u_1_1_0,  marker='*', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C6", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
ax1.loglog(h, err_p_01_01_01,  marker='^', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|p-p_h\|_{\Omega}$, $\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
ax1.loglog(h, err_u_01_01_01,  marker='^', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_W = 0.1,\ \tau_A = 0.1,\ \tau_B = 0.1$")

#ax1.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.legend(handles=[Oh2, pressure, velocity, space, square, circle, triangle],prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.set_xlabel(r"$h$ (log)", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$L^2$ error (log)", fontsize=22)
#ax1.set_title(r"Laplace-Beltrami, $\tau = 10^{-6}$")

plt.show()

fig3, ax3 = plt.subplots()

ax3.loglog(h, 2e3*np.power(h, -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
#ax3.loglog(h, 5e1*np.power(h, -2.5), label=r"$\mathcal{O}(h^{2.5})$", linestyle="-.", color="black")
ax3.loglog(h[:-1], cond_nostab,  marker='s', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"no stab.")
ax3.loglog(h[:-1], cond_1_1,  marker='o', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\tau_W = \tau_A = \tau_B = 1$")
ax3.loglog(h, cond_01_01_01_server,  marker='^', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
ax3.loglog(h, cond_areascaling_server,  marker='*', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
#ax3.loglog(h[:-2], cond_hscaling,  marker='p', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C6", label=r"$\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
ax3.legend(handles=[Ohneg2, space, square, circle, triangle],prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
#ax3.set_title(r"Laplace-Beltrami, $n=5$")

plt.show()

# %% [markdown]
# ### Testing scaling on fitted FEM using only the Nedelec terms of Ned 0

# %%
cond_noscaling = [6.766214e+03,1.071780e+04,1.486019e+04,2.134820e+04,4.448497e+04,6.378554e+04,1.390632e+05,2.687759e+05,6.562996e+05]#[6.766214e+03,1.071780e+04,1.709827e+04,2.134820e+04,3.560432e+04,7.641991e+04,1.269738e+05,2.864699e+05]
cond_hscaling = [7.775052e+03,1.231592e+04,1.790071e+04,2.439699e+04,4.931420e+04,9.258906e+04,1.704837e+05,3.498924e+05,6.866876e+05]
cond_areascaling = [7.090528e+03,1.076513e+04,1.612807e+04,2.198986e+04,3.640539e+04,6.477867e+04,1.152321e+05,2.179733e+05,4.054795e+05]

h = [0.25, 0.2, 0.166667, 0.142857, 0.111111, 0.0833333, 0.0625, 0.0454545, 0.0333333, 0.0243902]


fig3, ax3 = plt.subplots()

ax3.loglog(h[:-1], 3e2*np.power(h[:-1], -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax3.loglog(h[:-1], cond_noscaling,  marker='o', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"no scaling")
ax3.loglog(h[:-1], cond_hscaling,  marker='p', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$h$ scaling")
ax3.loglog(h[:-1], cond_areascaling,  marker='s', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"area scaling")
ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
ax3.set_title("Nedelec 0")

plt.show()

# %% [markdown]
# ### Test scaling Ned0 on fitted FEM but mixed formulation

# %%
cond_nochange = [2.8773e+03, 4.6217e+03, 6.9495e+03, 7.9408e+03, 2.0699e+04, 6.3249e+04, 1.9624e+05]

h = [0.25, 0.2, 0.166667, 0.142857, 0.111111, 0.0833333, 0.0625, 0.0454545, 0.0333333, 0.0243902]


fig3, ax3 = plt.subplots()

ax3.loglog(h[:-1], 2e3*np.power(h[:-1], -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax3.loglog(h[:-1], 1e1*np.power(h[:-1], -3), label=r"$\mathcal{O}(h^{3})$", linestyle="--", color="black")
ax3.loglog(h[:-3], cond_nochange,  marker='p', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0")
ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
#ax3.legend(handles=[Ohneg2, space, square, circle, triangle],prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_title("Mixed")
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
plt.show()

# %% [markdown]
# ### Scaling of RT0 in 3D on an fitted divergence problem

# %%
# scaling c = 1/(3*volume(K))

cond_negvolume = [6.568458e+03,9.475049e+03,1.655649e+04,2.190134e+04,3.719051e+04,8.153396e+04,1.329409e+05,3.716643e+05,6.528990e+05,1.561864e+06]

# no scaling
cond_noscaling = [6.028814e+03,1.048135e+04,1.789136e+04,1.862859e+04,4.121157e+04,7.401459e+04,1.630272e+05,3.074801e+05,5.765176e+05,1.648662e+06]


h = [0.25, 0.2, 0.166667, 0.142857, 0.111111, 0.0833333, 0.0625, 0.0454545, 0.0333333, 0.0243902]


fig3, ax3 = plt.subplots()

ax3.loglog(h, 2e3*np.power(h, -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
ax3.loglog(h, 1e2*np.power(h, -2.5), label=r"$\mathcal{O}(h^{2.5})$", linestyle="-.", color="black")
ax3.loglog(h, 1e1*np.power(h, -3), label=r"$\mathcal{O}(h^{3})$", linestyle="--", color="black")
ax3.loglog(h, cond_negvolume,  marker='p', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\text{volume}^{-1}$ scaling")
ax3.loglog(h, cond_noscaling,  marker='o', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"no scaling")
ax3.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
#ax3.legend(handles=[Ohneg2, space, square, circle, triangle],prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_title("RT0")
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
plt.show()

# %% [markdown]
# ### 28 June

# %%
# tau_w = 0.1, tau_a = 0.1, tau_b = 0.1 (with normals)

err_p_01_01_01 = [0.0199457, 0.0174212, 0.0132972, 0.0106431, 0.00799553, 0.00554254, 0.00370747, 0.00246373, 0.00170147, 0.00119862]
conv_p_01_01_01 = [0, 0.606454, 1.48164, 1.44433, 1.13812, 1.27373, 1.39774, 1.2833, 1.19354, 1.12147]
err_u_01_01_01 = [0.0516636, 0.0497051, 0.0409105, 0.0360387, 0.0310211, 0.0252184, 0.0194245, 0.0145354, 0.0108893, 0.00806178]
conv_u_01_01_01 = [0, 0.173192, 1.068, 0.822527, 0.596576, 0.719863, 0.907386, 0.910499, 0.931151, 0.962464]
err_divu_01_01_01 = [6.44259e-12, 5.23088e-11, 3.73509e-11, 2.07815e-11, 1.01851e-11, 7.72186e-11, 2.37399e-11, 1.75758e-10, 1.91958e-10, 5.4623e-10]
err_maxdivu_01_01_01 = [3.53834e-10, 9.75684e-10, 1.15517e-09, 5.89456e-10, 3.25931e-10, 5.80357e-09, 2.48483e-09, 6.90238e-08, 3.2688e-08, 2.05013e-07]

cond_01_01_01 = [2.884809e+04,7.181068e+04,8.896107e+04,7.082447e+04,1.242399e+05,2.739186e+05,4.003506e+05,7.158020e+05,2.428474e+06]
cond_01_01_01_server = [1.013597e+04,2.420934e+04,2.813385e+04,1.872918e+04,3.388703e+04,8.901836e+04,9.648696e+04,2.688849e+05,9.393482e+05,3.277491e+06]


#! constant scaling of RT0, and multiplied with area on Nedelec0

# tau_w = tau_a = tau_b = 0.1
err_p_01_01_01 = [0.021527, 0.0205078, 0.0148543, 0.0126294, 0.00992603, 0.00725948, 0.00519411, 0.00374702, 0.00274154, 0.00200338]
conv_p_01_01_01 = [0, 0.21738, 1.76893, 1.05265, 0.958413, 1.08749, 1.16372, 1.02548, 1.00737, 1.00419]
err_u_01_01_01 = [0.0543627, 0.0535372, 0.0433149, 0.037737, 0.0327652, 0.0269759, 0.0206431, 0.0156613, 0.0120868, 0.00926118]
conv_u_01_01_01 = [0, 0.0685665, 1.16212, 0.894303, 0.562138, 0.675825, 0.930066, 0.867269, 0.83534, 0.852433]
err_divu_01_01_01 = [5.0363e-11, 3.4181e-11, 2.47634e-10, 2.59471e-10, 2.90126e-12, 5.14717e-12, 3.80184e-11, 6.91292e-12, 8.7508e-12, 2.45519e-11]
h         err p          conv p         err u          conv u         err divu       err maxdivu    

0.25      0.0258537      0              0.0505271      0              8.86974e-14    1.14575e-12    
0.125     0.0111985      1.20707        0.0336744      0.585405       4.64157e-13    2.20464e-11    
0.0625    0.00538638     1.05591        0.0202047      0.736962       6.72441e-13    1.02489e-10    
0.03125   0.00262485     1.03708        0.011231       0.847208       2.69481e-12    1.1966e-09     
0.015625  0.0012947      1.01962        0.00623972     0.847929       8.61183e-12    3.72545e-09  
"""

# tau_w = 1, tau_m = 2, tau_b = 15
""" 
h         err p          conv p         err u          conv u         err divu       err maxdivu    

0.25      0.0133139      0              0.12824        0              6.41495e-10    2.81581e-09    
0.125     0.035875       -1.43004       0.0751308      0.771373       1.05212e-10    1.44044e-09    
0.0625    0.0184419      0.959994       0.0396524      0.921996       6.54738e-11    2.3958e-09     
0.03125   0.00680601     1.4381         0.0198913      0.99527        4.01238e-11    1.06366e-08    
0.015625  0.0022839      1.57531        0.010455       0.927949       7.18986e-11    2.25963e-08  
"""


h = [0.25, 0.2, 0.166667, 0.142857, 0.111111, 0.0833333, 0.0625, 0.0454545, 0.0333333, 0.0243902]


fig1, ax1 = plt.subplots()

ax1.loglog(h, 5.7e-1*np.power(h, 1), label=r"$\mathcal{O}(h)$", linestyle="-", color="black")

ax1.loglog(h, err_p_nostab,  marker='s', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$\|p-p_h\|_{\Omega}$, no stab.")
ax1.loglog(h, err_u_nostab,  marker='s', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, no stab.")
ax1.loglog(h, err_p_1_1_1,  marker='o', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\|p-p_h\|_{\Omega}$, $\tau_W = \tau_A = \tau_B = 1$")
ax1.loglog(h, err_u_1_1_1,  marker='o', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_W = \tau_A = \tau_B = 1$")
ax1.loglog(h, err_p_01_01_01,  marker='^', markersize=8,linestyle=":", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|p-p_h\|_{\Omega}$, $\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
ax1.loglog(h, err_u_01_01_01,  marker='^', markersize=8,linestyle="-.", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\|\mathbf{u}-\mathbf{u}_h\|_{\Omega}$, $\tau_W = 0.1,\ \tau_A = 0.1,\ \tau_B = 0.1$")

#ax1.legend(prop={'size': 13},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.legend(handles=[Oh2, pressure, velocity, space, square, circle, triangle],prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax1.set_xlabel(r"$h$ (log)", fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=17)
ax1.set_ylabel(r"$L^2$ error (log)", fontsize=22)
#ax1.set_title(r"Laplace-Beltrami, $\tau = 10^{-6}$")

plt.show()

fig3, ax3 = plt.subplots()

ax3.loglog(h[:-1], 2e3*np.power(h[:-1], -2), label=r"$\mathcal{O}(h^{2})$", linestyle="-", color="black")
#ax3.loglog(h, 5e1*np.power(h, -2.5), label=r"$\mathcal{O}(h^{2.5})$", linestyle="-.", color="black")
ax3.loglog(h[:-1], cond_nostab,  marker='s', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="black", label=r"no stab.")
#ax3.loglog(h[:-1], cond_1_1,  marker='o', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\tau_W = \tau_A = \tau_B = 1$")
ax3.loglog(h[:-1], cond_1_1_1,  marker='o', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C0", label=r"$\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
ax3.loglog(h[:-1], cond_01_01_01,  marker='^', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C2", label=r"$\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
ax3.loglog([0.25, 0.125, 0.0625, 0.03125],  [1.851092e+06,5.461285e+06,2.880016e+07,1.383240e+08])
#ax3.loglog(h, cond_areascaling_server,  marker='*', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C3", label=r"$\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")

#ax3.loglog(h[:-2], cond_hscaling,  marker='p', markersize=8, linestyle="--", markeredgewidth=0.8, markerfacecolor="None", color="C6", label=r"$\tau_W = 1,\ \tau_A = 0,\ \tau_B = 1$")
ax3.legend(handles=[Ohneg2, space, square, circle, triangle],prop={'size': 18},loc='center left', bbox_to_anchor=(1.0, 0.5), ncol=1, frameon=False)
ax3.set_xlabel(r"$h$ (log)", fontsize=18)
ax3.tick_params(axis='both', which='major', labelsize=17)
ax3.set_ylabel(r"Condition number (log)", fontsize=22)
#ax3.set_title(r"Laplace-Beltrami, $n=5$")

plt.show()
